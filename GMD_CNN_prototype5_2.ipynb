# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd
import torch
import torch.nn.functional as F
import torchaudio
import torchaudio.transforms as T
from torch.utils.data import Dataset

# %% [markdown]
# #verify Directories - do not need to rerun

# %%
import os
import pandas as pd

# Define base resource path
base_path = "/content/drive/My Drive/LUMT_Thesis_Resources"

# Metadata file path
metadata_path = os.path.join(base_path, "groove_2bar_16000hz_segmented_metadata_all_splits_withaudio_filepath_styleclass_10sec_split_rev_v2.csv") #changed for the new dataset with length_bin column

# Validate that paths exist
print("Checking directories and metadata:")
print(f"Base path exists: {os.path.exists(base_path)}")
print(f"Metadata file exists: {os.path.exists(metadata_path)}")

# Load metadata
metadata = pd.read_csv(metadata_path)

# Confirm required columns exist
assert 'split_rev' in metadata.columns, "'split_rev' column missing in metadata"
assert 'file_path' in metadata.columns, "'file_path' column missing in metadata"

# Preview and verify 3 file paths per split
print("\nChecking sample audio file existence for each split:")
for split in ['train', 'test', 'validation']:
    split_df = metadata[metadata['split_rev'] == split]
    sample_paths = split_df['file_path'].head(3)

    print(f"\n{split.capitalize()} split samples:")
    for rel_path in sample_paths:
        abs_path = os.path.join(base_path, rel_path)
        exists = os.path.exists(abs_path)
        print(f"File exists: {exists} - {abs_path}")
# Out:
# Checking directories and metadata:
# Base path exists: True
# Metadata file exists: True
#
# Checking sample audio file existence for each split:
#
# Train split samples:
# File exists: True - /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer1_session1_78_294.wav
# File exists: True - /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer8_session1_2_001.wav
# File exists: True - /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer1_session3_5_043.wav
#
# Test split samples:
# File exists: True - /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer8_session1_22_087.wav
# File exists: True - /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer1_session3_2_160.wav
# File exists: True - /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer8_session1_26_053.wav
#
# Validation split samples:
# File exists: True - /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer7_session2_64_040.wav
# File exists: True - /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer5_session2_6_065.wav
# File exists: True - /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer5_session2_2_024.wav

# %% [markdown]
# Note above how the split_rev is independednt of the original directory structures which was based on the initial split of the data.
#
# This way the model knows to look to the 'split_rev' to get the split then to the 'file_path' to get the exact location.
#
# This is instead of using some logic that assumes the file paths based on combining the base dir + audio folder +file names for example which would be used if the file paths matched the split_rev.
#
# This is crucial to note because it ensure no leakage between splits.

# %% [markdown]
# #Verify Class distributions

# %%
import pandas as pd

# Load metadata if not already loaded
metadata = pd.read_csv(metadata_path)

# Ensure column exists
assert 'split_rev' in metadata.columns
assert 'style_class' in metadata.columns

# Extract sorted unique classes
classes = sorted(metadata['style_class'].unique())
num_classes = len(classes)

print(f"Found {num_classes} unique classes: {classes}\n")

# Count total samples per class (entire dataset)
print("Total samples per class:")
total_class_counts = metadata['style_class'].value_counts().loc[classes]
for cls in classes:
    count = total_class_counts[cls]
    print(f"{cls}: {count} samples")

# Split-wise class distribution
print("\nClass distribution in new splits:\n")
for split in ['train', 'validation', 'test']:
    split_df = metadata[metadata['split_rev'] == split]
    total = len(split_df)
    print(f"{split.capitalize()} split:")
    print(f"Total samples: {total}")

    counts = split_df['style_class'].value_counts().reindex(classes, fill_value=0)
    for cls in classes:
        count = counts[cls]
        percent = (count / total) * 100
        print(f"{cls}: {count} samples ({percent:.1f}%)")
    print("")

# Index mapping
print("Class mapping:")
class_to_index = {i: cls for i, cls in enumerate(classes)}
for idx, cls in class_to_index.items():
    print(f"{idx}: {cls}")
# Out:
# Found 74 unique classes: ['afrobeat', 'afrocuban', 'afrocuban_bembe', 'afrocuban_calypso', 'afrocuban_rhumba', 'blues_shuffle', 'country', 'dance_breakbeat', 'dance_disco', 'funk', 'funk_fast', 'funk_groove1', 'funk_groove2', 'funk_groove5', 'funk_latin', 'funk_purdieshuffle', 'funk_rock', 'gospel', 'hiphop', 'hiphop_groove6', 'jazz', 'jazz_fast', 'jazz_funk', 'jazz_fusion', 'jazz_klezmer', 'jazz_linear', 'jazz_march', 'jazz_mediumfast', 'jazz_swing', 'latin', 'latin_ando', 'latin_bomba', 'latin_brazilian', 'latin_brazilian-baiao', 'latin_brazilian-bossa', 'latin_brazilian-frevo', 'latin_brazilian-ijexa', 'latin_brazilian-maracatu', 'latin_brazilian-samba', 'latin_brazilian-sambareggae', 'latin_brazilian-songo', 'latin_chacarera', 'latin_dominican-merengue', 'latin_merengue', 'latin_reggaeton', 'latin_samba', 'latin_venezuelan-joropo', 'latin_venezuelan-merengue', 'latin_venezuelan-sangueo', 'middleeastern', 'neworleans_chacha', 'neworleans_funk', 'neworleans_secondline', 'neworleans_shuffle', 'pop', 'pop_groove7', 'pop_soft', 'punk', 'reggae', 'reggae_slow', 'rock', 'rock_folk', 'rock_groove8', 'rock_halftime', 'rock_indie', 'rock_prog', 'rock_rockabilly', 'rock_shuffle', 'soul', 'soul_groove10', 'soul_groove3', 'soul_groove4', 'soul_groove9', 'soul_motown']
#
# Total samples per class:
# afrobeat: 303 samples
# afrocuban: 326 samples
# afrocuban_bembe: 104 samples
# afrocuban_calypso: 288 samples
# afrocuban_rhumba: 103 samples
# blues_shuffle: 87 samples
# country: 122 samples
# dance_breakbeat: 247 samples
# dance_disco: 294 samples
# funk: 1328 samples
# funk_fast: 130 samples
# funk_groove1: 60 samples
# funk_groove2: 60 samples
# funk_groove5: 60 samples
# funk_latin: 130 samples
# funk_purdieshuffle: 205 samples
# funk_rock: 45 samples
# gospel: 69 samples
# hiphop: 679 samples
# hiphop_groove6: 60 samples
# jazz: 911 samples
# jazz_fast: 460 samples
# jazz_funk: 170 samples
# jazz_fusion: 66 samples
# jazz_klezmer: 23 samples
# jazz_linear: 335 samples
# jazz_march: 237 samples
# jazz_mediumfast: 261 samples
# jazz_swing: 694 samples
# latin: 239 samples
# latin_ando: 111 samples
# latin_bomba: 88 samples
# latin_brazilian: 105 samples
# latin_brazilian-baiao: 216 samples
# latin_brazilian-bossa: 630 samples
# latin_brazilian-frevo: 79 samples
# latin_brazilian-ijexa: 85 samples
# latin_brazilian-maracatu: 181 samples
# latin_brazilian-samba: 319 samples
# latin_brazilian-sambareggae: 179 samples
# latin_brazilian-songo: 308 samples
# latin_chacarera: 241 samples
# latin_dominican-merengue: 166 samples
# latin_merengue: 11 samples
# latin_reggaeton: 36 samples
# latin_samba: 197 samples
# latin_venezuelan-joropo: 41 samples
# latin_venezuelan-merengue: 89 samples
# latin_venezuelan-sangueo: 33 samples
# middleeastern: 118 samples
# neworleans_chacha: 59 samples
# neworleans_funk: 303 samples
# neworleans_secondline: 211 samples
# neworleans_shuffle: 56 samples
# pop: 180 samples
# pop_groove7: 60 samples
# pop_soft: 74 samples
# punk: 273 samples
# reggae: 253 samples
# reggae_slow: 29 samples
# rock: 3528 samples
# rock_folk: 101 samples
# rock_groove8: 60 samples
# rock_halftime: 271 samples
# rock_indie: 53 samples
# rock_prog: 278 samples
# rock_rockabilly: 260 samples
# rock_shuffle: 273 samples
# soul: 225 samples
# soul_groove10: 60 samples
# soul_groove3: 60 samples
# soul_groove4: 60 samples
# soul_groove9: 60 samples
# soul_motown: 148 samples
#
# Class distribution in new splits:
#
# Train split:
# Total samples: 14611
# afrobeat: 242 samples (1.7%)
# afrocuban: 261 samples (1.8%)
# afrocuban_bembe: 83 samples (0.6%)
# afrocuban_calypso: 230 samples (1.6%)
# afrocuban_rhumba: 82 samples (0.6%)
# blues_shuffle: 70 samples (0.5%)
# country: 98 samples (0.7%)
# dance_breakbeat: 198 samples (1.4%)
# dance_disco: 235 samples (1.6%)
# funk: 1062 samples (7.3%)
# funk_fast: 104 samples (0.7%)
# funk_groove1: 48 samples (0.3%)
# funk_groove2: 48 samples (0.3%)
# funk_groove5: 48 samples (0.3%)
# funk_latin: 104 samples (0.7%)
# funk_purdieshuffle: 164 samples (1.1%)
# funk_rock: 36 samples (0.2%)
# gospel: 55 samples (0.4%)
# hiphop: 543 samples (3.7%)
# hiphop_groove6: 48 samples (0.3%)
# jazz: 729 samples (5.0%)
# jazz_fast: 368 samples (2.5%)
# jazz_funk: 136 samples (0.9%)
# jazz_fusion: 53 samples (0.4%)
# jazz_klezmer: 19 samples (0.1%)
# jazz_linear: 268 samples (1.8%)
# jazz_march: 190 samples (1.3%)
# jazz_mediumfast: 209 samples (1.4%)
# jazz_swing: 555 samples (3.8%)
# latin: 191 samples (1.3%)
# latin_ando: 89 samples (0.6%)
# latin_bomba: 71 samples (0.5%)
# latin_brazilian: 84 samples (0.6%)
# latin_brazilian-baiao: 173 samples (1.2%)
# latin_brazilian-bossa: 504 samples (3.4%)
# latin_brazilian-frevo: 63 samples (0.4%)
# latin_brazilian-ijexa: 68 samples (0.5%)
# latin_brazilian-maracatu: 145 samples (1.0%)
# latin_brazilian-samba: 255 samples (1.7%)
# latin_brazilian-sambareggae: 143 samples (1.0%)
# latin_brazilian-songo: 246 samples (1.7%)
# latin_chacarera: 193 samples (1.3%)
# latin_dominican-merengue: 133 samples (0.9%)
# latin_merengue: 9 samples (0.1%)
# latin_reggaeton: 29 samples (0.2%)
# latin_samba: 158 samples (1.1%)
# latin_venezuelan-joropo: 33 samples (0.2%)
# latin_venezuelan-merengue: 71 samples (0.5%)
# latin_venezuelan-sangueo: 27 samples (0.2%)
# middleeastern: 94 samples (0.6%)
# neworleans_chacha: 47 samples (0.3%)
# neworleans_funk: 242 samples (1.7%)
# neworleans_secondline: 169 samples (1.2%)
# neworleans_shuffle: 45 samples (0.3%)
# pop: 144 samples (1.0%)
# pop_groove7: 48 samples (0.3%)
# pop_soft: 59 samples (0.4%)
# punk: 218 samples (1.5%)
# reggae: 202 samples (1.4%)
# reggae_slow: 23 samples (0.2%)
# rock: 2822 samples (19.3%)
# rock_folk: 81 samples (0.6%)
# rock_groove8: 48 samples (0.3%)
# rock_halftime: 217 samples (1.5%)
# rock_indie: 43 samples (0.3%)
# rock_prog: 222 samples (1.5%)
# rock_rockabilly: 208 samples (1.4%)
# rock_shuffle: 218 samples (1.5%)
# soul: 180 samples (1.2%)
# soul_groove10: 48 samples (0.3%)
# soul_groove3: 48 samples (0.3%)
# soul_groove4: 48 samples (0.3%)
# soul_groove9: 48 samples (0.3%)
# soul_motown: 118 samples (0.8%)
#
# Validation split:
# Total samples: 1826
# afrobeat: 30 samples (1.6%)
# afrocuban: 32 samples (1.8%)
# afrocuban_bembe: 11 samples (0.6%)
# afrocuban_calypso: 29 samples (1.6%)
# afrocuban_rhumba: 11 samples (0.6%)
# blues_shuffle: 9 samples (0.5%)
# country: 12 samples (0.7%)
# dance_breakbeat: 24 samples (1.3%)
# dance_disco: 29 samples (1.6%)
# funk: 133 samples (7.3%)
# funk_fast: 13 samples (0.7%)
# funk_groove1: 6 samples (0.3%)
# funk_groove2: 6 samples (0.3%)
# funk_groove5: 6 samples (0.3%)
# funk_latin: 13 samples (0.7%)
# funk_purdieshuffle: 20 samples (1.1%)
# funk_rock: 5 samples (0.3%)
# gospel: 7 samples (0.4%)
# hiphop: 68 samples (3.7%)
# hiphop_groove6: 6 samples (0.3%)
# jazz: 91 samples (5.0%)
# jazz_fast: 46 samples (2.5%)
# jazz_funk: 17 samples (0.9%)
# jazz_fusion: 7 samples (0.4%)
# jazz_klezmer: 2 samples (0.1%)
# jazz_linear: 33 samples (1.8%)
# jazz_march: 23 samples (1.3%)
# jazz_mediumfast: 26 samples (1.4%)
# jazz_swing: 69 samples (3.8%)
# latin: 24 samples (1.3%)
# latin_ando: 11 samples (0.6%)
# latin_bomba: 9 samples (0.5%)
# latin_brazilian: 11 samples (0.6%)
# latin_brazilian-baiao: 21 samples (1.2%)
# latin_brazilian-bossa: 63 samples (3.5%)
# latin_brazilian-frevo: 8 samples (0.4%)
# latin_brazilian-ijexa: 9 samples (0.5%)
# latin_brazilian-maracatu: 18 samples (1.0%)
# latin_brazilian-samba: 32 samples (1.8%)
# latin_brazilian-sambareggae: 18 samples (1.0%)
# latin_brazilian-songo: 31 samples (1.7%)
# latin_chacarera: 24 samples (1.3%)
# latin_dominican-merengue: 17 samples (0.9%)
# latin_merengue: 1 samples (0.1%)
# latin_reggaeton: 4 samples (0.2%)
# latin_samba: 20 samples (1.1%)
# latin_venezuelan-joropo: 4 samples (0.2%)
# latin_venezuelan-merengue: 9 samples (0.5%)
# latin_venezuelan-sangueo: 3 samples (0.2%)
# middleeastern: 12 samples (0.7%)
# neworleans_chacha: 6 samples (0.3%)
# neworleans_funk: 30 samples (1.6%)
# neworleans_secondline: 21 samples (1.2%)
# neworleans_shuffle: 6 samples (0.3%)
# pop: 18 samples (1.0%)
# pop_groove7: 6 samples (0.3%)
# pop_soft: 8 samples (0.4%)
# punk: 27 samples (1.5%)
# reggae: 25 samples (1.4%)
# reggae_slow: 3 samples (0.2%)
# rock: 353 samples (19.3%)
# rock_folk: 10 samples (0.5%)
# rock_groove8: 6 samples (0.3%)
# rock_halftime: 27 samples (1.5%)
# rock_indie: 5 samples (0.3%)
# rock_prog: 28 samples (1.5%)
# rock_rockabilly: 26 samples (1.4%)
# rock_shuffle: 27 samples (1.5%)
# soul: 22 samples (1.2%)
# soul_groove10: 6 samples (0.3%)
# soul_groove3: 6 samples (0.3%)
# soul_groove4: 6 samples (0.3%)
# soul_groove9: 6 samples (0.3%)
# soul_motown: 15 samples (0.8%)
#
# Test split:
# Total samples: 1827
# afrobeat: 31 samples (1.7%)
# afrocuban: 33 samples (1.8%)
# afrocuban_bembe: 10 samples (0.5%)
# afrocuban_calypso: 29 samples (1.6%)
# afrocuban_rhumba: 10 samples (0.5%)
# blues_shuffle: 8 samples (0.4%)
# country: 12 samples (0.7%)
# dance_breakbeat: 25 samples (1.4%)
# dance_disco: 30 samples (1.6%)
# funk: 133 samples (7.3%)
# funk_fast: 13 samples (0.7%)
# funk_groove1: 6 samples (0.3%)
# funk_groove2: 6 samples (0.3%)
# funk_groove5: 6 samples (0.3%)
# funk_latin: 13 samples (0.7%)
# funk_purdieshuffle: 21 samples (1.1%)
# funk_rock: 4 samples (0.2%)
# gospel: 7 samples (0.4%)
# hiphop: 68 samples (3.7%)
# hiphop_groove6: 6 samples (0.3%)
# jazz: 91 samples (5.0%)
# jazz_fast: 46 samples (2.5%)
# jazz_funk: 17 samples (0.9%)
# jazz_fusion: 6 samples (0.3%)
# jazz_klezmer: 2 samples (0.1%)
# jazz_linear: 34 samples (1.9%)
# jazz_march: 24 samples (1.3%)
# jazz_mediumfast: 26 samples (1.4%)
# jazz_swing: 70 samples (3.8%)
# latin: 24 samples (1.3%)
# latin_ando: 11 samples (0.6%)
# latin_bomba: 8 samples (0.4%)
# latin_brazilian: 10 samples (0.5%)
# latin_brazilian-baiao: 22 samples (1.2%)
# latin_brazilian-bossa: 63 samples (3.4%)
# latin_brazilian-frevo: 8 samples (0.4%)
# latin_brazilian-ijexa: 8 samples (0.4%)
# latin_brazilian-maracatu: 18 samples (1.0%)
# latin_brazilian-samba: 32 samples (1.8%)
# latin_brazilian-sambareggae: 18 samples (1.0%)
# latin_brazilian-songo: 31 samples (1.7%)
# latin_chacarera: 24 samples (1.3%)
# latin_dominican-merengue: 16 samples (0.9%)
# latin_merengue: 1 samples (0.1%)
# latin_reggaeton: 3 samples (0.2%)
# latin_samba: 19 samples (1.0%)
# latin_venezuelan-joropo: 4 samples (0.2%)
# latin_venezuelan-merengue: 9 samples (0.5%)
# latin_venezuelan-sangueo: 3 samples (0.2%)
# middleeastern: 12 samples (0.7%)
# neworleans_chacha: 6 samples (0.3%)
# neworleans_funk: 31 samples (1.7%)
# neworleans_secondline: 21 samples (1.1%)
# neworleans_shuffle: 5 samples (0.3%)
# pop: 18 samples (1.0%)
# pop_groove7: 6 samples (0.3%)
# pop_soft: 7 samples (0.4%)
# punk: 28 samples (1.5%)
# reggae: 26 samples (1.4%)
# reggae_slow: 3 samples (0.2%)
# rock: 353 samples (19.3%)
# rock_folk: 10 samples (0.5%)
# rock_groove8: 6 samples (0.3%)
# rock_halftime: 27 samples (1.5%)
# rock_indie: 5 samples (0.3%)
# rock_prog: 28 samples (1.5%)
# rock_rockabilly: 26 samples (1.4%)
# rock_shuffle: 28 samples (1.5%)
# soul: 23 samples (1.3%)
# soul_groove10: 6 samples (0.3%)
# soul_groove3: 6 samples (0.3%)
# soul_groove4: 6 samples (0.3%)
# soul_groove9: 6 samples (0.3%)
# soul_motown: 15 samples (0.8%)
#
# Class mapping:
# 0: afrobeat
# 1: afrocuban
# 2: afrocuban_bembe
# 3: afrocuban_calypso
# 4: afrocuban_rhumba
# 5: blues_shuffle
# 6: country
# 7: dance_breakbeat
# 8: dance_disco
# 9: funk
# 10: funk_fast
# 11: funk_groove1
# 12: funk_groove2
# 13: funk_groove5
# 14: funk_latin
# 15: funk_purdieshuffle
# 16: funk_rock
# 17: gospel
# 18: hiphop
# 19: hiphop_groove6
# 20: jazz
# 21: jazz_fast
# 22: jazz_funk
# 23: jazz_fusion
# 24: jazz_klezmer
# 25: jazz_linear
# 26: jazz_march
# 27: jazz_mediumfast
# 28: jazz_swing
# 29: latin
# 30: latin_ando
# 31: latin_bomba
# 32: latin_brazilian
# 33: latin_brazilian-baiao
# 34: latin_brazilian-bossa
# 35: latin_brazilian-frevo
# 36: latin_brazilian-ijexa
# 37: latin_brazilian-maracatu
# 38: latin_brazilian-samba
# 39: latin_brazilian-sambareggae
# 40: latin_brazilian-songo
# 41: latin_chacarera
# 42: latin_dominican-merengue
# 43: latin_merengue
# 44: latin_reggaeton
# 45: latin_samba
# 46: latin_venezuelan-joropo
# 47: latin_venezuelan-merengue
# 48: latin_venezuelan-sangueo
# 49: middleeastern
# 50: neworleans_chacha
# 51: neworleans_funk
# 52: neworleans_secondline
# 53: neworleans_shuffle
# 54: pop
# 55: pop_groove7
# 56: pop_soft
# 57: punk
# 58: reggae
# 59: reggae_slow
# 60: rock
# 61: rock_folk
# 62: rock_groove8
# 63: rock_halftime
# 64: rock_indie
# 65: rock_prog
# 66: rock_rockabilly
# 67: rock_shuffle
# 68: soul
# 69: soul_groove10
# 70: soul_groove3
# 71: soul_groove4
# 72: soul_groove9
# 73: soul_motown

# %% [markdown]
# #Dataset Class

# %%
# Constants
BASE_DIR = "/content/drive/My Drive/LUMT_Thesis_Resources/"
SAMPLE_RATE = 16_000
CLIP_LENGTH_SAMPLES = SAMPLE_RATE * 10  # 10 seconds = 160000 samples
METADATA_FILE = "groove_2bar_16000hz_segmented_metadata_all_splits_withaudio_filepath_styleclass_10sec_split_rev_v2.csv"
metadata_path = os.path.join(BASE_DIR, METADATA_FILE)

class GrooveDataset(Dataset):
    def __init__(self, split: str):
        assert split in ['train', 'test', 'validation'], f"Invalid split: {split}"

        print(f" Loading metadata from: {metadata_path}")
        df = pd.read_csv(metadata_path)
        print(f" Full metadata loaded: {df.shape[0]} rows")

        # Filter based on revised split
        df = df[df['split_rev'] == split].reset_index(drop=True) #new dataframe per split
        print(f" Subset for '{split}' split: {df.shape[0]} rows")

        # Check required columns
        assert 'file_path' in df.columns, "Missing 'file_path' in metadata"
        assert 'style_class' in df.columns, "Missing 'style_class' in metadata"

        # Convert relative paths to absolute
        df['file_path'] = df['file_path'].apply(lambda x: os.path.join(BASE_DIR, x))

        # Store processed dataframe
        self.data_df = df

        # Build label mapping
        self.labels = sorted(df["style_class"].unique())
        self.class_to_idx = {label: idx for idx, label in enumerate(self.labels)}

        print(" Available classes and mapping:")
        for idx, label in self.class_to_idx.items():
            print(f"  {label}: {idx}")

        # Preview head
        print(" Preview of dataset:")
        print(self.data_df[['file_path', 'style_class']].head(3))

    def __len__(self):
        return len(self.data_df)

    def __getitem__(self, idx):
        row = self.data_df.iloc[idx]
        file_path = row["file_path"]
        label = row["style_class"]

        try:
            waveform, sr = torchaudio.load(file_path)

            # Resample if needed
            if sr != SAMPLE_RATE:
                print(f"[RESAMPLE] {file_path}: {sr}Hz → {SAMPLE_RATE}Hz")
                resampler = T.Resample(orig_freq=sr, new_freq=SAMPLE_RATE)
                waveform = resampler(waveform)

            # Convert to mono
            if waveform.shape[0] > 1:
                waveform = waveform.mean(dim=0, keepdim=True)

            num_samples = waveform.size(1)
            print(f"[AUDIO] {file_path} | Original samples: {num_samples}")

            if num_samples < CLIP_LENGTH_SAMPLES:
                waveform = F.pad(waveform, (0, CLIP_LENGTH_SAMPLES - num_samples))
                print(f"[PADDED] Padded to {CLIP_LENGTH_SAMPLES}")
            else:
                waveform = waveform[:, :CLIP_LENGTH_SAMPLES]
                print(f"[TRIMMED] Trimmed to {CLIP_LENGTH_SAMPLES}")

            label_index = self.class_to_idx[label]
            return waveform, label_index, SAMPLE_RATE

        except Exception as e:
            print(f"[ERROR] Failed loading {file_path}: {e}")
            return None

# --- Instantiate all splits below ---

print(" Instantiating all dataset splits...\n")
train_dataset = GrooveDataset(split="train")
val_dataset = GrooveDataset(split="validation")
test_dataset = GrooveDataset(split="test")

# Print sizes
print(f" Dataset sizes:")
print(f"Train: {len(train_dataset)} samples")
print(f"Validation: {len(val_dataset)} samples")
print(f"Test: {len(test_dataset)} samples")

# Trigger sample loading for verification
print(f" Triggering 1 sample from each split for verification:")
_ = train_dataset[0]
_ = val_dataset[0]
_ = test_dataset[0]
# Out:
#  Instantiating all dataset splits...
#
#  Loading metadata from: /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_16000hz_segmented_metadata_all_splits_withaudio_filepath_styleclass_10sec_split_rev_v2.csv
#  Full metadata loaded: 18264 rows
#  Subset for 'train' split: 14611 rows
#  Available classes and mapping:
#   0: afrobeat
#   1: afrocuban
#   2: afrocuban_bembe
#   3: afrocuban_calypso
#   4: afrocuban_rhumba
#   5: blues_shuffle
#   6: country
#   7: dance_breakbeat
#   8: dance_disco
#   9: funk
#   10: funk_fast
#   11: funk_groove1
#   12: funk_groove2
#   13: funk_groove5
#   14: funk_latin
#   15: funk_purdieshuffle
#   16: funk_rock
#   17: gospel
#   18: hiphop
#   19: hiphop_groove6
#   20: jazz
#   21: jazz_fast
#   22: jazz_funk
#   23: jazz_fusion
#   24: jazz_klezmer
#   25: jazz_linear
#   26: jazz_march
#   27: jazz_mediumfast
#   28: jazz_swing
#   29: latin
#   30: latin_ando
#   31: latin_bomba
#   32: latin_brazilian
#   33: latin_brazilian-baiao
#   34: latin_brazilian-bossa
#   35: latin_brazilian-frevo
#   36: latin_brazilian-ijexa
#   37: latin_brazilian-maracatu
#   38: latin_brazilian-samba
#   39: latin_brazilian-sambareggae
#   40: latin_brazilian-songo
#   41: latin_chacarera
#   42: latin_dominican-merengue
#   43: latin_merengue
#   44: latin_reggaeton
#   45: latin_samba
#   46: latin_venezuelan-joropo
#   47: latin_venezuelan-merengue
#   48: latin_venezuelan-sangueo
#   49: middleeastern
#   50: neworleans_chacha
#   51: neworleans_funk
#   52: neworleans_secondline
#   53: neworleans_shuffle
#   54: pop
#   55: pop_groove7
#   56: pop_soft
#   57: punk
#   58: reggae
#   59: reggae_slow
#   60: rock
#   61: rock_folk
#   62: rock_groove8
#   63: rock_halftime
#   64: rock_indie
#   65: rock_prog
#   66: rock_rockabilly
#   67: rock_shuffle
#   68: soul
#   69: soul_groove10
#   70: soul_groove3
#   71: soul_groove4
#   72: soul_groove9
#   73: soul_motown
#  Preview of dataset:
#                                            file_path  style_class
# 0  /content/drive/My Drive/LUMT_Thesis_Resources/...    jazz_fast
# 1  /content/drive/My Drive/LUMT_Thesis_Resources/...         funk
# 2  /content/drive/My Drive/LUMT_Thesis_Resources/...  jazz_linear
#  Loading metadata from: /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_16000hz_segmented_metadata_all_splits_withaudio_filepath_styleclass_10sec_split_rev_v2.csv
#  Full metadata loaded: 18264 rows
#  Subset for 'validation' split: 1826 rows
#  Available classes and mapping:
#   0: afrobeat
#   1: afrocuban
#   2: afrocuban_bembe
#   3: afrocuban_calypso
#   4: afrocuban_rhumba
#   5: blues_shuffle
#   6: country
#   7: dance_breakbeat
#   8: dance_disco
#   9: funk
#   10: funk_fast
#   11: funk_groove1
#   12: funk_groove2
#   13: funk_groove5
#   14: funk_latin
#   15: funk_purdieshuffle
#   16: funk_rock
#   17: gospel
#   18: hiphop
#   19: hiphop_groove6
#   20: jazz
#   21: jazz_fast
#   22: jazz_funk
#   23: jazz_fusion
#   24: jazz_klezmer
#   25: jazz_linear
#   26: jazz_march
#   27: jazz_mediumfast
#   28: jazz_swing
#   29: latin
#   30: latin_ando
#   31: latin_bomba
#   32: latin_brazilian
#   33: latin_brazilian-baiao
#   34: latin_brazilian-bossa
#   35: latin_brazilian-frevo
#   36: latin_brazilian-ijexa
#   37: latin_brazilian-maracatu
#   38: latin_brazilian-samba
#   39: latin_brazilian-sambareggae
#   40: latin_brazilian-songo
#   41: latin_chacarera
#   42: latin_dominican-merengue
#   43: latin_merengue
#   44: latin_reggaeton
#   45: latin_samba
#   46: latin_venezuelan-joropo
#   47: latin_venezuelan-merengue
#   48: latin_venezuelan-sangueo
#   49: middleeastern
#   50: neworleans_chacha
#   51: neworleans_funk
#   52: neworleans_secondline
#   53: neworleans_shuffle
#   54: pop
#   55: pop_groove7
#   56: pop_soft
#   57: punk
#   58: reggae
#   59: reggae_slow
#   60: rock
#   61: rock_folk
#   62: rock_groove8
#   63: rock_halftime
#   64: rock_indie
#   65: rock_prog
#   66: rock_rockabilly
#   67: rock_shuffle
#   68: soul
#   69: soul_groove10
#   70: soul_groove3
#   71: soul_groove4
#   72: soul_groove9
#   73: soul_motown
#  Preview of dataset:
#                                            file_path            style_class
# 0  /content/drive/My Drive/LUMT_Thesis_Resources/...                   rock
# 1  /content/drive/My Drive/LUMT_Thesis_Resources/...  neworleans_secondline
# 2  /content/drive/My Drive/LUMT_Thesis_Resources/...        latin_brazilian
#  Loading metadata from: /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_16000hz_segmented_metadata_all_splits_withaudio_filepath_styleclass_10sec_split_rev_v2.csv
#  Full metadata loaded: 18264 rows
#  Subset for 'test' split: 1827 rows
#  Available classes and mapping:
#   0: afrobeat
#   1: afrocuban
#   2: afrocuban_bembe
#   3: afrocuban_calypso
#   4: afrocuban_rhumba
#   5: blues_shuffle
#   6: country
#   7: dance_breakbeat
#   8: dance_disco
#   9: funk
#   10: funk_fast
#   11: funk_groove1
#   12: funk_groove2
#   13: funk_groove5
#   14: funk_latin
#   15: funk_purdieshuffle
#   16: funk_rock
#   17: gospel
#   18: hiphop
#   19: hiphop_groove6
#   20: jazz
#   21: jazz_fast
#   22: jazz_funk
#   23: jazz_fusion
#   24: jazz_klezmer
#   25: jazz_linear
#   26: jazz_march
#   27: jazz_mediumfast
#   28: jazz_swing
#   29: latin
#   30: latin_ando
#   31: latin_bomba
#   32: latin_brazilian
#   33: latin_brazilian-baiao
#   34: latin_brazilian-bossa
#   35: latin_brazilian-frevo
#   36: latin_brazilian-ijexa
#   37: latin_brazilian-maracatu
#   38: latin_brazilian-samba
#   39: latin_brazilian-sambareggae
#   40: latin_brazilian-songo
#   41: latin_chacarera
#   42: latin_dominican-merengue
#   43: latin_merengue
#   44: latin_reggaeton
#   45: latin_samba
#   46: latin_venezuelan-joropo
#   47: latin_venezuelan-merengue
#   48: latin_venezuelan-sangueo
#   49: middleeastern
#   50: neworleans_chacha
#   51: neworleans_funk
#   52: neworleans_secondline
#   53: neworleans_shuffle
#   54: pop
#   55: pop_groove7
#   56: pop_soft
#   57: punk
#   58: reggae
#   59: reggae_slow
#   60: rock
#   61: rock_folk
#   62: rock_groove8
#   63: rock_halftime
#   64: rock_indie
#   65: rock_prog
#   66: rock_rockabilly
#   67: rock_shuffle
#   68: soul
#   69: soul_groove10
#   70: soul_groove3
#   71: soul_groove4
#   72: soul_groove9
#   73: soul_motown
#  Preview of dataset:
#                                            file_path style_class
# 0  /content/drive/My Drive/LUMT_Thesis_Resources/...        funk
# 1  /content/drive/My Drive/LUMT_Thesis_Resources/...  jazz_swing
# 2  /content/drive/My Drive/LUMT_Thesis_Resources/...    afrobeat
#  Dataset sizes:
# Train: 14611 samples
# Validation: 1826 samples
# Test: 1827 samples
#  Triggering 1 sample from each split for verification:
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer1_session1_78_294.wav | Original samples: 26483
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer7_session2_64_040.wav | Original samples: 52965
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer8_session1_22_087.wav | Original samples: 66783
# [PADDED] Padded to 160000

# %% [markdown]
# #Sanity Checks for datasets

# %%
# Sanity check: trigger 3 samples per dataset after instantiation

print(" Running sanity check: first 3 samples from each split\n")

dataset_dict = {
    "train": train_dataset,
    "validation": val_dataset,
    "test": test_dataset
}

for split_name, dataset in dataset_dict.items():
    print(f" Split: {split_name.upper()}")
    print(f"Size: {len(dataset)} samples")

    for i in range(3):
        print(f" Sample {i+1}:")
        _ = dataset[i]
# Out:
#  Running sanity check: first 3 samples from each split
#
#  Split: TRAIN
# Size: 14611 samples
#  Sample 1:
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer1_session1_78_294.wav | Original samples: 26483
# [PADDED] Padded to 160000
#  Sample 2:
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer8_session1_2_001.wav | Original samples: 80842
# [PADDED] Padded to 160000
#  Sample 3:
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer1_session3_5_043.wav | Original samples: 60000
# [PADDED] Padded to 160000
#  Split: VALIDATION
# Size: 1826 samples
#  Sample 1:
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer7_session2_64_040.wav | Original samples: 52965
# [PADDED] Padded to 160000
#  Sample 2:
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer5_session2_6_065.wav | Original samples: 77575
# [PADDED] Padded to 160000
#  Sample 3:
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer5_session2_2_024.wav | Original samples: 76039
# [PADDED] Padded to 160000
#  Split: TEST
# Size: 1827 samples
#  Sample 1:
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer8_session1_22_087.wav | Original samples: 66783
# [PADDED] Padded to 160000
#  Sample 2:
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer1_session3_2_160.wav | Original samples: 41513
# [PADDED] Padded to 160000
#  Sample 3:
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer8_session1_26_053.wav | Original samples: 81702
# [PADDED] Padded to 160000

# %%
# Enhanced debug: Inspect waveform, label, and metadata for 3 samples per split

print(" Detailed shape and label check per split...\n")

dataset_dict = {
    "train": train_dataset,
    "validation": val_dataset,
    "test": test_dataset
}

for split_name, dataset in dataset_dict.items():
    print(f" SPLIT: {split_name.upper()}")
    for i in range(3):
        print(f" Sample {i+1}:")

        # Load waveform, label index, sample rate
        sample_waveform, sample_label_idx, sample_rate = dataset[i]

        # Get corresponding metadata
        row = dataset.data_df.iloc[i]
        split_rev = row['split_rev']
        file_path = row['file_path']
        style_class = row['style_class']

        # Print info
        print(f"  ➤ split_rev     : {split_rev}")
        print(f"  ➤ file_path     : {file_path}")
        print(f"  ➤ style_class   : {style_class}")
        print(f"  ➤ label index   : {sample_label_idx}")
        print(f"  ➤ waveform shape: {sample_waveform.shape}")
        print(f"  ➤ sample rate   : {sample_rate}")
# Out:
#  Detailed shape and label check per split...
#
#  SPLIT: TRAIN
#  Sample 1:
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer1_session1_78_294.wav | Original samples: 26483
# [PADDED] Padded to 160000
#   ➤ split_rev     : train
#   ➤ file_path     : /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer1_session1_78_294.wav
#   ➤ style_class   : jazz_fast
#   ➤ label index   : 21
#   ➤ waveform shape: torch.Size([1, 160000])
#   ➤ sample rate   : 16000
#  Sample 2:
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer8_session1_2_001.wav | Original samples: 80842
# [PADDED] Padded to 160000
#   ➤ split_rev     : train
#   ➤ file_path     : /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer8_session1_2_001.wav
#   ➤ style_class   : funk
#   ➤ label index   : 9
#   ➤ waveform shape: torch.Size([1, 160000])
#   ➤ sample rate   : 16000
#  Sample 3:
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer1_session3_5_043.wav | Original samples: 60000
# [PADDED] Padded to 160000
#   ➤ split_rev     : train
#   ➤ file_path     : /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer1_session3_5_043.wav
#   ➤ style_class   : jazz_linear
#   ➤ label index   : 25
#   ➤ waveform shape: torch.Size([1, 160000])
#   ➤ sample rate   : 16000
#  SPLIT: VALIDATION
#  Sample 1:
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer7_session2_64_040.wav | Original samples: 52965
# [PADDED] Padded to 160000
#   ➤ split_rev     : validation
#   ➤ file_path     : /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer7_session2_64_040.wav
#   ➤ style_class   : rock
#   ➤ label index   : 60
#   ➤ waveform shape: torch.Size([1, 160000])
#   ➤ sample rate   : 16000
#  Sample 2:
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer5_session2_6_065.wav | Original samples: 77575
# [PADDED] Padded to 160000
#   ➤ split_rev     : validation
#   ➤ file_path     : /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer5_session2_6_065.wav
#   ➤ style_class   : neworleans_secondline
#   ➤ label index   : 52
#   ➤ waveform shape: torch.Size([1, 160000])
#   ➤ sample rate   : 16000
#  Sample 3:
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer5_session2_2_024.wav | Original samples: 76039
# [PADDED] Padded to 160000
#   ➤ split_rev     : validation
#   ➤ file_path     : /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer5_session2_2_024.wav
#   ➤ style_class   : latin_brazilian
#   ➤ label index   : 32
#   ➤ waveform shape: torch.Size([1, 160000])
#   ➤ sample rate   : 16000
#  SPLIT: TEST
#  Sample 1:
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer8_session1_22_087.wav | Original samples: 66783
# [PADDED] Padded to 160000
#   ➤ split_rev     : test
#   ➤ file_path     : /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer8_session1_22_087.wav
#   ➤ style_class   : funk
#   ➤ label index   : 9
#   ➤ waveform shape: torch.Size([1, 160000])
#   ➤ sample rate   : 16000
#  Sample 2:
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer1_session3_2_160.wav | Original samples: 41513
# [PADDED] Padded to 160000
#   ➤ split_rev     : test
#   ➤ file_path     : /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer1_session3_2_160.wav
#   ➤ style_class   : jazz_swing
#   ➤ label index   : 28
#   ➤ waveform shape: torch.Size([1, 160000])
#   ➤ sample rate   : 16000
#  Sample 3:
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer8_session1_26_053.wav | Original samples: 81702
# [PADDED] Padded to 160000
#   ➤ split_rev     : test
#   ➤ file_path     : /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer8_session1_26_053.wav
#   ➤ style_class   : afrobeat
#   ➤ label index   : 0
#   ➤ waveform shape: torch.Size([1, 160000])
#   ➤ sample rate   : 16000

# %% [markdown]
# #Waveform Features class and verify Feature Extraction

# %%
import torch.nn as nn
import torchaudio.transforms as T

class WaveformFeatures(nn.Module):
    def __init__(
        self,
        sample_rate=16_000,
        n_fft=1024,
        n_mels=128,
        power=2.0, #default value
    ):
        super().__init__()
        hop_length = n_fft // 4

        self.spectrogram = T.Spectrogram(n_fft=n_fft, hop_length=hop_length, power=power)
        self.mel_scale = T.MelScale(n_mels=n_mels, sample_rate=sample_rate, n_stft=n_fft // 2 + 1)

    def forward(self, waveform: torch.Tensor) -> torch.Tensor:
        # waveform: (1, N)
        spec = self.spectrogram(waveform)  # (1, F, T)
        mel_spec = self.mel_scale(spec)    # (1, M, T)
        return mel_spec

# %%
# Feature extraction test on real dataset sample
print(" Verifying Mel Spectrogram extraction pipeline...")

# Use existing train_dataset (already filtered, padded)
sample_waveform, sample_label_idx, sample_rate = train_dataset[0]

print(f"Input waveform shape: {sample_waveform.shape}")
print(f"Sample rate: {sample_rate}")
print(f"Label index: {sample_label_idx}")
print(f"Original class: {train_dataset.data_df.iloc[0]['style_class']}")
print(f"From file: {train_dataset.data_df.iloc[0]['file_path']}")

# Instantiate feature extractor
feature_extractor = WaveformFeatures(sample_rate=sample_rate)

# Generate log-mel spectrogram
mel_spectrogram = feature_extractor(sample_waveform)

# Print output shape
print(f" Mel Spectrogram shape: {mel_spectrogram.shape}")
# Out:
#  Verifying Mel Spectrogram extraction pipeline...
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer1_session1_78_294.wav | Original samples: 26483
# [PADDED] Padded to 160000
# Input waveform shape: torch.Size([1, 160000])
# Sample rate: 16000
# Label index: 21
# Original class: jazz_fast
# From file: /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer1_session1_78_294.wav
#  Mel Spectrogram shape: torch.Size([1, 128, 626])

# %% [markdown]
# #DataLoader

# %%
from torch.utils.data import DataLoader

# Hyperparameters
BATCH_SIZE = 16
NUM_WORKERS = 0  # Safe default for Colab

# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS)
val_loader   = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)
test_loader  = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)

print("DataLoaders created")

# Sample batch from train loader to verify shapes
print("Inspecting one batch from train_loader...")

batch = next(iter(train_loader))
waveforms, labels, sample_rates = batch

print(f"Waveform batch shape : {waveforms.shape}  # Expect: [B, 1, 160000]")
print(f"Labels shape         : {labels.shape}     # Expect: [B]")
print(f"Sample rates         : {sample_rates}")    # Should all be 16000
# Out:
# DataLoaders created
# Inspecting one batch from train_loader...
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_validation/drummer4_session1_5_021.wav | Original samples: 41740
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer1_session2_2_053.wav | Original samples: 65085
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer1_session1_1_020.wav | Original samples: 96000
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer1_session1_77_236.wav | Original samples: 42667
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer8_session1_5_026.wav | Original samples: 85333
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer7_session3_67_004.wav | Original samples: 82580
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer10_session1_3_022.wav | Original samples: 35721
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer7_session1_8_006.wav | Original samples: 82581
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer1_session1_47_066.wav | Original samples: 75295
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_test/drummer1_session1_250_000.wav | Original samples: 59076
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer8_session1_26_044.wav | Original samples: 81702
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_validation/drummer6_session3_4_056.wav | Original samples: 60472
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer7_session2_106_025.wav | Original samples: 73847
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer6_session3_7_006.wav | Original samples: 87272
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_validation/drummer1_session1_126_034.wav | Original samples: 61440
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer1_session1_79_001.wav | Original samples: 85334
# [PADDED] Padded to 160000
# Waveform batch shape : torch.Size([16, 1, 160000])  # Expect: [B, 1, 160000]
# Labels shape         : torch.Size([16])     # Expect: [B]
# Sample rates         : tensor([16000, 16000, 16000, 16000, 16000, 16000, 16000, 16000, 16000, 16000,
#         16000, 16000, 16000, 16000, 16000, 16000])

# %% [markdown]
# #Updated GrooveDataset with Feature Extraction (Dataset Class)

# %%
class GrooveDataset(Dataset):
    def __init__(self, split: str, transform=None):
        assert split in ['train', 'test', 'validation'], f"Invalid split: {split}"
        self.transform = transform

        print(f" Loading metadata from: {metadata_path}")
        df = pd.read_csv(metadata_path)
        print(f" Full metadata loaded: {df.shape[0]} rows")

        df = df[df['split_rev'] == split].reset_index(drop=True)
        print(f" Subset for '{split}' split: {df.shape[0]} rows")

        assert 'file_path' in df.columns
        assert 'style_class' in df.columns

        df['file_path'] = df['file_path'].apply(lambda x: os.path.join(BASE_DIR, x))
        self.data_df = df

        self.labels = sorted(df["style_class"].unique())
        self.class_to_idx = {label: idx for idx, label in enumerate(self.labels)}

        print(" Available classes and mapping:")
        for idx, label in self.class_to_idx.items():
            print(f"  {label}: {idx}")

        print(" Preview of dataset:")
        print(self.data_df[['file_path', 'style_class']].head(3))

    def __len__(self):
        return len(self.data_df)

    def __getitem__(self, idx):
        row = self.data_df.iloc[idx]
        file_path = row["file_path"]
        label = row["style_class"]

        try:
            waveform, sr = torchaudio.load(file_path)

            if sr != SAMPLE_RATE:
                print(f"[RESAMPLE] {file_path}: {sr}Hz → {SAMPLE_RATE}Hz")
                resampler = T.Resample(orig_freq=sr, new_freq=SAMPLE_RATE)
                waveform = resampler(waveform)

            if waveform.shape[0] > 1:
                waveform = waveform.mean(dim=0, keepdim=True)

            num_samples = waveform.size(1)
            print(f"[AUDIO] {file_path} | Original samples: {num_samples}")

            if num_samples < CLIP_LENGTH_SAMPLES:
                waveform = F.pad(waveform, (0, CLIP_LENGTH_SAMPLES - num_samples))
                print(f"[PADDED] Padded to {CLIP_LENGTH_SAMPLES}")
            else:
                waveform = waveform[:, :CLIP_LENGTH_SAMPLES]
                print(f"[TRIMMED] Trimmed to {CLIP_LENGTH_SAMPLES}")

            # APPLY MEL FEATURE EXTRACTOR HERE
            if self.transform:
                features = self.transform(waveform)  # Expect [1, 128, T]
            else:
                features = waveform  # Raw waveform fallback

            label_index = self.class_to_idx[label]
            return features, label_index, SAMPLE_RATE

        except Exception as e:
            print(f"[ERROR] Failed loading {file_path}: {e}")
            return None

# %% [markdown]
# #DATALOADER W/ MEL FEATURES + DEBUG PRINTS

# %%
# Instantiate feature extractor
feature_extractor = WaveformFeatures(sample_rate=16000)

# Create dataset objects with mel spectrogram transform
train_dataset = GrooveDataset(split="train", transform=feature_extractor)
val_dataset   = GrooveDataset(split="validation", transform=feature_extractor)
test_dataset  = GrooveDataset(split="test", transform=feature_extractor)

# Create dataloaders
from torch.utils.data import DataLoader

BATCH_SIZE = 16
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_loader  = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# Test a sample batch
print("Testing first batch from train_loader...\n")
batch = next(iter(train_loader))

batch_features, batch_labels, batch_sample_rates = batch

print(f"Waveform batch shape: {batch_features.shape}")  # [B, 1, 128, T]
print(f"Label indices       : {batch_labels}")
print(f"Sample rates        : {batch_sample_rates}")

# Optional: print label names
idx_to_class = {v: k for k, v in train_dataset.class_to_idx.items()}
label_names = [idx_to_class[i.item()] for i in batch_labels]
print(f"Label names         : {label_names}")
# Out:
#  Loading metadata from: /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_16000hz_segmented_metadata_all_splits_withaudio_filepath_styleclass_10sec_split_rev_v2.csv
#  Full metadata loaded: 18264 rows
#  Subset for 'train' split: 14611 rows
#  Available classes and mapping:
#   0: afrobeat
#   1: afrocuban
#   2: afrocuban_bembe
#   3: afrocuban_calypso
#   4: afrocuban_rhumba
#   5: blues_shuffle
#   6: country
#   7: dance_breakbeat
#   8: dance_disco
#   9: funk
#   10: funk_fast
#   11: funk_groove1
#   12: funk_groove2
#   13: funk_groove5
#   14: funk_latin
#   15: funk_purdieshuffle
#   16: funk_rock
#   17: gospel
#   18: hiphop
#   19: hiphop_groove6
#   20: jazz
#   21: jazz_fast
#   22: jazz_funk
#   23: jazz_fusion
#   24: jazz_klezmer
#   25: jazz_linear
#   26: jazz_march
#   27: jazz_mediumfast
#   28: jazz_swing
#   29: latin
#   30: latin_ando
#   31: latin_bomba
#   32: latin_brazilian
#   33: latin_brazilian-baiao
#   34: latin_brazilian-bossa
#   35: latin_brazilian-frevo
#   36: latin_brazilian-ijexa
#   37: latin_brazilian-maracatu
#   38: latin_brazilian-samba
#   39: latin_brazilian-sambareggae
#   40: latin_brazilian-songo
#   41: latin_chacarera
#   42: latin_dominican-merengue
#   43: latin_merengue
#   44: latin_reggaeton
#   45: latin_samba
#   46: latin_venezuelan-joropo
#   47: latin_venezuelan-merengue
#   48: latin_venezuelan-sangueo
#   49: middleeastern
#   50: neworleans_chacha
#   51: neworleans_funk
#   52: neworleans_secondline
#   53: neworleans_shuffle
#   54: pop
#   55: pop_groove7
#   56: pop_soft
#   57: punk
#   58: reggae
#   59: reggae_slow
#   60: rock
#   61: rock_folk
#   62: rock_groove8
#   63: rock_halftime
#   64: rock_indie
#   65: rock_prog
#   66: rock_rockabilly
#   67: rock_shuffle
#   68: soul
#   69: soul_groove10
#   70: soul_groove3
#   71: soul_groove4
#   72: soul_groove9
#   73: soul_motown
#  Preview of dataset:
#                                            file_path  style_class
# 0  /content/drive/My Drive/LUMT_Thesis_Resources/...    jazz_fast
# 1  /content/drive/My Drive/LUMT_Thesis_Resources/...         funk
# 2  /content/drive/My Drive/LUMT_Thesis_Resources/...  jazz_linear
#  Loading metadata from: /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_16000hz_segmented_metadata_all_splits_withaudio_filepath_styleclass_10sec_split_rev_v2.csv
#  Full metadata loaded: 18264 rows
#  Subset for 'validation' split: 1826 rows
#  Available classes and mapping:
#   0: afrobeat
#   1: afrocuban
#   2: afrocuban_bembe
#   3: afrocuban_calypso
#   4: afrocuban_rhumba
#   5: blues_shuffle
#   6: country
#   7: dance_breakbeat
#   8: dance_disco
#   9: funk
#   10: funk_fast
#   11: funk_groove1
#   12: funk_groove2
#   13: funk_groove5
#   14: funk_latin
#   15: funk_purdieshuffle
#   16: funk_rock
#   17: gospel
#   18: hiphop
#   19: hiphop_groove6
#   20: jazz
#   21: jazz_fast
#   22: jazz_funk
#   23: jazz_fusion
#   24: jazz_klezmer
#   25: jazz_linear
#   26: jazz_march
#   27: jazz_mediumfast
#   28: jazz_swing
#   29: latin
#   30: latin_ando
#   31: latin_bomba
#   32: latin_brazilian
#   33: latin_brazilian-baiao
#   34: latin_brazilian-bossa
#   35: latin_brazilian-frevo
#   36: latin_brazilian-ijexa
#   37: latin_brazilian-maracatu
#   38: latin_brazilian-samba
#   39: latin_brazilian-sambareggae
#   40: latin_brazilian-songo
#   41: latin_chacarera
#   42: latin_dominican-merengue
#   43: latin_merengue
#   44: latin_reggaeton
#   45: latin_samba
#   46: latin_venezuelan-joropo
#   47: latin_venezuelan-merengue
#   48: latin_venezuelan-sangueo
#   49: middleeastern
#   50: neworleans_chacha
#   51: neworleans_funk
#   52: neworleans_secondline
#   53: neworleans_shuffle
#   54: pop
#   55: pop_groove7
#   56: pop_soft
#   57: punk
#   58: reggae
#   59: reggae_slow
#   60: rock
#   61: rock_folk
#   62: rock_groove8
#   63: rock_halftime
#   64: rock_indie
#   65: rock_prog
#   66: rock_rockabilly
#   67: rock_shuffle
#   68: soul
#   69: soul_groove10
#   70: soul_groove3
#   71: soul_groove4
#   72: soul_groove9
#   73: soul_motown
#  Preview of dataset:
#                                            file_path            style_class
# 0  /content/drive/My Drive/LUMT_Thesis_Resources/...                   rock
# 1  /content/drive/My Drive/LUMT_Thesis_Resources/...  neworleans_secondline
# 2  /content/drive/My Drive/LUMT_Thesis_Resources/...        latin_brazilian
#  Loading metadata from: /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_16000hz_segmented_metadata_all_splits_withaudio_filepath_styleclass_10sec_split_rev_v2.csv
#  Full metadata loaded: 18264 rows
#  Subset for 'test' split: 1827 rows
#  Available classes and mapping:
#   0: afrobeat
#   1: afrocuban
#   2: afrocuban_bembe
#   3: afrocuban_calypso
#   4: afrocuban_rhumba
#   5: blues_shuffle
#   6: country
#   7: dance_breakbeat
#   8: dance_disco
#   9: funk
#   10: funk_fast
#   11: funk_groove1
#   12: funk_groove2
#   13: funk_groove5
#   14: funk_latin
#   15: funk_purdieshuffle
#   16: funk_rock
#   17: gospel
#   18: hiphop
#   19: hiphop_groove6
#   20: jazz
#   21: jazz_fast
#   22: jazz_funk
#   23: jazz_fusion
#   24: jazz_klezmer
#   25: jazz_linear
#   26: jazz_march
#   27: jazz_mediumfast
#   28: jazz_swing
#   29: latin
#   30: latin_ando
#   31: latin_bomba
#   32: latin_brazilian
#   33: latin_brazilian-baiao
#   34: latin_brazilian-bossa
#   35: latin_brazilian-frevo
#   36: latin_brazilian-ijexa
#   37: latin_brazilian-maracatu
#   38: latin_brazilian-samba
#   39: latin_brazilian-sambareggae
#   40: latin_brazilian-songo
#   41: latin_chacarera
#   42: latin_dominican-merengue
#   43: latin_merengue
#   44: latin_reggaeton
#   45: latin_samba
#   46: latin_venezuelan-joropo
#   47: latin_venezuelan-merengue
#   48: latin_venezuelan-sangueo
#   49: middleeastern
#   50: neworleans_chacha
#   51: neworleans_funk
#   52: neworleans_secondline
#   53: neworleans_shuffle
#   54: pop
#   55: pop_groove7
#   56: pop_soft
#   57: punk
#   58: reggae
#   59: reggae_slow
#   60: rock
#   61: rock_folk
#   62: rock_groove8
#   63: rock_halftime
#   64: rock_indie
#   65: rock_prog
#   66: rock_rockabilly
#   67: rock_shuffle
#   68: soul
#   69: soul_groove10
#   70: soul_groove3
#   71: soul_groove4
#   72: soul_groove9
#   73: soul_motown
#  Preview of dataset:
#                                            file_path style_class
# 0  /content/drive/My Drive/LUMT_Thesis_Resources/...        funk
# 1  /content/drive/My Drive/LUMT_Thesis_Resources/...  jazz_swing
# 2  /content/drive/My Drive/LUMT_Thesis_Resources/...    afrobeat
# Testing first batch from train_loader...
#
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_test/drummer1_session1_239_150.wav | Original samples: 59077
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer9_session1_20_050.wav | Original samples: 64000
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer8_session1_1_071.wav | Original samples: 80842
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer7_session2_95_001.wav | Original samples: 102400
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer6_session2_1_027.wav | Original samples: 80842
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer1_session1_75_010.wav | Original samples: 61440
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer7_session3_108_038.wav | Original samples: 80842
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer7_session2_108_000.wav | Original samples: 73846
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer5_session1_2_003.wav | Original samples: 60473
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer5_session2_14_028.wav | Original samples: 54857
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer7_session2_115_008.wav | Original samples: 80000
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer1_session2_2_022.wav | Original samples: 65084
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer10_session1_8_010.wav | Original samples: 35721
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer5_session1_19_037.wav | Original samples: 60952
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_test/drummer7_eval_session_3_006.wav | Original samples: 89303
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer1_session1_1_018.wav | Original samples: 96000
# [PADDED] Padded to 160000
# Waveform batch shape: torch.Size([16, 1, 128, 626])
# Label indices       : tensor([15, 60,  9, 18, 60, 20, 60, 73, 34, 60, 23, 41, 28, 49, 70,  9])
# Sample rates        : tensor([16000, 16000, 16000, 16000, 16000, 16000, 16000, 16000, 16000, 16000,
#         16000, 16000, 16000, 16000, 16000, 16000])
# Label names         : ['funk_purdieshuffle', 'rock', 'funk', 'hiphop', 'rock', 'jazz', 'rock', 'soul_motown', 'latin_brazilian-bossa', 'rock', 'jazz_fusion', 'latin_chacarera', 'jazz_swing', 'middleeastern', 'soul_groove3', 'funk']

# %% [markdown]
# # DrumStyleClassifier CNN Module

# %%
import torch.nn as nn
import torch.nn.functional as F

class DrumStyleClassifier(nn.Module):
    def __init__(self, num_classes, n_mel=128):
        super(DrumStyleClassifier, self).__init__()

        # Convolutional layers
        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1)
        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.dropout = nn.Dropout(0.5)

        # Adaptive Global Average Pooling to flatten time axis dynamically
        self.global_pool = nn.AdaptiveAvgPool2d((n_mel // 8, 1))  # Reduce to [batch, channels, mel/8, 1]

        # Fully connected layers
        fc_input_dim = 64 * (n_mel // 8) * 1
        self.fc1 = nn.Linear(fc_input_dim, 512)
        self.fc2 = nn.Linear(512, num_classes)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))  # -> [B, 16, 64, T/2]
        x = self.pool(F.relu(self.conv2(x)))  # -> [B, 32, 32, T/4]
        x = self.pool(F.relu(self.conv3(x)))  # -> [B, 64, 16, T/8]

        x = self.global_pool(x)               # -> [B, 64, mel/8, 1]
        x = x.view(x.size(0), -1)             # Flatten

        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# #Consolidated Model Code

# %%
import os
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchaudio
import torchaudio.transforms as T
from torch.utils.data import Dataset, DataLoader

# === Constants ===
BASE_DIR = "/content/drive/My Drive/LUMT_Thesis_Resources/"
SAMPLE_RATE = 16_000
CLIP_LENGTH_SAMPLES = SAMPLE_RATE * 10  # 10 seconds = 160000 samples
METADATA_FILE = "groove_2bar_16000hz_segmented_metadata_all_splits_withaudio_filepath_styleclass_10sec_split_rev_v2.csv"
metadata_path = os.path.join(BASE_DIR, METADATA_FILE)

# === Mel Feature Extractor ===
class WaveformFeatures(nn.Module):
    def __init__(self, sample_rate=16000, n_fft=1024, n_mels=128):
        super().__init__()
        hop_length = n_fft // 4
        self.spectrogram = T.Spectrogram(n_fft=n_fft, hop_length=hop_length, power=2.0)
        self.mel_scale = T.MelScale(n_mels=n_mels, sample_rate=sample_rate, n_stft=n_fft // 2 + 1)

    def forward(self, waveform: torch.Tensor) -> torch.Tensor:
        spec = self.spectrogram(waveform)
        mel_spec = self.mel_scale(spec)
        return mel_spec

# === Dataset Class with Mel Transform Support ===
class GrooveDataset(Dataset):
    def __init__(self, split: str, transform=None):
        assert split in ['train', 'test', 'validation'], f"Invalid split: {split}"
        self.transform = transform

        df = pd.read_csv(metadata_path)
        df = df[df['split_rev'] == split].reset_index(drop=True)
        df['file_path'] = df['file_path'].apply(lambda x: os.path.join(BASE_DIR, x))

        self.data_df = df
        self.labels = sorted(df["style_class"].unique())
        self.class_to_idx = {label: idx for idx, label in enumerate(self.labels)}
        self.idx_to_class = {idx: label for label, idx in self.class_to_idx.items()}

    def __len__(self):
        return len(self.data_df)

    def __getitem__(self, idx):
        row = self.data_df.iloc[idx]
        file_path = row["file_path"]
        label = row["style_class"]

        try:
            waveform, sr = torchaudio.load(file_path)
            if sr != SAMPLE_RATE:
                resampler = T.Resample(orig_freq=sr, new_freq=SAMPLE_RATE)
                waveform = resampler(waveform)

            if waveform.shape[0] > 1:
                waveform = waveform.mean(dim=0, keepdim=True)

            num_samples = waveform.size(1)
            if num_samples < CLIP_LENGTH_SAMPLES:
                waveform = F.pad(waveform, (0, CLIP_LENGTH_SAMPLES - num_samples))
            else:
                waveform = waveform[:, :CLIP_LENGTH_SAMPLES]

            if self.transform:
                features = self.transform(waveform)
            else:
                features = waveform

            label_index = self.class_to_idx[label]
            return features, label_index, SAMPLE_RATE

        except Exception as e:
            print(f"[ERROR] Failed loading {file_path}: {e}")
            return None

# === CNN Classifier with Adaptive Pooling ===
class DrumStyleClassifier(nn.Module):
    def __init__(self, num_classes, n_mel=128):
        super().__init__()

        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.dropout = nn.Dropout(0.5)

        # Reduce time dimension to 1; keep mel dim compressed to 16
        self.global_pool = nn.AdaptiveAvgPool2d((n_mel // 8, 1))  # → (16, 1)

        self.fc1 = nn.Linear(64 * (n_mel // 8) * 1, 512)
        self.fc2 = nn.Linear(512, num_classes)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))  # [B, 16, 64, T/2]
        x = self.pool(F.relu(self.conv2(x)))  # [B, 32, 32, T/4]
        x = self.pool(F.relu(self.conv3(x)))  # [B, 64, 16, T/8]
        x = self.global_pool(x)               # → [B, 64, 16, 1]
        x = x.view(x.size(0), -1)             # Flatten to [B, 1024]
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# #Dataloaders
#
# run after consolidated model code

# %%
# Instantiate feature extractor
feature_extractor = WaveformFeatures(sample_rate=16000)

# Create datasets w/ transform
train_dataset = GrooveDataset(split="train", transform=feature_extractor)
val_dataset   = GrooveDataset(split="validation", transform=feature_extractor)
test_dataset  = GrooveDataset(split="test", transform=feature_extractor)

# Create DataLoaders
BATCH_SIZE = 16
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_loader  = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# Optional: inspect 1 batch
batch = next(iter(train_loader))
features, labels, sample_rates = batch
print(f"Batch shape: {features.shape}, Labels: {labels}")
# Out:
# Batch shape: torch.Size([16, 1, 128, 626]), Labels: tensor([40, 60, 21, 16, 26,  9, 34, 40, 28, 43, 60, 72, 29, 45, 21,  9])

# %% [markdown]
# #Device Setup for Training

# %%
# === Device configuration ===
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f" Using device: {device}")
# Out:
#  Using device: cuda

# %% [markdown]
# #Instantiate the model

# %%
model = DrumStyleClassifier(num_classes=len(train_dataset.class_to_idx))
model = model.to(device)

# %% [markdown]
# #Training setup

# %%
import os
import csv
import time
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from tqdm import tqdm

# === SETTINGS ===
CHECKPOINTS_DIR = "checkpoints"
LOG_CSV = "gmd_cnn_p5_log.csv"  # Updated log file name
os.makedirs(CHECKPOINTS_DIR, exist_ok=True)

# === One epoch of train or val ===
def run_epoch(model, loader, criterion, optimizer, device, is_training):
    model.train() if is_training else model.eval()

    total_loss, correct, total = 0, 0, 0
    all_losses = []

    for features, labels, _ in tqdm(loader, desc="Train" if is_training else "Val", leave=False):
        features, labels = features.to(device), labels.to(device)
        outputs = model(features)
        loss = criterion(outputs, labels)

        if is_training:
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        total_loss += loss.item()
        all_losses.append(loss.item())

        # Accuracy
        preds = outputs.argmax(dim=1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

    avg_loss = total_loss / len(loader)
    accuracy = correct / total
    return avg_loss, accuracy, all_losses

# === Save current model state ===
def save_checkpoint(model, optimizer, epoch, path):
    torch.save({
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
    }, path)

# === Train full model with early stopping ===
def train_model(model, train_loader, val_loader, criterion, optimizer, device,
                max_epochs=50, patience=10):
    """
    Trains model and tracks:
      - train/val loss per batch & epoch
      - val accuracy per epoch
      - early stopping based on val accuracy
      - saves best model to disk
      - logs all epochs to CSV
    """

    best_val_acc = 0.0
    patience_counter = 0
    all_train_losses, all_val_losses = [], []
    all_val_accuracies = []

    # === Initialize CSV ===
    with open(LOG_CSV, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(["epoch", "train_loss", "val_loss", "val_accuracy"])

    for epoch in range(1, max_epochs + 1):
        print(f"Epoch {epoch}/{max_epochs}")

        # === Train / Validate
        train_loss, train_acc, train_losses = run_epoch(model, train_loader, criterion, optimizer, device, True)
        val_loss, val_acc, val_losses = run_epoch(model, val_loader, criterion, optimizer, device, False)

        # === Print summary for this epoch
        print(f"Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f}")

        all_train_losses.append(train_losses)
        all_val_losses.append(val_losses)
        all_val_accuracies.append(val_acc)

        # === Append to CSV
        with open(LOG_CSV, 'a', newline='') as f:
            writer = csv.writer(f)
            writer.writerow([epoch, train_loss, val_loss, val_acc])

        # === Early Stopping
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            patience_counter = 0
            best_model_path = f"{CHECKPOINTS_DIR}/best_model_epoch_{epoch}.pth"
            save_checkpoint(model, optimizer, epoch, best_model_path)
            print(f" New best model saved at: {best_model_path}")
        else:
            patience_counter += 1
            print(f"Patience: {patience_counter}/{patience}")
            if patience_counter >= patience:
                print("Early stopping triggered.")
                break

    return all_train_losses, all_val_losses, all_val_accuracies

# %% [markdown]
# #Training Execution

# %%
# === Instantiate model and training components ===
model = DrumStyleClassifier(num_classes=len(train_dataset.class_to_idx)).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)

# === Run training with early stopping & return model path
train_losses, val_losses, val_accuracies, best_model_path = train_model(
    model,
    train_loader,
    val_loader,
    criterion,
    optimizer,
    device,
    max_epochs=50,
    patience=10
)

# === Plot Loss + Validation Accuracy
epochs = list(range(1, len(val_accuracies) + 1))
train_loss_avg = [np.mean(epoch) for epoch in train_losses]
val_loss_avg = [np.mean(epoch) for epoch in val_losses]

plt.figure(figsize=(12, 6))
plt.plot(epochs, train_loss_avg, label="Train Loss", marker='o', color='blue')
plt.plot(epochs, val_loss_avg, label="Validation Loss", marker='o', color='red')
plt.plot(epochs, val_accuracies, label="Validation Accuracy", marker='s', color='green')

plt.title("Training Progress: Loss & Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Loss / Accuracy")
plt.grid(True)
plt.legend()
plt.savefig("loss_accuracy_plot.png", dpi=300, bbox_inches="tight")
plt.show()

# === Final training output
print("Training complete.")
print(f"Best model saved to: {best_model_path}")
print("Log CSV saved to: gmd_cnn_p5_log.csv")
print("  Plot saved to: loss_accuracy_plot.png")
# Out:
# Epoch 1/50
# Train Loss: 3.3081 | Val Loss: 2.9148 | Val Acc: 0.2486
#  New best model saved at: checkpoints/best_model_epoch_1.pth
# Epoch 2/50
# Train Loss: 2.8997 | Val Loss: 2.6651 | Val Acc: 0.2848
#  New best model saved at: checkpoints/best_model_epoch_2.pth
# Epoch 3/50
# Train Loss: 2.7122 | Val Loss: 2.4998 | Val Acc: 0.3165
#  New best model saved at: checkpoints/best_model_epoch_3.pth
# Epoch 4/50
# Train Loss: 2.5483 | Val Loss: 2.3355 | Val Acc: 0.3445
#  New best model saved at: checkpoints/best_model_epoch_4.pth
# Epoch 5/50
# Train Loss: 2.4245 | Val Loss: 2.2211 | Val Acc: 0.3729
#  New best model saved at: checkpoints/best_model_epoch_5.pth
# Epoch 6/50
# Train Loss: 2.3071 | Val Loss: 2.0853 | Val Acc: 0.4025
#  New best model saved at: checkpoints/best_model_epoch_6.pth
# Epoch 7/50
# Train Loss: 2.2165 | Val Loss: 2.0213 | Val Acc: 0.4195
#  New best model saved at: checkpoints/best_model_epoch_7.pth
# Epoch 8/50
# Train Loss: 2.1226 | Val Loss: 1.9289 | Val Acc: 0.4222
#  New best model saved at: checkpoints/best_model_epoch_8.pth
# Epoch 9/50
# Train Loss: 2.0401 | Val Loss: 1.8384 | Val Acc: 0.4556
#  New best model saved at: checkpoints/best_model_epoch_9.pth
# Epoch 10/50
# Train Loss: 1.9831 | Val Loss: 1.7957 | Val Acc: 0.4660
#  New best model saved at: checkpoints/best_model_epoch_10.pth
# Epoch 11/50
# Train Loss: 1.9245 | Val Loss: 1.7229 | Val Acc: 0.4956
#  New best model saved at: checkpoints/best_model_epoch_11.pth
# Epoch 12/50
# Train Loss: 1.8787 | Val Loss: 1.6943 | Val Acc: 0.5016
#  New best model saved at: checkpoints/best_model_epoch_12.pth
# Epoch 13/50
# Train Loss: 1.8220 | Val Loss: 1.6177 | Val Acc: 0.5142
#  New best model saved at: checkpoints/best_model_epoch_13.pth
# Epoch 14/50
# Train Loss: 1.7649 | Val Loss: 1.6413 | Val Acc: 0.5055
# Patience: 1/10
# Epoch 15/50
# Train Loss: 1.7311 | Val Loss: 1.5650 | Val Acc: 0.5329
#  New best model saved at: checkpoints/best_model_epoch_15.pth
# Epoch 16/50
# Train Loss: 1.6815 | Val Loss: 1.5235 | Val Acc: 0.5383
#  New best model saved at: checkpoints/best_model_epoch_16.pth
# Epoch 17/50
# Train Loss: 1.6470 | Val Loss: 1.4962 | Val Acc: 0.5531
#  New best model saved at: checkpoints/best_model_epoch_17.pth
# Epoch 18/50
# Train Loss: 1.6046 | Val Loss: 1.4669 | Val Acc: 0.5548
#  New best model saved at: checkpoints/best_model_epoch_18.pth
# Epoch 19/50
# Train Loss: 1.5856 | Val Loss: 1.4244 | Val Acc: 0.5827
#  New best model saved at: checkpoints/best_model_epoch_19.pth
# Epoch 20/50
# Train Loss: 1.5569 | Val Loss: 1.4062 | Val Acc: 0.5652
# Patience: 1/10
# Epoch 21/50
# Train Loss: 1.5181 | Val Loss: 1.3684 | Val Acc: 0.5745
# Patience: 2/10
# Epoch 22/50
# Train Loss: 1.4901 | Val Loss: 1.3417 | Val Acc: 0.5986
#  New best model saved at: checkpoints/best_model_epoch_22.pth
# Epoch 23/50
# Train Loss: 1.4485 | Val Loss: 1.3098 | Val Acc: 0.6057
#  New best model saved at: checkpoints/best_model_epoch_23.pth
# Epoch 24/50
# Train Loss: 1.4184 | Val Loss: 1.2930 | Val Acc: 0.6177
#  New best model saved at: checkpoints/best_model_epoch_24.pth
# Epoch 25/50
# Train Loss: 1.4015 | Val Loss: 1.2859 | Val Acc: 0.6079
# Patience: 1/10
# Epoch 26/50
# Train Loss: 1.3678 | Val Loss: 1.2638 | Val Acc: 0.6172
# Patience: 2/10
# Epoch 27/50
# Train Loss: 1.3402 | Val Loss: 1.2196 | Val Acc: 0.6375
#  New best model saved at: checkpoints/best_model_epoch_27.pth
# Epoch 28/50
# Train Loss: 1.3036 | Val Loss: 1.1948 | Val Acc: 0.6331
# Patience: 1/10
# Epoch 29/50
# Train Loss: 1.2938 | Val Loss: 1.1759 | Val Acc: 0.6555
#  New best model saved at: checkpoints/best_model_epoch_29.pth
# Epoch 30/50
# Train Loss: 1.2678 | Val Loss: 1.1381 | Val Acc: 0.6517
# Patience: 1/10
# Epoch 31/50
# Train Loss: 1.2476 | Val Loss: 1.1418 | Val Acc: 0.6648
#  New best model saved at: checkpoints/best_model_epoch_31.pth
# Epoch 32/50
# Train Loss: 1.2184 | Val Loss: 1.1244 | Val Acc: 0.6588
# Patience: 1/10
# Epoch 33/50
# Train Loss: 1.1931 | Val Loss: 1.0801 | Val Acc: 0.6818
#  New best model saved at: checkpoints/best_model_epoch_33.pth
# Epoch 34/50
# Train Loss: 1.1800 | Val Loss: 1.0417 | Val Acc: 0.6862
#  New best model saved at: checkpoints/best_model_epoch_34.pth
# Epoch 35/50
# Train Loss: 1.1391 | Val Loss: 1.0451 | Val Acc: 0.6857
# Patience: 1/10
# Epoch 36/50
# Train Loss: 1.1280 | Val Loss: 1.0061 | Val Acc: 0.6939
#  New best model saved at: checkpoints/best_model_epoch_36.pth
# Epoch 37/50
# Train Loss: 1.1079 | Val Loss: 1.0083 | Val Acc: 0.6966
#  New best model saved at: checkpoints/best_model_epoch_37.pth
# Epoch 38/50
# Train Loss: 1.0926 | Val Loss: 0.9898 | Val Acc: 0.6999
#  New best model saved at: checkpoints/best_model_epoch_38.pth
# Epoch 39/50
# Train Loss: 1.0603 | Val Loss: 0.9765 | Val Acc: 0.7059
#  New best model saved at: checkpoints/best_model_epoch_39.pth
# Epoch 40/50
# Train Loss: 1.0494 | Val Loss: 0.9385 | Val Acc: 0.7174
#  New best model saved at: checkpoints/best_model_epoch_40.pth
# Epoch 41/50
# Train Loss: 1.0272 | Val Loss: 0.9926 | Val Acc: 0.6922
# Patience: 1/10
# Epoch 42/50
# Train Loss: 1.0162 | Val Loss: 0.9253 | Val Acc: 0.7262
#  New best model saved at: checkpoints/best_model_epoch_42.pth
# Epoch 43/50
# Train Loss: 0.9906 | Val Loss: 0.8732 | Val Acc: 0.7349
#  New best model saved at: checkpoints/best_model_epoch_43.pth
# Epoch 44/50
# Train Loss: 0.9737 | Val Loss: 0.8840 | Val Acc: 0.7382
#  New best model saved at: checkpoints/best_model_epoch_44.pth
# Epoch 45/50
# Train Loss: 0.9636 | Val Loss: 0.8631 | Val Acc: 0.7349
# Patience: 1/10
# Epoch 46/50
# Train Loss: 0.9438 | Val Loss: 0.8723 | Val Acc: 0.7410
#  New best model saved at: checkpoints/best_model_epoch_46.pth
# Epoch 47/50
# Train Loss: 0.9364 | Val Loss: 0.8636 | Val Acc: 0.7393
# Patience: 1/10
# Epoch 48/50
# Train Loss: 0.9174 | Val Loss: 0.8273 | Val Acc: 0.7503
#  New best model saved at: checkpoints/best_model_epoch_48.pth
# Epoch 49/50
# Train Loss: 0.8982 | Val Loss: 0.8169 | Val Acc: 0.7547
#  New best model saved at: checkpoints/best_model_epoch_49.pth
# Epoch 50/50
# Train Loss: 0.8863 | Val Loss: 0.8054 | Val Acc: 0.7590
#  New best model saved at: checkpoints/best_model_epoch_50.pth
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-0de18b01d85d> in <cell line: 0>()
#       5
#       6 # === Run training with early stopping & return model path
# ----> 7 train_losses, val_losses, val_accuracies, best_model_path = train_model(
#       8     model,
#       9     train_loader,
#
# ValueError: not enough values to unpack (expected 4, got 3)

# %% [markdown]
# ^
# Error was thrown when trying to visualize training not in the training itself, for future iterations, edit this cell to exclude training visualization and just execute the training.

# %% [markdown]
# #Prevent timeout script

# %%
# %%javascript
# function preventIdle() {
#     setInterval(() => {
#         console.log("Preventing Colab Disconnect...");
#         document.querySelector("colab-toolbar-button")?.click();
#     }, 60000); // Clicks every 60 seconds
# }
# preventIdle();

# %% [markdown]
# #Train on A-100 GPu was 4h 55min

# %% [markdown]
# #Visualize the training

# %%
import pandas as pd
import matplotlib.pyplot as plt

# === Path to training log in Colab runtime
log_path = "gmd_cnn_p5_log.csv"

# === Load training log
log_df = pd.read_csv(log_path)

# === Extract columns
epochs = log_df["epoch"]
train_loss = log_df["train_loss"]
val_loss = log_df["val_loss"]
val_acc = log_df["val_accuracy"]

# === Plot loss and accuracy
plt.figure(figsize=(14, 6))

# Loss subplot
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, label="Train Loss", color='blue', marker='o')
plt.plot(epochs, val_loss, label="Validation Loss", color='red', marker='o')
plt.title("Training vs Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid(True)
plt.legend()

# Accuracy subplot
plt.subplot(1, 2, 2)
plt.plot(epochs, val_acc, label="Validation Accuracy", color='green', marker='s')
plt.title("Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.grid(True)
plt.legend()

# Save & show plot
plt.tight_layout()
plt.savefig("loss_accuracy_plot.png", dpi=300, bbox_inches="tight")
plt.show()

print("Training visualization complete.")
print("Plot saved as: loss_accuracy_plot.png")
# Out:
# Training visualization complete.
# Plot saved as: loss_accuracy_plot.png

# %% [markdown]
# ^^ Above seems training could have continued maybe another 30 epochs before validaion accuracy would have flattened out around 0.8

# %% [markdown]
# #Reload the Model and Load Weights

# %%
# === Rebuild model and load best weights ===
model = DrumStyleClassifier(num_classes=len(train_dataset.class_to_idx)).to(device)

# Load best checkpoint
best_model_path = "checkpoints/best_model_epoch_50.pth"
checkpoint = torch.load(best_model_path, map_location=device)
model.load_state_dict(checkpoint["model_state_dict"])
model.eval()

print(f"Model loaded from: {best_model_path}")
# Out:
# Model loaded from: checkpoints/best_model_epoch_50.pth

# %% [markdown]
# #note

# %% [markdown]
# #Reload Test set

# %%
# === Recreate test set loader ===
test_dataset = GrooveDataset(split="test", transform=feature_extractor)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

print(f"Test dataset size: {len(test_dataset)}")
# Out:
# Test dataset size: 1827

# %% [markdown]
# #Inference , Confusion Matrix, Report
#
# confusion matrix plots correctly

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# === Run inference
all_preds = []
all_labels = []

with torch.no_grad():
    for features, labels, _ in test_loader:
        features = features.to(device)
        outputs = model(features)
        preds = outputs.argmax(dim=1).cpu().numpy()
        all_preds.extend(preds)
        all_labels.extend(labels.numpy())

# === Decode labels
idx_to_class = test_dataset.idx_to_class
class_names = [idx_to_class[i] for i in sorted(idx_to_class)]

# === Confusion matrix
cm = confusion_matrix(all_labels, all_preds)
plt.figure(figsize=(20, 16))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix - Test Set")
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.savefig("confusion_matrix_test.png", dpi=500)
plt.show()

# === Classification report
report = classification_report(all_labels, all_preds, target_names=class_names)
print("Classification Report:\n")
print(report)
# Out:
# Classification Report:
#
#                              precision    recall  f1-score   support
#
#                    afrobeat       0.86      1.00      0.93        31
#                   afrocuban       0.81      0.64      0.71        33
#             afrocuban_bembe       0.89      0.80      0.84        10
#           afrocuban_calypso       0.85      1.00      0.92        29
#            afrocuban_rhumba       1.00      0.90      0.95        10
#               blues_shuffle       0.62      0.62      0.62         8
#                     country       0.89      0.67      0.76        12
#             dance_breakbeat       0.50      0.24      0.32        25
#                 dance_disco       0.82      0.77      0.79        30
#                        funk       0.76      0.72      0.74       133
#                   funk_fast       0.56      0.38      0.45        13
#                funk_groove1       0.50      0.17      0.25         6
#                funk_groove2       0.67      0.67      0.67         6
#                funk_groove5       0.83      0.83      0.83         6
#                  funk_latin       0.90      0.69      0.78        13
#          funk_purdieshuffle       0.64      0.33      0.44        21
#                   funk_rock       1.00      0.50      0.67         4
#                      gospel       1.00      0.57      0.73         7
#                      hiphop       0.84      0.68      0.75        68
#              hiphop_groove6       1.00      0.67      0.80         6
#                        jazz       0.72      0.76      0.74        91
#                   jazz_fast       0.33      0.98      0.49        46
#                   jazz_funk       0.86      0.35      0.50        17
#                 jazz_fusion       0.60      0.50      0.55         6
#                jazz_klezmer       1.00      1.00      1.00         2
#                 jazz_linear       0.96      0.79      0.87        34
#                  jazz_march       0.96      1.00      0.98        24
#             jazz_mediumfast       0.00      0.00      0.00        26
#                  jazz_swing       0.96      0.91      0.93        70
#                       latin       1.00      1.00      1.00        24
#                  latin_ando       0.77      0.91      0.83        11
#                 latin_bomba       1.00      0.75      0.86         8
#             latin_brazilian       1.00      0.30      0.46        10
#       latin_brazilian-baiao       0.75      0.55      0.63        22
#       latin_brazilian-bossa       0.73      0.90      0.81        63
#       latin_brazilian-frevo       0.89      1.00      0.94         8
#       latin_brazilian-ijexa       1.00      0.75      0.86         8
#    latin_brazilian-maracatu       0.79      0.61      0.69        18
#       latin_brazilian-samba       0.90      0.81      0.85        32
# latin_brazilian-sambareggae       1.00      0.94      0.97        18
#       latin_brazilian-songo       0.66      0.61      0.63        31
#             latin_chacarera       0.96      0.96      0.96        24
#    latin_dominican-merengue       0.80      1.00      0.89        16
#              latin_merengue       1.00      1.00      1.00         1
#             latin_reggaeton       1.00      1.00      1.00         3
#                 latin_samba       0.82      0.47      0.60        19
#     latin_venezuelan-joropo       1.00      0.75      0.86         4
#   latin_venezuelan-merengue       1.00      1.00      1.00         9
#    latin_venezuelan-sangueo       0.00      0.00      0.00         3
#               middleeastern       0.89      0.67      0.76        12
#           neworleans_chacha       0.50      0.17      0.25         6
#             neworleans_funk       0.94      0.52      0.67        31
#       neworleans_secondline       1.00      0.76      0.86        21
#          neworleans_shuffle       1.00      1.00      1.00         5
#                         pop       0.94      0.83      0.88        18
#                 pop_groove7       1.00      0.50      0.67         6
#                    pop_soft       0.67      0.57      0.62         7
#                        punk       0.96      0.89      0.93        28
#                      reggae       0.57      0.77      0.66        26
#                 reggae_slow       1.00      1.00      1.00         3
#                        rock       0.76      0.92      0.83       353
#                   rock_folk       1.00      0.70      0.82        10
#                rock_groove8       0.75      1.00      0.86         6
#               rock_halftime       0.59      0.48      0.53        27
#                  rock_indie       0.67      0.40      0.50         5
#                   rock_prog       0.68      0.82      0.74        28
#             rock_rockabilly       0.81      0.96      0.88        26
#                rock_shuffle       0.80      0.57      0.67        28
#                        soul       0.70      0.61      0.65        23
#               soul_groove10       0.67      0.33      0.44         6
#                soul_groove3       1.00      0.83      0.91         6
#                soul_groove4       1.00      0.17      0.29         6
#                soul_groove9       1.00      1.00      1.00         6
#                 soul_motown       1.00      0.73      0.85        15
#
#                    accuracy                           0.76      1827
#                   macro avg       0.81      0.70      0.73      1827
#                weighted avg       0.78      0.76      0.76      1827
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# %%javascript
# function preventIdle() {
#     setInterval(() => {
#         console.log("Preventing Colab Disconnect...");
#         document.querySelector("colab-toolbar-button")?.click();
#     }, 60000); // Clicks every 60 seconds
# }
# preventIdle();

# %% [markdown]
# #Updated Inference and Metrics
#
# additional metrics per class
# geting weird sizing errors on the class labels in the confusion matrix

# %%
from sklearn.metrics import (
    confusion_matrix, classification_report, roc_auc_score, average_precision_score,
    precision_score, recall_score, f1_score
)
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import torch

# === Inference and metric aggregation
all_preds = []
all_labels = []
all_probs = []

model.eval()
with torch.no_grad():
    for features, labels, _ in test_loader:
        features = features.to(device)
        outputs = model(features)

        probs = torch.softmax(outputs, dim=1).cpu().numpy()
        preds = np.argmax(probs, axis=1)

        all_probs.extend(probs)
        all_preds.extend(preds)
        all_labels.extend(labels.numpy())

all_probs = np.array(all_probs)
all_preds = np.array(all_preds)
all_labels = np.array(all_labels)

# === Setup
idx_to_class = test_dataset.idx_to_class
class_names = [idx_to_class[i] for i in sorted(idx_to_class)]
num_classes = len(class_names)

# === Confusion Matrix
cm = confusion_matrix(all_labels, all_preds)
plt.figure(figsize=(20, 16))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix - Test Set")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("confusion_matrix_test.png", dpi=500)
plt.show()

# === Standard Classification Report
report_str = classification_report(all_labels, all_preds, target_names=class_names, digits=2)
print("Classification Report:\n")
print(report_str)

# === Overall Accuracy
accuracy = np.mean(all_preds == all_labels) * 100
print(f"\nOverall Accuracy: {accuracy:.2f}%")

# === Mean Average Precision (mAP) and AUC (One-vs-Rest)
binary_labels = np.eye(num_classes)[all_labels]  # one-hot encoding
mAP = average_precision_score(binary_labels, all_probs, average="macro")
AUC = roc_auc_score(binary_labels, all_probs, average="macro")

print(f"Mean Average Precision (mAP): {mAP:.4f}")
print(f"Area Under Curve (AUC): {AUC:.4f}")

# === Per-Class Detailed Metrics
print("\nPer-class Metrics:\n")
for i, class_name in enumerate(class_names):
    y_true_binary = binary_labels[:, i]
    y_pred_binary = all_probs[:, i]

    precision = precision_score(all_labels == i, all_preds == i, zero_division=0)
    recall = recall_score(all_labels == i, all_preds == i, zero_division=0)
    f1 = f1_score(all_labels == i, all_preds == i, zero_division=0)
    ap = average_precision_score(y_true_binary, y_pred_binary)
    auc = roc_auc_score(y_true_binary, y_pred_binary)
    support = np.sum(all_labels == i)

    print(f"{class_name}:")
    print(f"  Precision: {precision * 100:.2f}%")
    print(f"  Recall: {recall * 100:.2f}%")
    print(f"  F1-score: {f1 * 100:.2f}%")
    print(f"  mAP: {ap:.4f}")
    print(f"  AUC: {auc:.4f}")
    print(f"  Support: {support}")
    print("")
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Classification Report:
#
#                              precision    recall  f1-score   support
#
#                    afrobeat       0.86      1.00      0.93        31
#                   afrocuban       0.81      0.64      0.71        33
#             afrocuban_bembe       0.89      0.80      0.84        10
#           afrocuban_calypso       0.85      1.00      0.92        29
#            afrocuban_rhumba       1.00      0.90      0.95        10
#               blues_shuffle       0.62      0.62      0.62         8
#                     country       0.89      0.67      0.76        12
#             dance_breakbeat       0.50      0.24      0.32        25
#                 dance_disco       0.82      0.77      0.79        30
#                        funk       0.76      0.72      0.74       133
#                   funk_fast       0.56      0.38      0.45        13
#                funk_groove1       0.50      0.17      0.25         6
#                funk_groove2       0.67      0.67      0.67         6
#                funk_groove5       0.83      0.83      0.83         6
#                  funk_latin       0.90      0.69      0.78        13
#          funk_purdieshuffle       0.64      0.33      0.44        21
#                   funk_rock       1.00      0.50      0.67         4
#                      gospel       1.00      0.57      0.73         7
#                      hiphop       0.84      0.68      0.75        68
#              hiphop_groove6       1.00      0.67      0.80         6
#                        jazz       0.72      0.76      0.74        91
#                   jazz_fast       0.33      0.98      0.49        46
#                   jazz_funk       0.86      0.35      0.50        17
#                 jazz_fusion       0.60      0.50      0.55         6
#                jazz_klezmer       1.00      1.00      1.00         2
#                 jazz_linear       0.96      0.79      0.87        34
#                  jazz_march       0.96      1.00      0.98        24
#             jazz_mediumfast       0.00      0.00      0.00        26
#                  jazz_swing       0.96      0.91      0.93        70
#                       latin       1.00      1.00      1.00        24
#                  latin_ando       0.77      0.91      0.83        11
#                 latin_bomba       1.00      0.75      0.86         8
#             latin_brazilian       1.00      0.30      0.46        10
#       latin_brazilian-baiao       0.75      0.55      0.63        22
#       latin_brazilian-bossa       0.73      0.90      0.81        63
#       latin_brazilian-frevo       0.89      1.00      0.94         8
#       latin_brazilian-ijexa       1.00      0.75      0.86         8
#    latin_brazilian-maracatu       0.79      0.61      0.69        18
#       latin_brazilian-samba       0.90      0.81      0.85        32
# latin_brazilian-sambareggae       1.00      0.94      0.97        18
#       latin_brazilian-songo       0.66      0.61      0.63        31
#             latin_chacarera       0.96      0.96      0.96        24
#    latin_dominican-merengue       0.80      1.00      0.89        16
#              latin_merengue       1.00      1.00      1.00         1
#             latin_reggaeton       1.00      1.00      1.00         3
#                 latin_samba       0.82      0.47      0.60        19
#     latin_venezuelan-joropo       1.00      0.75      0.86         4
#   latin_venezuelan-merengue       1.00      1.00      1.00         9
#    latin_venezuelan-sangueo       0.00      0.00      0.00         3
#               middleeastern       0.89      0.67      0.76        12
#           neworleans_chacha       0.50      0.17      0.25         6
#             neworleans_funk       0.94      0.52      0.67        31
#       neworleans_secondline       1.00      0.76      0.86        21
#          neworleans_shuffle       1.00      1.00      1.00         5
#                         pop       0.94      0.83      0.88        18
#                 pop_groove7       1.00      0.50      0.67         6
#                    pop_soft       0.67      0.57      0.62         7
#                        punk       0.96      0.89      0.93        28
#                      reggae       0.57      0.77      0.66        26
#                 reggae_slow       1.00      1.00      1.00         3
#                        rock       0.76      0.92      0.83       353
#                   rock_folk       1.00      0.70      0.82        10
#                rock_groove8       0.75      1.00      0.86         6
#               rock_halftime       0.59      0.48      0.53        27
#                  rock_indie       0.67      0.40      0.50         5
#                   rock_prog       0.68      0.82      0.74        28
#             rock_rockabilly       0.81      0.96      0.88        26
#                rock_shuffle       0.80      0.57      0.67        28
#                        soul       0.70      0.61      0.65        23
#               soul_groove10       0.67      0.33      0.44         6
#                soul_groove3       1.00      0.83      0.91         6
#                soul_groove4       1.00      0.17      0.29         6
#                soul_groove9       1.00      1.00      1.00         6
#                 soul_motown       1.00      0.73      0.85        15
#
#                    accuracy                           0.76      1827
#                   macro avg       0.81      0.70      0.73      1827
#                weighted avg       0.78      0.76      0.76      1827
#
#
# Overall Accuracy: 76.46%
# Mean Average Precision (mAP): 0.8168
# Area Under Curve (AUC): 0.9921
#
# Per-class Metrics:
#
# afrobeat:
#   Precision: 86.11%
#   Recall: 100.00%
#   F1-score: 92.54%
#   mAP: 0.9748
#   AUC: 0.9996
#   Support: 31
#
# afrocuban:
#   Precision: 80.77%
#   Recall: 63.64%
#   F1-score: 71.19%
#   mAP: 0.7590
#   AUC: 0.9841
#   Support: 33
#
# afrocuban_bembe:
#   Precision: 88.89%
#   Recall: 80.00%
#   F1-score: 84.21%
#   mAP: 0.8873
#   AUC: 0.9988
#   Support: 10
#
# afrocuban_calypso:
#   Precision: 85.29%
#   Recall: 100.00%
#   F1-score: 92.06%
#   mAP: 0.9763
#   AUC: 0.9996
#   Support: 29
#
# afrocuban_rhumba:
#   Precision: 100.00%
#   Recall: 90.00%
#   F1-score: 94.74%
#   mAP: 1.0000
#   AUC: 1.0000
#   Support: 10
#
# blues_shuffle:
#   Precision: 62.50%
#   Recall: 62.50%
#   F1-score: 62.50%
#   mAP: 0.5260
#   AUC: 0.9779
#   Support: 8
#
# country:
#   Precision: 88.89%
#   Recall: 66.67%
#   F1-score: 76.19%
#   mAP: 0.7499
#   AUC: 0.9927
#   Support: 12
#
# dance_breakbeat:
#   Precision: 50.00%
#   Recall: 24.00%
#   F1-score: 32.43%
#   mAP: 0.3559
#   AUC: 0.9713
#   Support: 25
#
# dance_disco:
#   Precision: 82.14%
#   Recall: 76.67%
#   F1-score: 79.31%
#   mAP: 0.8461
#   AUC: 0.9934
#   Support: 30
#
# funk:
#   Precision: 75.59%
#   Recall: 72.18%
#   F1-score: 73.85%
#   mAP: 0.8274
#   AUC: 0.9618
#   Support: 133
#
# funk_fast:
#   Precision: 55.56%
#   Recall: 38.46%
#   F1-score: 45.45%
#   mAP: 0.4838
#   AUC: 0.9746
#   Support: 13
#
# funk_groove1:
#   Precision: 50.00%
#   Recall: 16.67%
#   F1-score: 25.00%
#   mAP: 0.8734
#   AUC: 0.9996
#   Support: 6
#
# funk_groove2:
#   Precision: 66.67%
#   Recall: 66.67%
#   F1-score: 66.67%
#   mAP: 0.8556
#   AUC: 0.9995
#   Support: 6
#
# funk_groove5:
#   Precision: 83.33%
#   Recall: 83.33%
#   F1-score: 83.33%
#   mAP: 0.8215
#   AUC: 0.9993
#   Support: 6
#
# funk_latin:
#   Precision: 90.00%
#   Recall: 69.23%
#   F1-score: 78.26%
#   mAP: 0.8792
#   AUC: 0.9934
#   Support: 13
#
# funk_purdieshuffle:
#   Precision: 63.64%
#   Recall: 33.33%
#   F1-score: 43.75%
#   mAP: 0.4529
#   AUC: 0.9758
#   Support: 21
#
# funk_rock:
#   Precision: 100.00%
#   Recall: 50.00%
#   F1-score: 66.67%
#   mAP: 0.6771
#   AUC: 0.9982
#   Support: 4
#
# gospel:
#   Precision: 100.00%
#   Recall: 57.14%
#   F1-score: 72.73%
#   mAP: 0.9821
#   AUC: 0.9999
#   Support: 7
#
# hiphop:
#   Precision: 83.64%
#   Recall: 67.65%
#   F1-score: 74.80%
#   mAP: 0.8426
#   AUC: 0.9867
#   Support: 68
#
# hiphop_groove6:
#   Precision: 100.00%
#   Recall: 66.67%
#   F1-score: 80.00%
#   mAP: 0.8819
#   AUC: 0.9995
#   Support: 6
#
# jazz:
#   Precision: 71.88%
#   Recall: 75.82%
#   F1-score: 73.80%
#   mAP: 0.8107
#   AUC: 0.9833
#   Support: 91
#
# jazz_fast:
#   Precision: 33.09%
#   Recall: 97.83%
#   F1-score: 49.45%
#   mAP: 0.5171
#   AUC: 0.9808
#   Support: 46
#
# jazz_funk:
#   Precision: 85.71%
#   Recall: 35.29%
#   F1-score: 50.00%
#   mAP: 0.5077
#   AUC: 0.9487
#   Support: 17
#
# jazz_fusion:
#   Precision: 60.00%
#   Recall: 50.00%
#   F1-score: 54.55%
#   mAP: 0.5376
#   AUC: 0.9803
#   Support: 6
#
# jazz_klezmer:
#   Precision: 100.00%
#   Recall: 100.00%
#   F1-score: 100.00%
#   mAP: 1.0000
#   AUC: 1.0000
#   Support: 2
#
# jazz_linear:
#   Precision: 96.43%
#   Recall: 79.41%
#   F1-score: 87.10%
#   mAP: 0.9108
#   AUC: 0.9942
#   Support: 34
#
# jazz_march:
#   Precision: 96.00%
#   Recall: 100.00%
#   F1-score: 97.96%
#   mAP: 1.0000
#   AUC: 1.0000
#   Support: 24
#
# jazz_mediumfast:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.2820
#   AUC: 0.9682
#   Support: 26
#
# jazz_swing:
#   Precision: 95.52%
#   Recall: 91.43%
#   F1-score: 93.43%
#   mAP: 0.9688
#   AUC: 0.9960
#   Support: 70
#
# latin:
#   Precision: 100.00%
#   Recall: 100.00%
#   F1-score: 100.00%
#   mAP: 1.0000
#   AUC: 1.0000
#   Support: 24
#
# latin_ando:
#   Precision: 76.92%
#   Recall: 90.91%
#   F1-score: 83.33%
#   mAP: 0.8816
#   AUC: 0.9992
#   Support: 11
#
# latin_bomba:
#   Precision: 100.00%
#   Recall: 75.00%
#   F1-score: 85.71%
#   mAP: 0.9659
#   AUC: 0.9998
#   Support: 8
#
# latin_brazilian:
#   Precision: 100.00%
#   Recall: 30.00%
#   F1-score: 46.15%
#   mAP: 0.5556
#   AUC: 0.9859
#   Support: 10
#
# latin_brazilian-baiao:
#   Precision: 75.00%
#   Recall: 54.55%
#   F1-score: 63.16%
#   mAP: 0.6601
#   AUC: 0.9777
#   Support: 22
#
# latin_brazilian-bossa:
#   Precision: 73.08%
#   Recall: 90.48%
#   F1-score: 80.85%
#   mAP: 0.8789
#   AUC: 0.9903
#   Support: 63
#
# latin_brazilian-frevo:
#   Precision: 88.89%
#   Recall: 100.00%
#   F1-score: 94.12%
#   mAP: 0.9318
#   AUC: 0.9997
#   Support: 8
#
# latin_brazilian-ijexa:
#   Precision: 100.00%
#   Recall: 75.00%
#   F1-score: 85.71%
#   mAP: 0.9519
#   AUC: 0.9997
#   Support: 8
#
# latin_brazilian-maracatu:
#   Precision: 78.57%
#   Recall: 61.11%
#   F1-score: 68.75%
#   mAP: 0.8398
#   AUC: 0.9855
#   Support: 18
#
# latin_brazilian-samba:
#   Precision: 89.66%
#   Recall: 81.25%
#   F1-score: 85.25%
#   mAP: 0.9757
#   AUC: 0.9995
#   Support: 32
#
# latin_brazilian-sambareggae:
#   Precision: 100.00%
#   Recall: 94.44%
#   F1-score: 97.14%
#   mAP: 0.9971
#   AUC: 1.0000
#   Support: 18
#
# latin_brazilian-songo:
#   Precision: 65.52%
#   Recall: 61.29%
#   F1-score: 63.33%
#   mAP: 0.6762
#   AUC: 0.9919
#   Support: 31
#
# latin_chacarera:
#   Precision: 95.83%
#   Recall: 95.83%
#   F1-score: 95.83%
#   mAP: 0.9983
#   AUC: 1.0000
#   Support: 24
#
# latin_dominican-merengue:
#   Precision: 80.00%
#   Recall: 100.00%
#   F1-score: 88.89%
#   mAP: 1.0000
#   AUC: 1.0000
#   Support: 16
#
# latin_merengue:
#   Precision: 100.00%
#   Recall: 100.00%
#   F1-score: 100.00%
#   mAP: 1.0000
#   AUC: 1.0000
#   Support: 1
#
# latin_reggaeton:
#   Precision: 100.00%
#   Recall: 100.00%
#   F1-score: 100.00%
#   mAP: 1.0000
#   AUC: 1.0000
#   Support: 3
#
# latin_samba:
#   Precision: 81.82%
#   Recall: 47.37%
#   F1-score: 60.00%
#   mAP: 0.7342
#   AUC: 0.9902
#   Support: 19
#
# latin_venezuelan-joropo:
#   Precision: 100.00%
#   Recall: 75.00%
#   F1-score: 85.71%
#   mAP: 1.0000
#   AUC: 1.0000
#   Support: 4
#
# latin_venezuelan-merengue:
#   Precision: 100.00%
#   Recall: 100.00%
#   F1-score: 100.00%
#   mAP: 1.0000
#   AUC: 1.0000
#   Support: 9
#
# latin_venezuelan-sangueo:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.3874
#   AUC: 0.9898
#   Support: 3
#
# middleeastern:
#   Precision: 88.89%
#   Recall: 66.67%
#   F1-score: 76.19%
#   mAP: 0.7742
#   AUC: 0.9929
#   Support: 12
#
# neworleans_chacha:
#   Precision: 50.00%
#   Recall: 16.67%
#   F1-score: 25.00%
#   mAP: 0.4030
#   AUC: 0.9765
#   Support: 6
#
# neworleans_funk:
#   Precision: 94.12%
#   Recall: 51.61%
#   F1-score: 66.67%
#   mAP: 0.7889
#   AUC: 0.9879
#   Support: 31
#
# neworleans_secondline:
#   Precision: 100.00%
#   Recall: 76.19%
#   F1-score: 86.49%
#   mAP: 0.9277
#   AUC: 0.9966
#   Support: 21
#
# neworleans_shuffle:
#   Precision: 100.00%
#   Recall: 100.00%
#   F1-score: 100.00%
#   mAP: 1.0000
#   AUC: 1.0000
#   Support: 5
#
# pop:
#   Precision: 93.75%
#   Recall: 83.33%
#   F1-score: 88.24%
#   mAP: 0.9575
#   AUC: 0.9994
#   Support: 18
#
# pop_groove7:
#   Precision: 100.00%
#   Recall: 50.00%
#   F1-score: 66.67%
#   mAP: 0.6920
#   AUC: 0.9855
#   Support: 6
#
# pop_soft:
#   Precision: 66.67%
#   Recall: 57.14%
#   F1-score: 61.54%
#   mAP: 0.6827
#   AUC: 0.9967
#   Support: 7
#
# punk:
#   Precision: 96.15%
#   Recall: 89.29%
#   F1-score: 92.59%
#   mAP: 0.9916
#   AUC: 0.9999
#   Support: 28
#
# reggae:
#   Precision: 57.14%
#   Recall: 76.92%
#   F1-score: 65.57%
#   mAP: 0.7800
#   AUC: 0.9957
#   Support: 26
#
# reggae_slow:
#   Precision: 100.00%
#   Recall: 100.00%
#   F1-score: 100.00%
#   mAP: 1.0000
#   AUC: 1.0000
#   Support: 3
#
# rock:
#   Precision: 75.52%
#   Recall: 91.78%
#   F1-score: 82.86%
#   mAP: 0.9343
#   AUC: 0.9792
#   Support: 353
#
# rock_folk:
#   Precision: 100.00%
#   Recall: 70.00%
#   F1-score: 82.35%
#   mAP: 0.9769
#   AUC: 0.9998
#   Support: 10
#
# rock_groove8:
#   Precision: 75.00%
#   Recall: 100.00%
#   F1-score: 85.71%
#   mAP: 0.9107
#   AUC: 0.9996
#   Support: 6
#
# rock_halftime:
#   Precision: 59.09%
#   Recall: 48.15%
#   F1-score: 53.06%
#   mAP: 0.5685
#   AUC: 0.9767
#   Support: 27
#
# rock_indie:
#   Precision: 66.67%
#   Recall: 40.00%
#   F1-score: 50.00%
#   mAP: 0.6652
#   AUC: 0.9957
#   Support: 5
#
# rock_prog:
#   Precision: 67.65%
#   Recall: 82.14%
#   F1-score: 74.19%
#   mAP: 0.8638
#   AUC: 0.9953
#   Support: 28
#
# rock_rockabilly:
#   Precision: 80.65%
#   Recall: 96.15%
#   F1-score: 87.72%
#   mAP: 0.9646
#   AUC: 0.9994
#   Support: 26
#
# rock_shuffle:
#   Precision: 80.00%
#   Recall: 57.14%
#   F1-score: 66.67%
#   mAP: 0.7602
#   AUC: 0.9901
#   Support: 28
#
# soul:
#   Precision: 70.00%
#   Recall: 60.87%
#   F1-score: 65.12%
#   mAP: 0.7983
#   AUC: 0.9924
#   Support: 23
#
# soul_groove10:
#   Precision: 66.67%
#   Recall: 33.33%
#   F1-score: 44.44%
#   mAP: 0.6996
#   AUC: 0.9986
#   Support: 6
#
# soul_groove3:
#   Precision: 100.00%
#   Recall: 83.33%
#   F1-score: 90.91%
#   mAP: 0.9762
#   AUC: 0.9999
#   Support: 6
#
# soul_groove4:
#   Precision: 100.00%
#   Recall: 16.67%
#   F1-score: 28.57%
#   mAP: 0.8000
#   AUC: 0.9989
#   Support: 6
#
# soul_groove9:
#   Precision: 100.00%
#   Recall: 100.00%
#   F1-score: 100.00%
#   mAP: 0.9762
#   AUC: 0.9999
#   Support: 6
#
# soul_motown:
#   Precision: 100.00%
#   Recall: 73.33%
#   F1-score: 84.62%
#   mAP: 0.9269
#   AUC: 0.9960
#   Support: 15
