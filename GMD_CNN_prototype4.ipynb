# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd
import torch
import torch.nn.functional as F
import torchaudio
import torchaudio.transforms as T
from torch.utils.data import Dataset

# %% [markdown]
# #verify Directories - do not need to rerun

# %%
import os
import pandas as pd

# Define base resource path
base_path = "/content/drive/My Drive/LUMT_Thesis_Resources"

# Metadata file path
metadata_path = os.path.join(base_path, "groove_2bar_16000hz_segmented_metadata_all_splits_withaudio_filepath_styleclass_10sec_split_rev_mini_v2.csv")

# Validate that paths exist
print("Checking directories and metadata:")
print(f"Base path exists: {os.path.exists(base_path)}")
print(f"Metadata file exists: {os.path.exists(metadata_path)}")

# Load metadata
metadata = pd.read_csv(metadata_path)

# Confirm required columns exist
assert 'split_rev' in metadata.columns, "'split_rev' column missing in metadata"
assert 'file_path' in metadata.columns, "'file_path' column missing in metadata"

# Preview and verify 3 file paths per split
print("\nChecking sample audio file existence for each split:")
for split in ['train', 'test', 'validation']:
    split_df = metadata[metadata['split_rev'] == split]
    sample_paths = split_df['file_path'].head(3)

    print(f"\n{split.capitalize()} split samples:")
    for rel_path in sample_paths:
        abs_path = os.path.join(base_path, rel_path)
        exists = os.path.exists(abs_path)
        print(f"File exists: {exists} - {abs_path}")
# Out:
# Checking directories and metadata:
# Base path exists: True
# Metadata file exists: True
#
# Checking sample audio file existence for each split:
#
# Train split samples:
# File exists: True - /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer8_session1_26_025.wav
# File exists: True - /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer8_session1_26_061.wav
# File exists: True - /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer8_session1_26_030.wav
#
# Test split samples:
# File exists: True - /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_validation/drummer8_session1_16_049.wav
# File exists: True - /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer8_session1_17_008.wav
# File exists: True - /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_validation/drummer8_session1_16_051.wav
#
# Validation split samples:
# File exists: True - /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_validation/drummer8_session1_16_036.wav
# File exists: True - /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer8_session1_17_013.wav
# File exists: True - /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_validation/drummer8_session1_16_034.wav

# %% [markdown]
# Note above how the split_rev is independednt of the original directory structures which was based on the initial split of the data.
#
# This way the model knows to look to the 'split_rev' to get the split then to the 'file_path' to get the exact location.
#
# This is instead of using some logic that assumes the file paths based on combining the base dir + audio folder +file names for example which would be used if the file paths matched the split_rev.
#
# This is crucial to note because it ensure no leakage between splits.

# %% [markdown]
# #Verify Class distributions

# %%
import pandas as pd

# Load metadata if not already loaded
metadata = pd.read_csv(metadata_path)

# Ensure column exists
assert 'split_rev' in metadata.columns
assert 'style_class' in metadata.columns

# Extract sorted unique classes
classes = sorted(metadata['style_class'].unique())
num_classes = len(classes)

print(f"Found {num_classes} unique classes: {classes}\n")

# Count total samples per class (entire dataset)
print("Total samples per class:")
total_class_counts = metadata['style_class'].value_counts().loc[classes]
for cls in classes:
    count = total_class_counts[cls]
    print(f"{cls}: {count} samples")

# Split-wise class distribution
print("\nClass distribution in new splits:\n")
for split in ['train', 'validation', 'test']:
    split_df = metadata[metadata['split_rev'] == split]
    total = len(split_df)
    print(f"{split.capitalize()} split:")
    print(f"Total samples: {total}")

    counts = split_df['style_class'].value_counts().reindex(classes, fill_value=0)
    for cls in classes:
        count = counts[cls]
        percent = (count / total) * 100
        print(f"{cls}: {count} samples ({percent:.1f}%)")
    print("")

# Index mapping
print("Class mapping:")
class_to_index = {i: cls for i, cls in enumerate(classes)}
for idx, cls in class_to_index.items():
    print(f"{idx}: {cls}")
# Out:
# Found 74 unique classes: ['afrobeat', 'afrocuban', 'afrocuban_bembe', 'afrocuban_calypso', 'afrocuban_rhumba', 'blues_shuffle', 'country', 'dance_breakbeat', 'dance_disco', 'funk', 'funk_fast', 'funk_groove1', 'funk_groove2', 'funk_groove5', 'funk_latin', 'funk_purdieshuffle', 'funk_rock', 'gospel', 'hiphop', 'hiphop_groove6', 'jazz', 'jazz_fast', 'jazz_funk', 'jazz_fusion', 'jazz_klezmer', 'jazz_linear', 'jazz_march', 'jazz_mediumfast', 'jazz_swing', 'latin', 'latin_ando', 'latin_bomba', 'latin_brazilian', 'latin_brazilian-baiao', 'latin_brazilian-bossa', 'latin_brazilian-frevo', 'latin_brazilian-ijexa', 'latin_brazilian-maracatu', 'latin_brazilian-samba', 'latin_brazilian-sambareggae', 'latin_brazilian-songo', 'latin_chacarera', 'latin_dominican-merengue', 'latin_merengue', 'latin_reggaeton', 'latin_samba', 'latin_venezuelan-joropo', 'latin_venezuelan-merengue', 'latin_venezuelan-sangueo', 'middleeastern', 'neworleans_chacha', 'neworleans_funk', 'neworleans_secondline', 'neworleans_shuffle', 'pop', 'pop_groove7', 'pop_soft', 'punk', 'reggae', 'reggae_slow', 'rock', 'rock_folk', 'rock_groove8', 'rock_halftime', 'rock_indie', 'rock_prog', 'rock_rockabilly', 'rock_shuffle', 'soul', 'soul_groove10', 'soul_groove3', 'soul_groove4', 'soul_groove9', 'soul_motown']
#
# Total samples per class:
# afrobeat: 30 samples
# afrocuban: 32 samples
# afrocuban_bembe: 10 samples
# afrocuban_calypso: 29 samples
# afrocuban_rhumba: 10 samples
# blues_shuffle: 12 samples
# country: 14 samples
# dance_breakbeat: 24 samples
# dance_disco: 30 samples
# funk: 132 samples
# funk_fast: 12 samples
# funk_groove1: 7 samples
# funk_groove2: 7 samples
# funk_groove5: 7 samples
# funk_latin: 12 samples
# funk_purdieshuffle: 20 samples
# funk_rock: 6 samples
# gospel: 8 samples
# hiphop: 69 samples
# hiphop_groove6: 7 samples
# jazz: 93 samples
# jazz_fast: 47 samples
# jazz_funk: 18 samples
# jazz_fusion: 7 samples
# jazz_klezmer: 4 samples
# jazz_linear: 33 samples
# jazz_march: 25 samples
# jazz_mediumfast: 27 samples
# jazz_swing: 70 samples
# latin: 23 samples
# latin_ando: 11 samples
# latin_bomba: 9 samples
# latin_brazilian: 13 samples
# latin_brazilian-baiao: 23 samples
# latin_brazilian-bossa: 62 samples
# latin_brazilian-frevo: 8 samples
# latin_brazilian-ijexa: 9 samples
# latin_brazilian-maracatu: 18 samples
# latin_brazilian-samba: 33 samples
# latin_brazilian-sambareggae: 18 samples
# latin_brazilian-songo: 31 samples
# latin_chacarera: 23 samples
# latin_dominican-merengue: 17 samples
# latin_merengue: 3 samples
# latin_reggaeton: 5 samples
# latin_samba: 20 samples
# latin_venezuelan-joropo: 5 samples
# latin_venezuelan-merengue: 9 samples
# latin_venezuelan-sangueo: 5 samples
# middleeastern: 11 samples
# neworleans_chacha: 7 samples
# neworleans_funk: 30 samples
# neworleans_secondline: 22 samples
# neworleans_shuffle: 6 samples
# pop: 18 samples
# pop_groove7: 7 samples
# pop_soft: 8 samples
# punk: 28 samples
# reggae: 26 samples
# reggae_slow: 4 samples
# rock: 352 samples
# rock_folk: 10 samples
# rock_groove8: 7 samples
# rock_halftime: 28 samples
# rock_indie: 6 samples
# rock_prog: 30 samples
# rock_rockabilly: 27 samples
# rock_shuffle: 28 samples
# soul: 24 samples
# soul_groove10: 7 samples
# soul_groove3: 7 samples
# soul_groove4: 7 samples
# soul_groove9: 7 samples
# soul_motown: 16 samples
#
# Class distribution in new splits:
#
# Train split:
# Total samples: 1464
# afrobeat: 24 samples (1.6%)
# afrocuban: 26 samples (1.8%)
# afrocuban_bembe: 8 samples (0.5%)
# afrocuban_calypso: 23 samples (1.6%)
# afrocuban_rhumba: 8 samples (0.5%)
# blues_shuffle: 8 samples (0.5%)
# country: 10 samples (0.7%)
# dance_breakbeat: 20 samples (1.4%)
# dance_disco: 24 samples (1.6%)
# funk: 106 samples (7.2%)
# funk_fast: 10 samples (0.7%)
# funk_groove1: 5 samples (0.3%)
# funk_groove2: 5 samples (0.3%)
# funk_groove5: 5 samples (0.3%)
# funk_latin: 10 samples (0.7%)
# funk_purdieshuffle: 16 samples (1.1%)
# funk_rock: 4 samples (0.3%)
# gospel: 6 samples (0.4%)
# hiphop: 55 samples (3.8%)
# hiphop_groove6: 5 samples (0.3%)
# jazz: 73 samples (5.0%)
# jazz_fast: 37 samples (2.5%)
# jazz_funk: 14 samples (1.0%)
# jazz_fusion: 5 samples (0.3%)
# jazz_klezmer: 2 samples (0.1%)
# jazz_linear: 26 samples (1.8%)
# jazz_march: 19 samples (1.3%)
# jazz_mediumfast: 21 samples (1.4%)
# jazz_swing: 56 samples (3.8%)
# latin: 19 samples (1.3%)
# latin_ando: 9 samples (0.6%)
# latin_bomba: 7 samples (0.5%)
# latin_brazilian: 9 samples (0.6%)
# latin_brazilian-baiao: 18 samples (1.2%)
# latin_brazilian-bossa: 50 samples (3.4%)
# latin_brazilian-frevo: 6 samples (0.4%)
# latin_brazilian-ijexa: 7 samples (0.5%)
# latin_brazilian-maracatu: 14 samples (1.0%)
# latin_brazilian-samba: 25 samples (1.7%)
# latin_brazilian-sambareggae: 14 samples (1.0%)
# latin_brazilian-songo: 25 samples (1.7%)
# latin_chacarera: 19 samples (1.3%)
# latin_dominican-merengue: 13 samples (0.9%)
# latin_merengue: 1 samples (0.1%)
# latin_reggaeton: 3 samples (0.2%)
# latin_samba: 16 samples (1.1%)
# latin_venezuelan-joropo: 3 samples (0.2%)
# latin_venezuelan-merengue: 7 samples (0.5%)
# latin_venezuelan-sangueo: 3 samples (0.2%)
# middleeastern: 9 samples (0.6%)
# neworleans_chacha: 5 samples (0.3%)
# neworleans_funk: 24 samples (1.6%)
# neworleans_secondline: 17 samples (1.2%)
# neworleans_shuffle: 4 samples (0.3%)
# pop: 14 samples (1.0%)
# pop_groove7: 5 samples (0.3%)
# pop_soft: 6 samples (0.4%)
# punk: 22 samples (1.5%)
# reggae: 20 samples (1.4%)
# reggae_slow: 2 samples (0.1%)
# rock: 283 samples (19.3%)
# rock_folk: 8 samples (0.5%)
# rock_groove8: 5 samples (0.3%)
# rock_halftime: 22 samples (1.5%)
# rock_indie: 4 samples (0.3%)
# rock_prog: 22 samples (1.5%)
# rock_rockabilly: 21 samples (1.4%)
# rock_shuffle: 22 samples (1.5%)
# soul: 18 samples (1.2%)
# soul_groove10: 5 samples (0.3%)
# soul_groove3: 5 samples (0.3%)
# soul_groove4: 5 samples (0.3%)
# soul_groove9: 5 samples (0.3%)
# soul_motown: 12 samples (0.8%)
#
# Validation split:
# Total samples: 204
# afrobeat: 3 samples (1.5%)
# afrocuban: 3 samples (1.5%)
# afrocuban_bembe: 1 samples (0.5%)
# afrocuban_calypso: 3 samples (1.5%)
# afrocuban_rhumba: 1 samples (0.5%)
# blues_shuffle: 2 samples (1.0%)
# country: 2 samples (1.0%)
# dance_breakbeat: 2 samples (1.0%)
# dance_disco: 3 samples (1.5%)
# funk: 13 samples (6.4%)
# funk_fast: 1 samples (0.5%)
# funk_groove1: 1 samples (0.5%)
# funk_groove2: 1 samples (0.5%)
# funk_groove5: 1 samples (0.5%)
# funk_latin: 1 samples (0.5%)
# funk_purdieshuffle: 2 samples (1.0%)
# funk_rock: 1 samples (0.5%)
# gospel: 1 samples (0.5%)
# hiphop: 7 samples (3.4%)
# hiphop_groove6: 1 samples (0.5%)
# jazz: 10 samples (4.9%)
# jazz_fast: 5 samples (2.5%)
# jazz_funk: 2 samples (1.0%)
# jazz_fusion: 1 samples (0.5%)
# jazz_klezmer: 1 samples (0.5%)
# jazz_linear: 3 samples (1.5%)
# jazz_march: 3 samples (1.5%)
# jazz_mediumfast: 3 samples (1.5%)
# jazz_swing: 7 samples (3.4%)
# latin: 2 samples (1.0%)
# latin_ando: 1 samples (0.5%)
# latin_bomba: 1 samples (0.5%)
# latin_brazilian: 2 samples (1.0%)
# latin_brazilian-baiao: 3 samples (1.5%)
# latin_brazilian-bossa: 6 samples (2.9%)
# latin_brazilian-frevo: 1 samples (0.5%)
# latin_brazilian-ijexa: 1 samples (0.5%)
# latin_brazilian-maracatu: 2 samples (1.0%)
# latin_brazilian-samba: 4 samples (2.0%)
# latin_brazilian-sambareggae: 2 samples (1.0%)
# latin_brazilian-songo: 3 samples (1.5%)
# latin_chacarera: 2 samples (1.0%)
# latin_dominican-merengue: 2 samples (1.0%)
# latin_merengue: 1 samples (0.5%)
# latin_reggaeton: 1 samples (0.5%)
# latin_samba: 2 samples (1.0%)
# latin_venezuelan-joropo: 1 samples (0.5%)
# latin_venezuelan-merengue: 1 samples (0.5%)
# latin_venezuelan-sangueo: 1 samples (0.5%)
# middleeastern: 1 samples (0.5%)
# neworleans_chacha: 1 samples (0.5%)
# neworleans_funk: 3 samples (1.5%)
# neworleans_secondline: 3 samples (1.5%)
# neworleans_shuffle: 1 samples (0.5%)
# pop: 2 samples (1.0%)
# pop_groove7: 1 samples (0.5%)
# pop_soft: 1 samples (0.5%)
# punk: 3 samples (1.5%)
# reggae: 3 samples (1.5%)
# reggae_slow: 1 samples (0.5%)
# rock: 35 samples (17.2%)
# rock_folk: 1 samples (0.5%)
# rock_groove8: 1 samples (0.5%)
# rock_halftime: 3 samples (1.5%)
# rock_indie: 1 samples (0.5%)
# rock_prog: 4 samples (2.0%)
# rock_rockabilly: 3 samples (1.5%)
# rock_shuffle: 3 samples (1.5%)
# soul: 3 samples (1.5%)
# soul_groove10: 1 samples (0.5%)
# soul_groove3: 1 samples (0.5%)
# soul_groove4: 1 samples (0.5%)
# soul_groove9: 1 samples (0.5%)
# soul_motown: 2 samples (1.0%)
#
# Test split:
# Total samples: 202
# afrobeat: 3 samples (1.5%)
# afrocuban: 3 samples (1.5%)
# afrocuban_bembe: 1 samples (0.5%)
# afrocuban_calypso: 3 samples (1.5%)
# afrocuban_rhumba: 1 samples (0.5%)
# blues_shuffle: 2 samples (1.0%)
# country: 2 samples (1.0%)
# dance_breakbeat: 2 samples (1.0%)
# dance_disco: 3 samples (1.5%)
# funk: 13 samples (6.4%)
# funk_fast: 1 samples (0.5%)
# funk_groove1: 1 samples (0.5%)
# funk_groove2: 1 samples (0.5%)
# funk_groove5: 1 samples (0.5%)
# funk_latin: 1 samples (0.5%)
# funk_purdieshuffle: 2 samples (1.0%)
# funk_rock: 1 samples (0.5%)
# gospel: 1 samples (0.5%)
# hiphop: 7 samples (3.5%)
# hiphop_groove6: 1 samples (0.5%)
# jazz: 10 samples (5.0%)
# jazz_fast: 5 samples (2.5%)
# jazz_funk: 2 samples (1.0%)
# jazz_fusion: 1 samples (0.5%)
# jazz_klezmer: 1 samples (0.5%)
# jazz_linear: 4 samples (2.0%)
# jazz_march: 3 samples (1.5%)
# jazz_mediumfast: 3 samples (1.5%)
# jazz_swing: 7 samples (3.5%)
# latin: 2 samples (1.0%)
# latin_ando: 1 samples (0.5%)
# latin_bomba: 1 samples (0.5%)
# latin_brazilian: 2 samples (1.0%)
# latin_brazilian-baiao: 2 samples (1.0%)
# latin_brazilian-bossa: 6 samples (3.0%)
# latin_brazilian-frevo: 1 samples (0.5%)
# latin_brazilian-ijexa: 1 samples (0.5%)
# latin_brazilian-maracatu: 2 samples (1.0%)
# latin_brazilian-samba: 4 samples (2.0%)
# latin_brazilian-sambareggae: 2 samples (1.0%)
# latin_brazilian-songo: 3 samples (1.5%)
# latin_chacarera: 2 samples (1.0%)
# latin_dominican-merengue: 2 samples (1.0%)
# latin_merengue: 1 samples (0.5%)
# latin_reggaeton: 1 samples (0.5%)
# latin_samba: 2 samples (1.0%)
# latin_venezuelan-joropo: 1 samples (0.5%)
# latin_venezuelan-merengue: 1 samples (0.5%)
# latin_venezuelan-sangueo: 1 samples (0.5%)
# middleeastern: 1 samples (0.5%)
# neworleans_chacha: 1 samples (0.5%)
# neworleans_funk: 3 samples (1.5%)
# neworleans_secondline: 2 samples (1.0%)
# neworleans_shuffle: 1 samples (0.5%)
# pop: 2 samples (1.0%)
# pop_groove7: 1 samples (0.5%)
# pop_soft: 1 samples (0.5%)
# punk: 3 samples (1.5%)
# reggae: 3 samples (1.5%)
# reggae_slow: 1 samples (0.5%)
# rock: 34 samples (16.8%)
# rock_folk: 1 samples (0.5%)
# rock_groove8: 1 samples (0.5%)
# rock_halftime: 3 samples (1.5%)
# rock_indie: 1 samples (0.5%)
# rock_prog: 4 samples (2.0%)
# rock_rockabilly: 3 samples (1.5%)
# rock_shuffle: 3 samples (1.5%)
# soul: 3 samples (1.5%)
# soul_groove10: 1 samples (0.5%)
# soul_groove3: 1 samples (0.5%)
# soul_groove4: 1 samples (0.5%)
# soul_groove9: 1 samples (0.5%)
# soul_motown: 2 samples (1.0%)
#
# Class mapping:
# 0: afrobeat
# 1: afrocuban
# 2: afrocuban_bembe
# 3: afrocuban_calypso
# 4: afrocuban_rhumba
# 5: blues_shuffle
# 6: country
# 7: dance_breakbeat
# 8: dance_disco
# 9: funk
# 10: funk_fast
# 11: funk_groove1
# 12: funk_groove2
# 13: funk_groove5
# 14: funk_latin
# 15: funk_purdieshuffle
# 16: funk_rock
# 17: gospel
# 18: hiphop
# 19: hiphop_groove6
# 20: jazz
# 21: jazz_fast
# 22: jazz_funk
# 23: jazz_fusion
# 24: jazz_klezmer
# 25: jazz_linear
# 26: jazz_march
# 27: jazz_mediumfast
# 28: jazz_swing
# 29: latin
# 30: latin_ando
# 31: latin_bomba
# 32: latin_brazilian
# 33: latin_brazilian-baiao
# 34: latin_brazilian-bossa
# 35: latin_brazilian-frevo
# 36: latin_brazilian-ijexa
# 37: latin_brazilian-maracatu
# 38: latin_brazilian-samba
# 39: latin_brazilian-sambareggae
# 40: latin_brazilian-songo
# 41: latin_chacarera
# 42: latin_dominican-merengue
# 43: latin_merengue
# 44: latin_reggaeton
# 45: latin_samba
# 46: latin_venezuelan-joropo
# 47: latin_venezuelan-merengue
# 48: latin_venezuelan-sangueo
# 49: middleeastern
# 50: neworleans_chacha
# 51: neworleans_funk
# 52: neworleans_secondline
# 53: neworleans_shuffle
# 54: pop
# 55: pop_groove7
# 56: pop_soft
# 57: punk
# 58: reggae
# 59: reggae_slow
# 60: rock
# 61: rock_folk
# 62: rock_groove8
# 63: rock_halftime
# 64: rock_indie
# 65: rock_prog
# 66: rock_rockabilly
# 67: rock_shuffle
# 68: soul
# 69: soul_groove10
# 70: soul_groove3
# 71: soul_groove4
# 72: soul_groove9
# 73: soul_motown

# %% [markdown]
# #Dataset Class

# %%
# Constants
BASE_DIR = "/content/drive/My Drive/LUMT_Thesis_Resources/"
SAMPLE_RATE = 16_000
CLIP_LENGTH_SAMPLES = SAMPLE_RATE * 10  # 10 seconds = 160000 samples
METADATA_FILE = "groove_2bar_16000hz_segmented_metadata_all_splits_withaudio_filepath_styleclass_10sec_split_rev_mini_v2.csv"
metadata_path = os.path.join(BASE_DIR, METADATA_FILE)

class GrooveDataset(Dataset):
    def __init__(self, split: str):
        assert split in ['train', 'test', 'validation'], f"Invalid split: {split}"

        print(f" Loading metadata from: {metadata_path}")
        df = pd.read_csv(metadata_path)
        print(f" Full metadata loaded: {df.shape[0]} rows")

        # Filter based on revised split
        df = df[df['split_rev'] == split].reset_index(drop=True) #new dataframe per split
        print(f" Subset for '{split}' split: {df.shape[0]} rows")

        # Check required columns
        assert 'file_path' in df.columns, "Missing 'file_path' in metadata"
        assert 'style_class' in df.columns, "Missing 'style_class' in metadata"

        # Convert relative paths to absolute
        df['file_path'] = df['file_path'].apply(lambda x: os.path.join(BASE_DIR, x))

        # Store processed dataframe
        self.data_df = df

        # Build label mapping
        self.labels = sorted(df["style_class"].unique())
        self.class_to_idx = {label: idx for idx, label in enumerate(self.labels)}

        print(" Available classes and mapping:")
        for idx, label in self.class_to_idx.items():
            print(f"  {label}: {idx}")

        # Preview head
        print(" Preview of dataset:")
        print(self.data_df[['file_path', 'style_class']].head(3))

    def __len__(self):
        return len(self.data_df)

    def __getitem__(self, idx):
        row = self.data_df.iloc[idx]
        file_path = row["file_path"]
        label = row["style_class"]

        try:
            waveform, sr = torchaudio.load(file_path)

            # Resample if needed
            if sr != SAMPLE_RATE:
                print(f"[RESAMPLE] {file_path}: {sr}Hz → {SAMPLE_RATE}Hz")
                resampler = T.Resample(orig_freq=sr, new_freq=SAMPLE_RATE)
                waveform = resampler(waveform)

            # Convert to mono
            if waveform.shape[0] > 1:
                waveform = waveform.mean(dim=0, keepdim=True)

            num_samples = waveform.size(1)
            print(f"[AUDIO] {file_path} | Original samples: {num_samples}")

            if num_samples < CLIP_LENGTH_SAMPLES:
                waveform = F.pad(waveform, (0, CLIP_LENGTH_SAMPLES - num_samples))
                print(f"[PADDED] Padded to {CLIP_LENGTH_SAMPLES}")
            else:
                waveform = waveform[:, :CLIP_LENGTH_SAMPLES]
                print(f"[TRIMMED] Trimmed to {CLIP_LENGTH_SAMPLES}")

            label_index = self.class_to_idx[label]
            return waveform, label_index, SAMPLE_RATE

        except Exception as e:
            print(f"[ERROR] Failed loading {file_path}: {e}")
            return None

# --- Instantiate all splits below ---

print(" Instantiating all dataset splits...\n")
train_dataset = GrooveDataset(split="train")
val_dataset = GrooveDataset(split="validation")
test_dataset = GrooveDataset(split="test")

# Print sizes
print(f" Dataset sizes:")
print(f"Train: {len(train_dataset)} samples")
print(f"Validation: {len(val_dataset)} samples")
print(f"Test: {len(test_dataset)} samples")

# Trigger sample loading for verification
print(f" Triggering 1 sample from each split for verification:")
_ = train_dataset[0]
_ = val_dataset[0]
_ = test_dataset[0]
# Out:
#  Instantiating all dataset splits...
#
#  Loading metadata from: /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_16000hz_segmented_metadata_all_splits_withaudio_filepath_styleclass_10sec_split_rev_mini_v2.csv
#  Full metadata loaded: 1870 rows
#  Subset for 'train' split: 1464 rows
#  Available classes and mapping:
#   0: afrobeat
#   1: afrocuban
#   2: afrocuban_bembe
#   3: afrocuban_calypso
#   4: afrocuban_rhumba
#   5: blues_shuffle
#   6: country
#   7: dance_breakbeat
#   8: dance_disco
#   9: funk
#   10: funk_fast
#   11: funk_groove1
#   12: funk_groove2
#   13: funk_groove5
#   14: funk_latin
#   15: funk_purdieshuffle
#   16: funk_rock
#   17: gospel
#   18: hiphop
#   19: hiphop_groove6
#   20: jazz
#   21: jazz_fast
#   22: jazz_funk
#   23: jazz_fusion
#   24: jazz_klezmer
#   25: jazz_linear
#   26: jazz_march
#   27: jazz_mediumfast
#   28: jazz_swing
#   29: latin
#   30: latin_ando
#   31: latin_bomba
#   32: latin_brazilian
#   33: latin_brazilian-baiao
#   34: latin_brazilian-bossa
#   35: latin_brazilian-frevo
#   36: latin_brazilian-ijexa
#   37: latin_brazilian-maracatu
#   38: latin_brazilian-samba
#   39: latin_brazilian-sambareggae
#   40: latin_brazilian-songo
#   41: latin_chacarera
#   42: latin_dominican-merengue
#   43: latin_merengue
#   44: latin_reggaeton
#   45: latin_samba
#   46: latin_venezuelan-joropo
#   47: latin_venezuelan-merengue
#   48: latin_venezuelan-sangueo
#   49: middleeastern
#   50: neworleans_chacha
#   51: neworleans_funk
#   52: neworleans_secondline
#   53: neworleans_shuffle
#   54: pop
#   55: pop_groove7
#   56: pop_soft
#   57: punk
#   58: reggae
#   59: reggae_slow
#   60: rock
#   61: rock_folk
#   62: rock_groove8
#   63: rock_halftime
#   64: rock_indie
#   65: rock_prog
#   66: rock_rockabilly
#   67: rock_shuffle
#   68: soul
#   69: soul_groove10
#   70: soul_groove3
#   71: soul_groove4
#   72: soul_groove9
#   73: soul_motown
#  Preview of dataset:
#                                            file_path style_class
# 0  /content/drive/My Drive/LUMT_Thesis_Resources/...    afrobeat
# 1  /content/drive/My Drive/LUMT_Thesis_Resources/...    afrobeat
# 2  /content/drive/My Drive/LUMT_Thesis_Resources/...    afrobeat
#  Loading metadata from: /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_16000hz_segmented_metadata_all_splits_withaudio_filepath_styleclass_10sec_split_rev_mini_v2.csv
#  Full metadata loaded: 1870 rows
#  Subset for 'validation' split: 204 rows
#  Available classes and mapping:
#   0: afrobeat
#   1: afrocuban
#   2: afrocuban_bembe
#   3: afrocuban_calypso
#   4: afrocuban_rhumba
#   5: blues_shuffle
#   6: country
#   7: dance_breakbeat
#   8: dance_disco
#   9: funk
#   10: funk_fast
#   11: funk_groove1
#   12: funk_groove2
#   13: funk_groove5
#   14: funk_latin
#   15: funk_purdieshuffle
#   16: funk_rock
#   17: gospel
#   18: hiphop
#   19: hiphop_groove6
#   20: jazz
#   21: jazz_fast
#   22: jazz_funk
#   23: jazz_fusion
#   24: jazz_klezmer
#   25: jazz_linear
#   26: jazz_march
#   27: jazz_mediumfast
#   28: jazz_swing
#   29: latin
#   30: latin_ando
#   31: latin_bomba
#   32: latin_brazilian
#   33: latin_brazilian-baiao
#   34: latin_brazilian-bossa
#   35: latin_brazilian-frevo
#   36: latin_brazilian-ijexa
#   37: latin_brazilian-maracatu
#   38: latin_brazilian-samba
#   39: latin_brazilian-sambareggae
#   40: latin_brazilian-songo
#   41: latin_chacarera
#   42: latin_dominican-merengue
#   43: latin_merengue
#   44: latin_reggaeton
#   45: latin_samba
#   46: latin_venezuelan-joropo
#   47: latin_venezuelan-merengue
#   48: latin_venezuelan-sangueo
#   49: middleeastern
#   50: neworleans_chacha
#   51: neworleans_funk
#   52: neworleans_secondline
#   53: neworleans_shuffle
#   54: pop
#   55: pop_groove7
#   56: pop_soft
#   57: punk
#   58: reggae
#   59: reggae_slow
#   60: rock
#   61: rock_folk
#   62: rock_groove8
#   63: rock_halftime
#   64: rock_indie
#   65: rock_prog
#   66: rock_rockabilly
#   67: rock_shuffle
#   68: soul
#   69: soul_groove10
#   70: soul_groove3
#   71: soul_groove4
#   72: soul_groove9
#   73: soul_motown
#  Preview of dataset:
#                                            file_path style_class
# 0  /content/drive/My Drive/LUMT_Thesis_Resources/...    afrobeat
# 1  /content/drive/My Drive/LUMT_Thesis_Resources/...    afrobeat
# 2  /content/drive/My Drive/LUMT_Thesis_Resources/...    afrobeat
#  Loading metadata from: /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_16000hz_segmented_metadata_all_splits_withaudio_filepath_styleclass_10sec_split_rev_mini_v2.csv
#  Full metadata loaded: 1870 rows
#  Subset for 'test' split: 202 rows
#  Available classes and mapping:
#   0: afrobeat
#   1: afrocuban
#   2: afrocuban_bembe
#   3: afrocuban_calypso
#   4: afrocuban_rhumba
#   5: blues_shuffle
#   6: country
#   7: dance_breakbeat
#   8: dance_disco
#   9: funk
#   10: funk_fast
#   11: funk_groove1
#   12: funk_groove2
#   13: funk_groove5
#   14: funk_latin
#   15: funk_purdieshuffle
#   16: funk_rock
#   17: gospel
#   18: hiphop
#   19: hiphop_groove6
#   20: jazz
#   21: jazz_fast
#   22: jazz_funk
#   23: jazz_fusion
#   24: jazz_klezmer
#   25: jazz_linear
#   26: jazz_march
#   27: jazz_mediumfast
#   28: jazz_swing
#   29: latin
#   30: latin_ando
#   31: latin_bomba
#   32: latin_brazilian
#   33: latin_brazilian-baiao
#   34: latin_brazilian-bossa
#   35: latin_brazilian-frevo
#   36: latin_brazilian-ijexa
#   37: latin_brazilian-maracatu
#   38: latin_brazilian-samba
#   39: latin_brazilian-sambareggae
#   40: latin_brazilian-songo
#   41: latin_chacarera
#   42: latin_dominican-merengue
#   43: latin_merengue
#   44: latin_reggaeton
#   45: latin_samba
#   46: latin_venezuelan-joropo
#   47: latin_venezuelan-merengue
#   48: latin_venezuelan-sangueo
#   49: middleeastern
#   50: neworleans_chacha
#   51: neworleans_funk
#   52: neworleans_secondline
#   53: neworleans_shuffle
#   54: pop
#   55: pop_groove7
#   56: pop_soft
#   57: punk
#   58: reggae
#   59: reggae_slow
#   60: rock
#   61: rock_folk
#   62: rock_groove8
#   63: rock_halftime
#   64: rock_indie
#   65: rock_prog
#   66: rock_rockabilly
#   67: rock_shuffle
#   68: soul
#   69: soul_groove10
#   70: soul_groove3
#   71: soul_groove4
#   72: soul_groove9
#   73: soul_motown
#  Preview of dataset:
#                                            file_path style_class
# 0  /content/drive/My Drive/LUMT_Thesis_Resources/...    afrobeat
# 1  /content/drive/My Drive/LUMT_Thesis_Resources/...    afrobeat
# 2  /content/drive/My Drive/LUMT_Thesis_Resources/...    afrobeat
#  Dataset sizes:
# Train: 1464 samples
# Validation: 204 samples
# Test: 202 samples
#  Triggering 1 sample from each split for verification:
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer8_session1_26_025.wav | Original samples: 81702
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_validation/drummer8_session1_16_036.wav | Original samples: 85333
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_validation/drummer8_session1_16_049.wav | Original samples: 85334
# [PADDED] Padded to 160000

# %% [markdown]
# #Sanity Checks for datasets

# %%
# Sanity check: trigger 3 samples per dataset after instantiation

print(" Running sanity check: first 3 samples from each split\n")

dataset_dict = {
    "train": train_dataset,
    "validation": val_dataset,
    "test": test_dataset
}

for split_name, dataset in dataset_dict.items():
    print(f" Split: {split_name.upper()}")
    print(f"Size: {len(dataset)} samples")

    for i in range(3):
        print(f" Sample {i+1}:")
        _ = dataset[i]
# Out:
#  Running sanity check: first 3 samples from each split
#
#  Split: TRAIN
# Size: 1464 samples
#  Sample 1:
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer8_session1_26_025.wav | Original samples: 81702
# [PADDED] Padded to 160000
#  Sample 2:
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer8_session1_26_061.wav | Original samples: 81703
# [PADDED] Padded to 160000
#  Sample 3:
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer8_session1_26_030.wav | Original samples: 81703
# [PADDED] Padded to 160000
#  Split: VALIDATION
# Size: 204 samples
#  Sample 1:
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_validation/drummer8_session1_16_036.wav | Original samples: 85333
# [PADDED] Padded to 160000
#  Sample 2:
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer8_session1_17_013.wav | Original samples: 85334
# [PADDED] Padded to 160000
#  Sample 3:
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_validation/drummer8_session1_16_034.wav | Original samples: 85334
# [PADDED] Padded to 160000
#  Split: TEST
# Size: 202 samples
#  Sample 1:
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_validation/drummer8_session1_16_049.wav | Original samples: 85334
# [PADDED] Padded to 160000
#  Sample 2:
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer8_session1_17_008.wav | Original samples: 85333
# [PADDED] Padded to 160000
#  Sample 3:
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_validation/drummer8_session1_16_051.wav | Original samples: 85333
# [PADDED] Padded to 160000

# %%
# Enhanced debug: Inspect waveform, label, and metadata for 3 samples per split

print(" Detailed shape and label check per split...\n")

dataset_dict = {
    "train": train_dataset,
    "validation": val_dataset,
    "test": test_dataset
}

for split_name, dataset in dataset_dict.items():
    print(f" SPLIT: {split_name.upper()}")
    for i in range(3):
        print(f" Sample {i+1}:")

        # Load waveform, label index, sample rate
        sample_waveform, sample_label_idx, sample_rate = dataset[i]

        # Get corresponding metadata
        row = dataset.data_df.iloc[i]
        split_rev = row['split_rev']
        file_path = row['file_path']
        style_class = row['style_class']

        # Print info
        print(f"  ➤ split_rev     : {split_rev}")
        print(f"  ➤ file_path     : {file_path}")
        print(f"  ➤ style_class   : {style_class}")
        print(f"  ➤ label index   : {sample_label_idx}")
        print(f"  ➤ waveform shape: {sample_waveform.shape}")
        print(f"  ➤ sample rate   : {sample_rate}")
# Out:
#  Detailed shape and label check per split...
#
#  SPLIT: TRAIN
#  Sample 1:
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer8_session1_26_025.wav | Original samples: 81702
# [PADDED] Padded to 160000
#   ➤ split_rev     : train
#   ➤ file_path     : /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer8_session1_26_025.wav
#   ➤ style_class   : afrobeat
#   ➤ label index   : 0
#   ➤ waveform shape: torch.Size([1, 160000])
#   ➤ sample rate   : 16000
#  Sample 2:
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer8_session1_26_061.wav | Original samples: 81703
# [PADDED] Padded to 160000
#   ➤ split_rev     : train
#   ➤ file_path     : /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer8_session1_26_061.wav
#   ➤ style_class   : afrobeat
#   ➤ label index   : 0
#   ➤ waveform shape: torch.Size([1, 160000])
#   ➤ sample rate   : 16000
#  Sample 3:
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer8_session1_26_030.wav | Original samples: 81703
# [PADDED] Padded to 160000
#   ➤ split_rev     : train
#   ➤ file_path     : /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer8_session1_26_030.wav
#   ➤ style_class   : afrobeat
#   ➤ label index   : 0
#   ➤ waveform shape: torch.Size([1, 160000])
#   ➤ sample rate   : 16000
#  SPLIT: VALIDATION
#  Sample 1:
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_validation/drummer8_session1_16_036.wav | Original samples: 85333
# [PADDED] Padded to 160000
#   ➤ split_rev     : validation
#   ➤ file_path     : /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_validation/drummer8_session1_16_036.wav
#   ➤ style_class   : afrobeat
#   ➤ label index   : 0
#   ➤ waveform shape: torch.Size([1, 160000])
#   ➤ sample rate   : 16000
#  Sample 2:
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer8_session1_17_013.wav | Original samples: 85334
# [PADDED] Padded to 160000
#   ➤ split_rev     : validation
#   ➤ file_path     : /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer8_session1_17_013.wav
#   ➤ style_class   : afrobeat
#   ➤ label index   : 0
#   ➤ waveform shape: torch.Size([1, 160000])
#   ➤ sample rate   : 16000
#  Sample 3:
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_validation/drummer8_session1_16_034.wav | Original samples: 85334
# [PADDED] Padded to 160000
#   ➤ split_rev     : validation
#   ➤ file_path     : /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_validation/drummer8_session1_16_034.wav
#   ➤ style_class   : afrobeat
#   ➤ label index   : 0
#   ➤ waveform shape: torch.Size([1, 160000])
#   ➤ sample rate   : 16000
#  SPLIT: TEST
#  Sample 1:
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_validation/drummer8_session1_16_049.wav | Original samples: 85334
# [PADDED] Padded to 160000
#   ➤ split_rev     : test
#   ➤ file_path     : /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_validation/drummer8_session1_16_049.wav
#   ➤ style_class   : afrobeat
#   ➤ label index   : 0
#   ➤ waveform shape: torch.Size([1, 160000])
#   ➤ sample rate   : 16000
#  Sample 2:
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer8_session1_17_008.wav | Original samples: 85333
# [PADDED] Padded to 160000
#   ➤ split_rev     : test
#   ➤ file_path     : /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer8_session1_17_008.wav
#   ➤ style_class   : afrobeat
#   ➤ label index   : 0
#   ➤ waveform shape: torch.Size([1, 160000])
#   ➤ sample rate   : 16000
#  Sample 3:
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_validation/drummer8_session1_16_051.wav | Original samples: 85333
# [PADDED] Padded to 160000
#   ➤ split_rev     : test
#   ➤ file_path     : /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_validation/drummer8_session1_16_051.wav
#   ➤ style_class   : afrobeat
#   ➤ label index   : 0
#   ➤ waveform shape: torch.Size([1, 160000])
#   ➤ sample rate   : 16000

# %% [markdown]
# #Waveform Features class and verify Feature Extraction

# %%
import torch.nn as nn
import torchaudio.transforms as T

class WaveformFeatures(nn.Module):
    def __init__(
        self,
        sample_rate=16_000,
        n_fft=1024,
        n_mels=128,
        power=2.0, #default value
    ):
        super().__init__()
        hop_length = n_fft // 4

        self.spectrogram = T.Spectrogram(n_fft=n_fft, hop_length=hop_length, power=power)
        self.mel_scale = T.MelScale(n_mels=n_mels, sample_rate=sample_rate, n_stft=n_fft // 2 + 1)

    def forward(self, waveform: torch.Tensor) -> torch.Tensor:
        # waveform: (1, N)
        spec = self.spectrogram(waveform)  # (1, F, T)
        mel_spec = self.mel_scale(spec)    # (1, M, T)
        return mel_spec

# %%
# Feature extraction test on real dataset sample
print(" Verifying Mel Spectrogram extraction pipeline...")

# Use existing train_dataset (already filtered, padded)
sample_waveform, sample_label_idx, sample_rate = train_dataset[0]

print(f"Input waveform shape: {sample_waveform.shape}")
print(f"Sample rate: {sample_rate}")
print(f"Label index: {sample_label_idx}")
print(f"Original class: {train_dataset.data_df.iloc[0]['style_class']}")
print(f"From file: {train_dataset.data_df.iloc[0]['file_path']}")

# Instantiate feature extractor
feature_extractor = WaveformFeatures(sample_rate=sample_rate)

# Generate log-mel spectrogram
mel_spectrogram = feature_extractor(sample_waveform)

# Print output shape
print(f" Mel Spectrogram shape: {mel_spectrogram.shape}")
# Out:
#  Verifying Mel Spectrogram extraction pipeline...
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer8_session1_26_025.wav | Original samples: 81702
# [PADDED] Padded to 160000
# Input waveform shape: torch.Size([1, 160000])
# Sample rate: 16000
# Label index: 0
# Original class: afrobeat
# From file: /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer8_session1_26_025.wav
#  Mel Spectrogram shape: torch.Size([1, 128, 626])

# %% [markdown]
# #DataLoader

# %%
from torch.utils.data import DataLoader

# Hyperparameters
BATCH_SIZE = 16
NUM_WORKERS = 0  # Safe default for Colab

# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS)
val_loader   = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)
test_loader  = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)

print("DataLoaders created")

# Sample batch from train loader to verify shapes
print("Inspecting one batch from train_loader...")

batch = next(iter(train_loader))
waveforms, labels, sample_rates = batch

print(f"Waveform batch shape : {waveforms.shape}  # Expect: [B, 1, 160000]")
print(f"Labels shape         : {labels.shape}     # Expect: [B]")
print(f"Sample rates         : {sample_rates}")    # Should all be 16000
# Out:
# DataLoaders created
# Inspecting one batch from train_loader...
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_test/drummer5_eval_session_4_003.wav | Original samples: 96000
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer5_session1_2_247.wav | Original samples: 60472
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer1_session1_5_065.wav | Original samples: 66207
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_test/drummer5_session2_4_094.wav | Original samples: 54468
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer1_session3_4_102.wav | Original samples: 42198
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer1_session1_206_000.wav | Original samples: 54857
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer7_session2_64_010.wav | Original samples: 52966
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_test/drummer7_eval_session_6_004.wav | Original samples: 88276
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer10_session1_1_066.wav | Original samples: 61936
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer5_session1_1_012.wav | Original samples: 60473
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_test/drummer1_session1_239_115.wav | Original samples: 59077
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_validation/drummer1_session3_13_104.wav | Original samples: 66783
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer5_session1_8_030.wav | Original samples: 59260
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_test/drummer5_eval_session_2_003.wav | Original samples: 73143
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer1_session1_146_080.wav | Original samples: 80842
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer1_session3_10_016.wav | Original samples: 85334
# [PADDED] Padded to 160000
# Waveform batch shape : torch.Size([16, 1, 160000])  # Expect: [B, 1, 160000]
# Labels shape         : torch.Size([16])     # Expect: [B]
# Sample rates         : tensor([16000, 16000, 16000, 16000, 16000, 16000, 16000, 16000, 16000, 16000,
#         16000, 16000, 16000, 16000, 16000, 16000])

# %% [markdown]
# #Updated GrooveDataset with Feature Extraction (Dataset Class)

# %%
class GrooveDataset(Dataset):
    def __init__(self, split: str, transform=None):
        assert split in ['train', 'test', 'validation'], f"Invalid split: {split}"
        self.transform = transform

        print(f" Loading metadata from: {metadata_path}")
        df = pd.read_csv(metadata_path)
        print(f" Full metadata loaded: {df.shape[0]} rows")

        df = df[df['split_rev'] == split].reset_index(drop=True)
        print(f" Subset for '{split}' split: {df.shape[0]} rows")

        assert 'file_path' in df.columns
        assert 'style_class' in df.columns

        df['file_path'] = df['file_path'].apply(lambda x: os.path.join(BASE_DIR, x))
        self.data_df = df

        self.labels = sorted(df["style_class"].unique())
        self.class_to_idx = {label: idx for idx, label in enumerate(self.labels)}

        print(" Available classes and mapping:")
        for idx, label in self.class_to_idx.items():
            print(f"  {label}: {idx}")

        print(" Preview of dataset:")
        print(self.data_df[['file_path', 'style_class']].head(3))

    def __len__(self):
        return len(self.data_df)

    def __getitem__(self, idx):
        row = self.data_df.iloc[idx]
        file_path = row["file_path"]
        label = row["style_class"]

        try:
            waveform, sr = torchaudio.load(file_path)

            if sr != SAMPLE_RATE:
                print(f"[RESAMPLE] {file_path}: {sr}Hz → {SAMPLE_RATE}Hz")
                resampler = T.Resample(orig_freq=sr, new_freq=SAMPLE_RATE)
                waveform = resampler(waveform)

            if waveform.shape[0] > 1:
                waveform = waveform.mean(dim=0, keepdim=True)

            num_samples = waveform.size(1)
            print(f"[AUDIO] {file_path} | Original samples: {num_samples}")

            if num_samples < CLIP_LENGTH_SAMPLES:
                waveform = F.pad(waveform, (0, CLIP_LENGTH_SAMPLES - num_samples))
                print(f"[PADDED] Padded to {CLIP_LENGTH_SAMPLES}")
            else:
                waveform = waveform[:, :CLIP_LENGTH_SAMPLES]
                print(f"[TRIMMED] Trimmed to {CLIP_LENGTH_SAMPLES}")

            # APPLY MEL FEATURE EXTRACTOR HERE
            if self.transform:
                features = self.transform(waveform)  # Expect [1, 128, T]
            else:
                features = waveform  # Raw waveform fallback

            label_index = self.class_to_idx[label]
            return features, label_index, SAMPLE_RATE

        except Exception as e:
            print(f"[ERROR] Failed loading {file_path}: {e}")
            return None

# %% [markdown]
# #DATALOADER W/ MEL FEATURES + DEBUG PRINTS

# %%
# Instantiate feature extractor
feature_extractor = WaveformFeatures(sample_rate=16000)

# Create dataset objects with mel spectrogram transform
train_dataset = GrooveDataset(split="train", transform=feature_extractor)
val_dataset   = GrooveDataset(split="validation", transform=feature_extractor)
test_dataset  = GrooveDataset(split="test", transform=feature_extractor)

# Create dataloaders
from torch.utils.data import DataLoader

BATCH_SIZE = 16
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_loader  = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# Test a sample batch
print("Testing first batch from train_loader...\n")
batch = next(iter(train_loader))

batch_features, batch_labels, batch_sample_rates = batch

print(f"Waveform batch shape: {batch_features.shape}")  # [B, 1, 128, T]
print(f"Label indices       : {batch_labels}")
print(f"Sample rates        : {batch_sample_rates}")

# Optional: print label names
idx_to_class = {v: k for k, v in train_dataset.class_to_idx.items()}
label_names = [idx_to_class[i.item()] for i in batch_labels]
print(f"Label names         : {label_names}")
# Out:
#  Loading metadata from: /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_16000hz_segmented_metadata_all_splits_withaudio_filepath_styleclass_10sec_split_rev_mini_v2.csv
#  Full metadata loaded: 1870 rows
#  Subset for 'train' split: 1464 rows
#  Available classes and mapping:
#   0: afrobeat
#   1: afrocuban
#   2: afrocuban_bembe
#   3: afrocuban_calypso
#   4: afrocuban_rhumba
#   5: blues_shuffle
#   6: country
#   7: dance_breakbeat
#   8: dance_disco
#   9: funk
#   10: funk_fast
#   11: funk_groove1
#   12: funk_groove2
#   13: funk_groove5
#   14: funk_latin
#   15: funk_purdieshuffle
#   16: funk_rock
#   17: gospel
#   18: hiphop
#   19: hiphop_groove6
#   20: jazz
#   21: jazz_fast
#   22: jazz_funk
#   23: jazz_fusion
#   24: jazz_klezmer
#   25: jazz_linear
#   26: jazz_march
#   27: jazz_mediumfast
#   28: jazz_swing
#   29: latin
#   30: latin_ando
#   31: latin_bomba
#   32: latin_brazilian
#   33: latin_brazilian-baiao
#   34: latin_brazilian-bossa
#   35: latin_brazilian-frevo
#   36: latin_brazilian-ijexa
#   37: latin_brazilian-maracatu
#   38: latin_brazilian-samba
#   39: latin_brazilian-sambareggae
#   40: latin_brazilian-songo
#   41: latin_chacarera
#   42: latin_dominican-merengue
#   43: latin_merengue
#   44: latin_reggaeton
#   45: latin_samba
#   46: latin_venezuelan-joropo
#   47: latin_venezuelan-merengue
#   48: latin_venezuelan-sangueo
#   49: middleeastern
#   50: neworleans_chacha
#   51: neworleans_funk
#   52: neworleans_secondline
#   53: neworleans_shuffle
#   54: pop
#   55: pop_groove7
#   56: pop_soft
#   57: punk
#   58: reggae
#   59: reggae_slow
#   60: rock
#   61: rock_folk
#   62: rock_groove8
#   63: rock_halftime
#   64: rock_indie
#   65: rock_prog
#   66: rock_rockabilly
#   67: rock_shuffle
#   68: soul
#   69: soul_groove10
#   70: soul_groove3
#   71: soul_groove4
#   72: soul_groove9
#   73: soul_motown
#  Preview of dataset:
#                                            file_path style_class
# 0  /content/drive/My Drive/LUMT_Thesis_Resources/...    afrobeat
# 1  /content/drive/My Drive/LUMT_Thesis_Resources/...    afrobeat
# 2  /content/drive/My Drive/LUMT_Thesis_Resources/...    afrobeat
#  Loading metadata from: /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_16000hz_segmented_metadata_all_splits_withaudio_filepath_styleclass_10sec_split_rev_mini_v2.csv
#  Full metadata loaded: 1870 rows
#  Subset for 'validation' split: 204 rows
#  Available classes and mapping:
#   0: afrobeat
#   1: afrocuban
#   2: afrocuban_bembe
#   3: afrocuban_calypso
#   4: afrocuban_rhumba
#   5: blues_shuffle
#   6: country
#   7: dance_breakbeat
#   8: dance_disco
#   9: funk
#   10: funk_fast
#   11: funk_groove1
#   12: funk_groove2
#   13: funk_groove5
#   14: funk_latin
#   15: funk_purdieshuffle
#   16: funk_rock
#   17: gospel
#   18: hiphop
#   19: hiphop_groove6
#   20: jazz
#   21: jazz_fast
#   22: jazz_funk
#   23: jazz_fusion
#   24: jazz_klezmer
#   25: jazz_linear
#   26: jazz_march
#   27: jazz_mediumfast
#   28: jazz_swing
#   29: latin
#   30: latin_ando
#   31: latin_bomba
#   32: latin_brazilian
#   33: latin_brazilian-baiao
#   34: latin_brazilian-bossa
#   35: latin_brazilian-frevo
#   36: latin_brazilian-ijexa
#   37: latin_brazilian-maracatu
#   38: latin_brazilian-samba
#   39: latin_brazilian-sambareggae
#   40: latin_brazilian-songo
#   41: latin_chacarera
#   42: latin_dominican-merengue
#   43: latin_merengue
#   44: latin_reggaeton
#   45: latin_samba
#   46: latin_venezuelan-joropo
#   47: latin_venezuelan-merengue
#   48: latin_venezuelan-sangueo
#   49: middleeastern
#   50: neworleans_chacha
#   51: neworleans_funk
#   52: neworleans_secondline
#   53: neworleans_shuffle
#   54: pop
#   55: pop_groove7
#   56: pop_soft
#   57: punk
#   58: reggae
#   59: reggae_slow
#   60: rock
#   61: rock_folk
#   62: rock_groove8
#   63: rock_halftime
#   64: rock_indie
#   65: rock_prog
#   66: rock_rockabilly
#   67: rock_shuffle
#   68: soul
#   69: soul_groove10
#   70: soul_groove3
#   71: soul_groove4
#   72: soul_groove9
#   73: soul_motown
#  Preview of dataset:
#                                            file_path style_class
# 0  /content/drive/My Drive/LUMT_Thesis_Resources/...    afrobeat
# 1  /content/drive/My Drive/LUMT_Thesis_Resources/...    afrobeat
# 2  /content/drive/My Drive/LUMT_Thesis_Resources/...    afrobeat
#  Loading metadata from: /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_16000hz_segmented_metadata_all_splits_withaudio_filepath_styleclass_10sec_split_rev_mini_v2.csv
#  Full metadata loaded: 1870 rows
#  Subset for 'test' split: 202 rows
#  Available classes and mapping:
#   0: afrobeat
#   1: afrocuban
#   2: afrocuban_bembe
#   3: afrocuban_calypso
#   4: afrocuban_rhumba
#   5: blues_shuffle
#   6: country
#   7: dance_breakbeat
#   8: dance_disco
#   9: funk
#   10: funk_fast
#   11: funk_groove1
#   12: funk_groove2
#   13: funk_groove5
#   14: funk_latin
#   15: funk_purdieshuffle
#   16: funk_rock
#   17: gospel
#   18: hiphop
#   19: hiphop_groove6
#   20: jazz
#   21: jazz_fast
#   22: jazz_funk
#   23: jazz_fusion
#   24: jazz_klezmer
#   25: jazz_linear
#   26: jazz_march
#   27: jazz_mediumfast
#   28: jazz_swing
#   29: latin
#   30: latin_ando
#   31: latin_bomba
#   32: latin_brazilian
#   33: latin_brazilian-baiao
#   34: latin_brazilian-bossa
#   35: latin_brazilian-frevo
#   36: latin_brazilian-ijexa
#   37: latin_brazilian-maracatu
#   38: latin_brazilian-samba
#   39: latin_brazilian-sambareggae
#   40: latin_brazilian-songo
#   41: latin_chacarera
#   42: latin_dominican-merengue
#   43: latin_merengue
#   44: latin_reggaeton
#   45: latin_samba
#   46: latin_venezuelan-joropo
#   47: latin_venezuelan-merengue
#   48: latin_venezuelan-sangueo
#   49: middleeastern
#   50: neworleans_chacha
#   51: neworleans_funk
#   52: neworleans_secondline
#   53: neworleans_shuffle
#   54: pop
#   55: pop_groove7
#   56: pop_soft
#   57: punk
#   58: reggae
#   59: reggae_slow
#   60: rock
#   61: rock_folk
#   62: rock_groove8
#   63: rock_halftime
#   64: rock_indie
#   65: rock_prog
#   66: rock_rockabilly
#   67: rock_shuffle
#   68: soul
#   69: soul_groove10
#   70: soul_groove3
#   71: soul_groove4
#   72: soul_groove9
#   73: soul_motown
#  Preview of dataset:
#                                            file_path style_class
# 0  /content/drive/My Drive/LUMT_Thesis_Resources/...    afrobeat
# 1  /content/drive/My Drive/LUMT_Thesis_Resources/...    afrobeat
# 2  /content/drive/My Drive/LUMT_Thesis_Resources/...    afrobeat
# Testing first batch from train_loader...
#
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer7_session1_12_018.wav | Original samples: 75294
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer1_session1_78_212.wav | Original samples: 26483
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer8_session1_26_025.wav | Original samples: 81702
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer6_session3_6_010.wav | Original samples: 87273
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer10_session1_2_056.wav | Original samples: 35720
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer10_session1_2_054.wav | Original samples: 35721
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer1_session1_78_105.wav | Original samples: 26483
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_test/drummer1_eval_session_9_005.wav | Original samples: 73143
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer5_session1_17_019.wav | Original samples: 106667
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer7_session2_45_007.wav | Original samples: 56889
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_validation/drummer8_session1_18_051.wav | Original samples: 71111
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer10_session1_1_038.wav | Original samples: 61935
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer1_session2_4_010.wav | Original samples: 48000
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer5_session1_13_141.wav | Original samples: 61936
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer1_session1_78_101.wav | Original samples: 26483
# [PADDED] Padded to 160000
# [AUDIO] /content/drive/My Drive/LUMT_Thesis_Resources/groove_2bar_audio_train/drummer1_session3_1_056.wav | Original samples: 61440
# [PADDED] Padded to 160000
# Waveform batch shape: torch.Size([16, 1, 128, 626])
# Label indices       : tensor([ 9, 21,  0, 60, 28, 28, 21, 72,  5, 60,  9, 28, 20,  3, 21, 65])
# Sample rates        : tensor([16000, 16000, 16000, 16000, 16000, 16000, 16000, 16000, 16000, 16000,
#         16000, 16000, 16000, 16000, 16000, 16000])
# Label names         : ['funk', 'jazz_fast', 'afrobeat', 'rock', 'jazz_swing', 'jazz_swing', 'jazz_fast', 'soul_groove9', 'blues_shuffle', 'rock', 'funk', 'jazz_swing', 'jazz', 'afrocuban_calypso', 'jazz_fast', 'rock_prog']

# %% [markdown]
# # DrumStyleClassifier CNN Module

# %%
import torch.nn as nn
import torch.nn.functional as F

class DrumStyleClassifier(nn.Module):
    def __init__(self, num_classes, n_mel=128):
        super(DrumStyleClassifier, self).__init__()

        # Convolutional layers
        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1)
        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.dropout = nn.Dropout(0.5)

        # Adaptive Global Average Pooling to flatten time axis dynamically
        self.global_pool = nn.AdaptiveAvgPool2d((n_mel // 8, 1))  # Reduce to [batch, channels, mel/8, 1]

        # Fully connected layers
        fc_input_dim = 64 * (n_mel // 8) * 1
        self.fc1 = nn.Linear(fc_input_dim, 512)
        self.fc2 = nn.Linear(512, num_classes)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))  # -> [B, 16, 64, T/2]
        x = self.pool(F.relu(self.conv2(x)))  # -> [B, 32, 32, T/4]
        x = self.pool(F.relu(self.conv3(x)))  # -> [B, 64, 16, T/8]

        x = self.global_pool(x)               # -> [B, 64, mel/8, 1]
        x = x.view(x.size(0), -1)             # Flatten

        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# #Consolidated Model Code

# %%
import os
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchaudio
import torchaudio.transforms as T
from torch.utils.data import Dataset, DataLoader

# === Constants ===
BASE_DIR = "/content/drive/My Drive/LUMT_Thesis_Resources/"
SAMPLE_RATE = 16_000
CLIP_LENGTH_SAMPLES = SAMPLE_RATE * 10  # 10 seconds = 160000 samples
METADATA_FILE = "groove_2bar_16000hz_segmented_metadata_all_splits_withaudio_filepath_styleclass_10sec_split_rev_mini_v2.csv"
metadata_path = os.path.join(BASE_DIR, METADATA_FILE)

# === Mel Feature Extractor ===
class WaveformFeatures(nn.Module):
    def __init__(self, sample_rate=16000, n_fft=1024, n_mels=128):
        super().__init__()
        hop_length = n_fft // 4
        self.spectrogram = T.Spectrogram(n_fft=n_fft, hop_length=hop_length, power=2.0)
        self.mel_scale = T.MelScale(n_mels=n_mels, sample_rate=sample_rate, n_stft=n_fft // 2 + 1)

    def forward(self, waveform: torch.Tensor) -> torch.Tensor:
        spec = self.spectrogram(waveform)
        mel_spec = self.mel_scale(spec)
        return mel_spec

# === Dataset Class with Mel Transform Support ===
class GrooveDataset(Dataset):
    def __init__(self, split: str, transform=None):
        assert split in ['train', 'test', 'validation'], f"Invalid split: {split}"
        self.transform = transform

        df = pd.read_csv(metadata_path)
        df = df[df['split_rev'] == split].reset_index(drop=True)
        df['file_path'] = df['file_path'].apply(lambda x: os.path.join(BASE_DIR, x))

        self.data_df = df
        self.labels = sorted(df["style_class"].unique())
        self.class_to_idx = {label: idx for idx, label in enumerate(self.labels)}
        self.idx_to_class = {idx: label for label, idx in self.class_to_idx.items()}

    def __len__(self):
        return len(self.data_df)

    def __getitem__(self, idx):
        row = self.data_df.iloc[idx]
        file_path = row["file_path"]
        label = row["style_class"]

        try:
            waveform, sr = torchaudio.load(file_path)
            if sr != SAMPLE_RATE:
                resampler = T.Resample(orig_freq=sr, new_freq=SAMPLE_RATE)
                waveform = resampler(waveform)

            if waveform.shape[0] > 1:
                waveform = waveform.mean(dim=0, keepdim=True)

            num_samples = waveform.size(1)
            if num_samples < CLIP_LENGTH_SAMPLES:
                waveform = F.pad(waveform, (0, CLIP_LENGTH_SAMPLES - num_samples))
            else:
                waveform = waveform[:, :CLIP_LENGTH_SAMPLES]

            if self.transform:
                features = self.transform(waveform)
            else:
                features = waveform

            label_index = self.class_to_idx[label]
            return features, label_index, SAMPLE_RATE

        except Exception as e:
            print(f"[ERROR] Failed loading {file_path}: {e}")
            return None

# === CNN Classifier with Adaptive Pooling ===
class DrumStyleClassifier(nn.Module):
    def __init__(self, num_classes, n_mel=128):
        super().__init__()

        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.dropout = nn.Dropout(0.5)

        # Reduce time dimension to 1; keep mel dim compressed to 16
        self.global_pool = nn.AdaptiveAvgPool2d((n_mel // 8, 1))  # → (16, 1)

        self.fc1 = nn.Linear(64 * (n_mel // 8) * 1, 512)
        self.fc2 = nn.Linear(512, num_classes)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))  # [B, 16, 64, T/2]
        x = self.pool(F.relu(self.conv2(x)))  # [B, 32, 32, T/4]
        x = self.pool(F.relu(self.conv3(x)))  # [B, 64, 16, T/8]
        x = self.global_pool(x)               # → [B, 64, 16, 1]
        x = x.view(x.size(0), -1)             # Flatten to [B, 1024]
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# #Dataloaders
#
# run after consolidated model code

# %%
# Instantiate feature extractor
feature_extractor = WaveformFeatures(sample_rate=16000)

# Create datasets w/ transform
train_dataset = GrooveDataset(split="train", transform=feature_extractor)
val_dataset   = GrooveDataset(split="validation", transform=feature_extractor)
test_dataset  = GrooveDataset(split="test", transform=feature_extractor)

# Create DataLoaders
BATCH_SIZE = 16
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_loader  = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# Optional: inspect 1 batch
batch = next(iter(train_loader))
features, labels, sample_rates = batch
print(f"Batch shape: {features.shape}, Labels: {labels}")
# Out:
# Batch shape: torch.Size([16, 1, 128, 626]), Labels: tensor([68, 21, 42, 25, 60, 60, 29, 41, 25, 20, 45, 20, 33, 60, 29, 33])

# %% [markdown]
# #Device Setup for Training

# %%
# === Device configuration ===
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f" Using device: {device}")
# Out:
#  Using device: cuda

# %% [markdown]
# #Instantiate the model

# %%
model = DrumStyleClassifier(num_classes=len(train_dataset.class_to_idx))
model = model.to(device)

# %% [markdown]
# #Training setup

# %%
import os
import csv
import time
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from tqdm import tqdm

# === SETTINGS ===
CHECKPOINTS_DIR = "checkpoints"
LOG_CSV = "gmd_cnn_p4_log.csv"  # Updated log file name
os.makedirs(CHECKPOINTS_DIR, exist_ok=True)

# === One epoch of train or val ===
def run_epoch(model, loader, criterion, optimizer, device, is_training):
    model.train() if is_training else model.eval()

    total_loss, correct, total = 0, 0, 0
    all_losses = []

    for features, labels, _ in tqdm(loader, desc="Train" if is_training else "Val", leave=False):
        features, labels = features.to(device), labels.to(device)
        outputs = model(features)
        loss = criterion(outputs, labels)

        if is_training:
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        total_loss += loss.item()
        all_losses.append(loss.item())

        # Accuracy
        preds = outputs.argmax(dim=1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

    avg_loss = total_loss / len(loader)
    accuracy = correct / total
    return avg_loss, accuracy, all_losses

# === Save current model state ===
def save_checkpoint(model, optimizer, epoch, path):
    torch.save({
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
    }, path)

# === Train full model with early stopping ===
def train_model(model, train_loader, val_loader, criterion, optimizer, device,
                max_epochs=50, patience=10):
    """
    Trains model and tracks:
      - train/val loss per batch & epoch
      - val accuracy per epoch
      - early stopping based on val accuracy
      - saves best model to disk
      - logs all epochs to CSV
    """

    best_val_acc = 0.0
    patience_counter = 0
    all_train_losses, all_val_losses = [], []
    all_val_accuracies = []

    # === Initialize CSV ===
    with open(LOG_CSV, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(["epoch", "train_loss", "val_loss", "val_accuracy"])

    for epoch in range(1, max_epochs + 1):
        print(f"Epoch {epoch}/{max_epochs}")

        # === Train / Validate
        train_loss, train_acc, train_losses = run_epoch(model, train_loader, criterion, optimizer, device, True)
        val_loss, val_acc, val_losses = run_epoch(model, val_loader, criterion, optimizer, device, False)

        # === Print summary for this epoch
        print(f"Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f}")

        all_train_losses.append(train_losses)
        all_val_losses.append(val_losses)
        all_val_accuracies.append(val_acc)

        # === Append to CSV
        with open(LOG_CSV, 'a', newline='') as f:
            writer = csv.writer(f)
            writer.writerow([epoch, train_loss, val_loss, val_acc])

        # === Early Stopping
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            patience_counter = 0
            best_model_path = f"{CHECKPOINTS_DIR}/best_model_epoch_{epoch}.pth"
            save_checkpoint(model, optimizer, epoch, best_model_path)
            print(f" New best model saved at: {best_model_path}")
        else:
            patience_counter += 1
            print(f"Patience: {patience_counter}/{patience}")
            if patience_counter >= patience:
                print("Early stopping triggered.")
                break

    return all_train_losses, all_val_losses, all_val_accuracies

# %% [markdown]
# #Training Execution

# %%
# === Instantiate model and training components ===
model = DrumStyleClassifier(num_classes=len(train_dataset.class_to_idx)).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)

# === Run training with early stopping & return model path
train_losses, val_losses, val_accuracies, best_model_path = train_model(
    model,
    train_loader,
    val_loader,
    criterion,
    optimizer,
    device,
    max_epochs=50,
    patience=10
)

# === Plot Loss + Validation Accuracy
epochs = list(range(1, len(val_accuracies) + 1))
train_loss_avg = [np.mean(epoch) for epoch in train_losses]
val_loss_avg = [np.mean(epoch) for epoch in val_losses]

plt.figure(figsize=(12, 6))
plt.plot(epochs, train_loss_avg, label="Train Loss", marker='o', color='blue')
plt.plot(epochs, val_loss_avg, label="Validation Loss", marker='o', color='red')
plt.plot(epochs, val_accuracies, label="Validation Accuracy", marker='s', color='green')

plt.title("Training Progress: Loss & Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Loss / Accuracy")
plt.grid(True)
plt.legend()
plt.savefig("loss_accuracy_plot.png", dpi=300, bbox_inches="tight")
plt.show()

# === Final training output
print("Training complete.")
print(f"Best model saved to: {best_model_path}")
print("Log CSV saved to: gmd_cnn_p4_log.csv")
print("  Plot saved to: loss_accuracy_plot.png")
# Out:
# Epoch 1/50
# Train Loss: 3.9112 | Val Loss: 3.7371 | Val Acc: 0.1716
#  New best model saved at: checkpoints/best_model_epoch_1.pth
# Epoch 2/50
# Train Loss: 3.6201 | Val Loss: 3.5633 | Val Acc: 0.1716
# Patience: 1/10
# Epoch 3/50
# Train Loss: 3.4265 | Val Loss: 3.4388 | Val Acc: 0.2010
#  New best model saved at: checkpoints/best_model_epoch_3.pth
# Epoch 4/50
# Train Loss: 3.3208 | Val Loss: 3.3668 | Val Acc: 0.1961
# Patience: 1/10
# Epoch 5/50
# Train Loss: 3.2425 | Val Loss: 3.2898 | Val Acc: 0.2157
#  New best model saved at: checkpoints/best_model_epoch_5.pth
# Epoch 6/50
# Train Loss: 3.1672 | Val Loss: 3.2310 | Val Acc: 0.2108
# Patience: 1/10
# Epoch 7/50
# Train Loss: 3.1073 | Val Loss: 3.2084 | Val Acc: 0.2010
# Patience: 2/10
# Epoch 8/50
# Train Loss: 3.0727 | Val Loss: 3.2026 | Val Acc: 0.1912
# Patience: 3/10
# Epoch 9/50
# Train Loss: 3.0035 | Val Loss: 3.1215 | Val Acc: 0.2059
# Patience: 4/10
# Epoch 10/50
# Train Loss: 2.9638 | Val Loss: 3.0676 | Val Acc: 0.2402
#  New best model saved at: checkpoints/best_model_epoch_10.pth
# Epoch 11/50
# Train Loss: 2.9202 | Val Loss: 3.0372 | Val Acc: 0.2549
#  New best model saved at: checkpoints/best_model_epoch_11.pth
# Epoch 12/50
# Train Loss: 2.9011 | Val Loss: 3.0307 | Val Acc: 0.2108
# Patience: 1/10
# Epoch 13/50
# Train Loss: 2.8427 | Val Loss: 2.9752 | Val Acc: 0.2745
#  New best model saved at: checkpoints/best_model_epoch_13.pth
# Epoch 14/50
# Train Loss: 2.8206 | Val Loss: 2.9500 | Val Acc: 0.2696
# Patience: 1/10
# Epoch 15/50
# Train Loss: 2.7737 | Val Loss: 2.9485 | Val Acc: 0.2549
# Patience: 2/10
# Epoch 16/50
# Train Loss: 2.7401 | Val Loss: 2.8982 | Val Acc: 0.2745
# Patience: 3/10
# Epoch 17/50
# Train Loss: 2.7282 | Val Loss: 2.8583 | Val Acc: 0.2843
#  New best model saved at: checkpoints/best_model_epoch_17.pth
# Epoch 18/50
# Train Loss: 2.6916 | Val Loss: 2.8547 | Val Acc: 0.3137
#  New best model saved at: checkpoints/best_model_epoch_18.pth
# Epoch 19/50
# Train Loss: 2.7001 | Val Loss: 2.8021 | Val Acc: 0.2843
# Patience: 1/10
# Epoch 20/50
# Train Loss: 2.6427 | Val Loss: 2.8193 | Val Acc: 0.3039
# Patience: 2/10
# Epoch 21/50
# Train Loss: 2.6234 | Val Loss: 2.7797 | Val Acc: 0.3088
# Patience: 3/10
# Epoch 22/50
# Train Loss: 2.5898 | Val Loss: 2.7234 | Val Acc: 0.3382
#  New best model saved at: checkpoints/best_model_epoch_22.pth
# Epoch 23/50
# Train Loss: 2.5607 | Val Loss: 2.7299 | Val Acc: 0.3137
# Patience: 1/10
# Epoch 24/50
# Train Loss: 2.5611 | Val Loss: 2.7097 | Val Acc: 0.3382
# Patience: 2/10
# Epoch 25/50
# Train Loss: 2.5156 | Val Loss: 2.7009 | Val Acc: 0.3088
# Patience: 3/10
# Epoch 26/50
# Train Loss: 2.4966 | Val Loss: 2.6868 | Val Acc: 0.3284
# Patience: 4/10
# Epoch 27/50
# Train Loss: 2.4980 | Val Loss: 2.6626 | Val Acc: 0.3382
# Patience: 5/10
# Epoch 28/50
# Train Loss: 2.4723 | Val Loss: 2.6443 | Val Acc: 0.3529
#  New best model saved at: checkpoints/best_model_epoch_28.pth
# Epoch 29/50
# Train Loss: 2.4047 | Val Loss: 2.6104 | Val Acc: 0.3480
# Patience: 1/10
# Epoch 30/50
# Train Loss: 2.4194 | Val Loss: 2.5955 | Val Acc: 0.3578
#  New best model saved at: checkpoints/best_model_epoch_30.pth
# Epoch 31/50
# Train Loss: 2.3933 | Val Loss: 2.5916 | Val Acc: 0.3578
# Patience: 1/10
# Epoch 32/50
# Train Loss: 2.3578 | Val Loss: 2.5957 | Val Acc: 0.3333
# Patience: 2/10
# Epoch 33/50
# Train Loss: 2.3466 | Val Loss: 2.5591 | Val Acc: 0.3431
# Patience: 3/10
# Epoch 34/50
# Train Loss: 2.2970 | Val Loss: 2.5466 | Val Acc: 0.3676
#  New best model saved at: checkpoints/best_model_epoch_34.pth
# Epoch 35/50
# Train Loss: 2.3130 | Val Loss: 2.5601 | Val Acc: 0.3382
# Patience: 1/10
# Epoch 36/50
# Train Loss: 2.2685 | Val Loss: 2.5183 | Val Acc: 0.3725
#  New best model saved at: checkpoints/best_model_epoch_36.pth
# Epoch 37/50
# Train Loss: 2.2597 | Val Loss: 2.5170 | Val Acc: 0.3676
# Patience: 1/10
# Epoch 38/50
# Train Loss: 2.2227 | Val Loss: 2.4713 | Val Acc: 0.3725
# Patience: 2/10
# Epoch 39/50
# Train Loss: 2.2574 | Val Loss: 2.4745 | Val Acc: 0.3480
# Patience: 3/10
# Epoch 40/50
# Train Loss: 2.2046 | Val Loss: 2.4493 | Val Acc: 0.4118
#  New best model saved at: checkpoints/best_model_epoch_40.pth
# Epoch 41/50
# Train Loss: 2.2117 | Val Loss: 2.4562 | Val Acc: 0.3578
# Patience: 1/10
# Epoch 42/50
# Train Loss: 2.1736 | Val Loss: 2.4229 | Val Acc: 0.3775
# Patience: 2/10
# Epoch 43/50
# Train Loss: 2.1756 | Val Loss: 2.4400 | Val Acc: 0.3725
# Patience: 3/10
# Epoch 44/50
# Train Loss: 2.1353 | Val Loss: 2.3860 | Val Acc: 0.3775
# Patience: 4/10
# Epoch 45/50
# Train Loss: 2.1045 | Val Loss: 2.3919 | Val Acc: 0.3824
# Patience: 5/10
# Epoch 46/50
# Train Loss: 2.1124 | Val Loss: 2.3970 | Val Acc: 0.3873
# Patience: 6/10
# Epoch 47/50
# Train Loss: 2.0720 | Val Loss: 2.3857 | Val Acc: 0.4020
# Patience: 7/10
# Epoch 48/50
# Train Loss: 2.0689 | Val Loss: 2.3809 | Val Acc: 0.3873
# Patience: 8/10
# Epoch 49/50
# Train Loss: 2.0761 | Val Loss: 2.3927 | Val Acc: 0.3873
# Patience: 9/10
# Epoch 50/50
# Train Loss: 2.0330 | Val Loss: 2.3540 | Val Acc: 0.4118
# Patience: 10/10
# Early stopping triggered.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-b9877d592f40> in <cell line: 0>()
#       5
#       6 # === Run training with early stopping & return model path
# ----> 7 train_losses, val_losses, val_accuracies, best_model_path = train_model(
#       8     model,
#       9     train_loader,
#
# ValueError: not enough values to unpack (expected 4, got 3)

# %% [markdown]
# ^ above results show best at epoch 40, downloaded the top 3 epochs to save to google drive. (40,36,34)
#
# Error was thrown when trying to visualize training not in the training itself, for future iterations, edit this cell to exclude training visualization and just execute the training.

# %% [markdown]
# #Prevent timeout script

# %%
# %%javascript
# function preventIdle() {
#     setInterval(() => {
#         console.log("Preventing Colab Disconnect...");
#         document.querySelector("colab-toolbar-button")?.click();
#     }, 60000); // Clicks every 60 seconds
# }
# preventIdle();

# %% [markdown]
# #Visualize the training

# %%
import pandas as pd
import matplotlib.pyplot as plt

# === Path to training log in Colab runtime
log_path = "gmd_cnn_p4_log.csv"

# === Load training log
log_df = pd.read_csv(log_path)

# === Extract columns
epochs = log_df["epoch"]
train_loss = log_df["train_loss"]
val_loss = log_df["val_loss"]
val_acc = log_df["val_accuracy"]

# === Plot loss and accuracy
plt.figure(figsize=(14, 6))

# Loss subplot
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, label="Train Loss", color='blue', marker='o')
plt.plot(epochs, val_loss, label="Validation Loss", color='red', marker='o')
plt.title("Training vs Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid(True)
plt.legend()

# Accuracy subplot
plt.subplot(1, 2, 2)
plt.plot(epochs, val_acc, label="Validation Accuracy", color='green', marker='s')
plt.title("Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.grid(True)
plt.legend()

# Save & show plot
plt.tight_layout()
plt.savefig("loss_accuracy_plot.png", dpi=300, bbox_inches="tight")
plt.show()

print("Training visualization complete.")
print("Plot saved as: loss_accuracy_plot.png")
# Out:
# Training visualization complete.
# Plot saved as: loss_accuracy_plot.png

# %% [markdown]
# ^^ Above seems like the potential for overfitting or indeed actual overfitting is started.

# %% [markdown]
# #Reload the Model and Load Weights

# %%
# === Rebuild model and load best weights ===
model = DrumStyleClassifier(num_classes=len(train_dataset.class_to_idx)).to(device)

# Load best checkpoint
best_model_path = "checkpoints/best_model_epoch_40.pth"
checkpoint = torch.load(best_model_path, map_location=device)
model.load_state_dict(checkpoint["model_state_dict"])
model.eval()

print(f"Model loaded from: {best_model_path}")
# Out:
# Model loaded from: checkpoints/best_model_epoch_40.pth

# %% [markdown]
# #note
#
# ran inference on epoch 40, even though train/val loss continue to decrease after epoch 40 but validation accuracy plateaued:
#
# Epoch 40/50
# Train Loss: 2.2046 | Val Loss: 2.4493 | Val Acc: 0.4118
# New best model saved at: checkpoints/best_model_epoch_40.pth
#
# Epoch 50/50
# Train Loss: 2.0330 | Val Loss: 2.3540 | Val Acc: 0.4118
# Patience: 10/10
# Early stopping triggered.

# %% [markdown]
# #Reload Test set

# %%
# === Recreate test set loader ===
test_dataset = GrooveDataset(split="test", transform=feature_extractor)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

print(f"Test dataset size: {len(test_dataset)}")
# Out:
# Test dataset size: 202

# %% [markdown]
# #Inference , Confusion Matrix, Report
#
# confusion matrix plots correctly

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# === Run inference
all_preds = []
all_labels = []

with torch.no_grad():
    for features, labels, _ in test_loader:
        features = features.to(device)
        outputs = model(features)
        preds = outputs.argmax(dim=1).cpu().numpy()
        all_preds.extend(preds)
        all_labels.extend(labels.numpy())

# === Decode labels
idx_to_class = test_dataset.idx_to_class
class_names = [idx_to_class[i] for i in sorted(idx_to_class)]

# === Confusion matrix
cm = confusion_matrix(all_labels, all_preds)
plt.figure(figsize=(20, 16))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix - Test Set")
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.savefig("confusion_matrix_test.png", dpi=500)
plt.show()

# === Classification report
report = classification_report(all_labels, all_preds, target_names=class_names)
print("Classification Report:\n")
print(report)
# Out:
# Classification Report:
#
#                              precision    recall  f1-score   support
#
#                    afrobeat       0.00      0.00      0.00         3
#                   afrocuban       0.20      0.33      0.25         3
#             afrocuban_bembe       0.00      0.00      0.00         1
#           afrocuban_calypso       0.50      0.67      0.57         3
#            afrocuban_rhumba       0.00      0.00      0.00         1
#               blues_shuffle       0.00      0.00      0.00         2
#                     country       0.00      0.00      0.00         2
#             dance_breakbeat       0.00      0.00      0.00         2
#                 dance_disco       0.00      0.00      0.00         3
#                        funk       0.24      0.31      0.27        13
#                   funk_fast       0.00      0.00      0.00         1
#                funk_groove1       0.00      0.00      0.00         1
#                funk_groove2       0.00      0.00      0.00         1
#                funk_groove5       0.00      0.00      0.00         1
#                  funk_latin       0.00      0.00      0.00         1
#          funk_purdieshuffle       0.00      0.00      0.00         2
#                   funk_rock       0.00      0.00      0.00         1
#                      gospel       0.00      0.00      0.00         1
#                      hiphop       0.43      0.43      0.43         7
#              hiphop_groove6       0.00      0.00      0.00         1
#                        jazz       0.44      0.40      0.42        10
#                   jazz_fast       0.26      1.00      0.42         5
#                   jazz_funk       0.00      0.00      0.00         2
#                 jazz_fusion       0.00      0.00      0.00         1
#                jazz_klezmer       0.00      0.00      0.00         1
#                 jazz_linear       0.00      0.00      0.00         4
#                  jazz_march       1.00      0.67      0.80         3
#             jazz_mediumfast       0.00      0.00      0.00         3
#                  jazz_swing       0.67      0.57      0.62         7
#                       latin       0.67      1.00      0.80         2
#                  latin_ando       0.00      0.00      0.00         1
#                 latin_bomba       0.00      0.00      0.00         1
#             latin_brazilian       0.00      0.00      0.00         2
#       latin_brazilian-baiao       0.00      0.00      0.00         2
#       latin_brazilian-bossa       0.12      0.17      0.14         6
#       latin_brazilian-frevo       1.00      1.00      1.00         1
#       latin_brazilian-ijexa       0.00      0.00      0.00         1
#    latin_brazilian-maracatu       0.50      0.50      0.50         2
#       latin_brazilian-samba       0.18      0.50      0.27         4
# latin_brazilian-sambareggae       1.00      1.00      1.00         2
#       latin_brazilian-songo       0.00      0.00      0.00         3
#             latin_chacarera       0.67      1.00      0.80         2
#    latin_dominican-merengue       0.50      0.50      0.50         2
#              latin_merengue       0.00      0.00      0.00         1
#             latin_reggaeton       0.00      0.00      0.00         1
#                 latin_samba       0.00      0.00      0.00         2
#     latin_venezuelan-joropo       0.00      0.00      0.00         1
#   latin_venezuelan-merengue       1.00      1.00      1.00         1
#    latin_venezuelan-sangueo       0.00      0.00      0.00         1
#               middleeastern       0.00      0.00      0.00         1
#           neworleans_chacha       0.00      0.00      0.00         1
#             neworleans_funk       0.00      0.00      0.00         3
#       neworleans_secondline       0.00      0.00      0.00         2
#          neworleans_shuffle       0.00      0.00      0.00         1
#                         pop       0.00      0.00      0.00         2
#                 pop_groove7       0.00      0.00      0.00         1
#                    pop_soft       0.00      0.00      0.00         1
#                        punk       0.50      0.33      0.40         3
#                      reggae       0.50      0.33      0.40         3
#                 reggae_slow       0.00      0.00      0.00         1
#                        rock       0.30      0.74      0.42        34
#                   rock_folk       0.00      0.00      0.00         1
#                rock_groove8       0.00      0.00      0.00         1
#               rock_halftime       0.00      0.00      0.00         3
#                  rock_indie       0.00      0.00      0.00         1
#                   rock_prog       0.00      0.00      0.00         4
#             rock_rockabilly       0.00      0.00      0.00         3
#                rock_shuffle       0.00      0.00      0.00         3
#                        soul       0.00      0.00      0.00         3
#               soul_groove10       0.00      0.00      0.00         1
#                soul_groove3       0.00      0.00      0.00         1
#                soul_groove4       0.00      0.00      0.00         1
#                soul_groove9       0.00      0.00      0.00         1
#                 soul_motown       1.00      0.50      0.67         2
#
#                    accuracy                           0.33       202
#                   macro avg       0.16      0.17      0.16       202
#                weighted avg       0.23      0.33      0.25       202
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# #Updated Inference and Metrics
#
# additional metrics per class
# geting weird sizing errors on the class labels in the confusion matrix

# %%
from sklearn.metrics import (
    confusion_matrix, classification_report, roc_auc_score, average_precision_score,
    precision_score, recall_score, f1_score
)
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import torch

# === Inference and metric aggregation
all_preds = []
all_labels = []
all_probs = []

model.eval()
with torch.no_grad():
    for features, labels, _ in test_loader:
        features = features.to(device)
        outputs = model(features)

        probs = torch.softmax(outputs, dim=1).cpu().numpy()
        preds = np.argmax(probs, axis=1)

        all_probs.extend(probs)
        all_preds.extend(preds)
        all_labels.extend(labels.numpy())

all_probs = np.array(all_probs)
all_preds = np.array(all_preds)
all_labels = np.array(all_labels)

# === Setup
idx_to_class = test_dataset.idx_to_class
class_names = [idx_to_class[i] for i in sorted(idx_to_class)]
num_classes = len(class_names)

# === Confusion Matrix
cm = confusion_matrix(all_labels, all_preds)
plt.figure(figsize=(20, 16))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix - Test Set")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("confusion_matrix_test.png", dpi=500)
plt.show()

# === Standard Classification Report
report_str = classification_report(all_labels, all_preds, target_names=class_names, digits=2)
print("Classification Report:\n")
print(report_str)

# === Overall Accuracy
accuracy = np.mean(all_preds == all_labels) * 100
print(f"\nOverall Accuracy: {accuracy:.2f}%")

# === Mean Average Precision (mAP) and AUC (One-vs-Rest)
binary_labels = np.eye(num_classes)[all_labels]  # one-hot encoding
mAP = average_precision_score(binary_labels, all_probs, average="macro")
AUC = roc_auc_score(binary_labels, all_probs, average="macro")

print(f"Mean Average Precision (mAP): {mAP:.4f}")
print(f"Area Under Curve (AUC): {AUC:.4f}")

# === Per-Class Detailed Metrics
print("\nPer-class Metrics:\n")
for i, class_name in enumerate(class_names):
    y_true_binary = binary_labels[:, i]
    y_pred_binary = all_probs[:, i]

    precision = precision_score(all_labels == i, all_preds == i, zero_division=0)
    recall = recall_score(all_labels == i, all_preds == i, zero_division=0)
    f1 = f1_score(all_labels == i, all_preds == i, zero_division=0)
    ap = average_precision_score(y_true_binary, y_pred_binary)
    auc = roc_auc_score(y_true_binary, y_pred_binary)
    support = np.sum(all_labels == i)

    print(f"{class_name}:")
    print(f"  Precision: {precision * 100:.2f}%")
    print(f"  Recall: {recall * 100:.2f}%")
    print(f"  F1-score: {f1 * 100:.2f}%")
    print(f"  mAP: {ap:.4f}")
    print(f"  AUC: {auc:.4f}")
    print(f"  Support: {support}")
    print("")
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Classification Report:
#
#                              precision    recall  f1-score   support
#
#                    afrobeat       0.00      0.00      0.00         3
#                   afrocuban       0.20      0.33      0.25         3
#             afrocuban_bembe       0.00      0.00      0.00         1
#           afrocuban_calypso       0.50      0.67      0.57         3
#            afrocuban_rhumba       0.00      0.00      0.00         1
#               blues_shuffle       0.00      0.00      0.00         2
#                     country       0.00      0.00      0.00         2
#             dance_breakbeat       0.00      0.00      0.00         2
#                 dance_disco       0.00      0.00      0.00         3
#                        funk       0.24      0.31      0.27        13
#                   funk_fast       0.00      0.00      0.00         1
#                funk_groove1       0.00      0.00      0.00         1
#                funk_groove2       0.00      0.00      0.00         1
#                funk_groove5       0.00      0.00      0.00         1
#                  funk_latin       0.00      0.00      0.00         1
#          funk_purdieshuffle       0.00      0.00      0.00         2
#                   funk_rock       0.00      0.00      0.00         1
#                      gospel       0.00      0.00      0.00         1
#                      hiphop       0.43      0.43      0.43         7
#              hiphop_groove6       0.00      0.00      0.00         1
#                        jazz       0.44      0.40      0.42        10
#                   jazz_fast       0.26      1.00      0.42         5
#                   jazz_funk       0.00      0.00      0.00         2
#                 jazz_fusion       0.00      0.00      0.00         1
#                jazz_klezmer       0.00      0.00      0.00         1
#                 jazz_linear       0.00      0.00      0.00         4
#                  jazz_march       1.00      0.67      0.80         3
#             jazz_mediumfast       0.00      0.00      0.00         3
#                  jazz_swing       0.67      0.57      0.62         7
#                       latin       0.67      1.00      0.80         2
#                  latin_ando       0.00      0.00      0.00         1
#                 latin_bomba       0.00      0.00      0.00         1
#             latin_brazilian       0.00      0.00      0.00         2
#       latin_brazilian-baiao       0.00      0.00      0.00         2
#       latin_brazilian-bossa       0.12      0.17      0.14         6
#       latin_brazilian-frevo       1.00      1.00      1.00         1
#       latin_brazilian-ijexa       0.00      0.00      0.00         1
#    latin_brazilian-maracatu       0.50      0.50      0.50         2
#       latin_brazilian-samba       0.18      0.50      0.27         4
# latin_brazilian-sambareggae       1.00      1.00      1.00         2
#       latin_brazilian-songo       0.00      0.00      0.00         3
#             latin_chacarera       0.67      1.00      0.80         2
#    latin_dominican-merengue       0.50      0.50      0.50         2
#              latin_merengue       0.00      0.00      0.00         1
#             latin_reggaeton       0.00      0.00      0.00         1
#                 latin_samba       0.00      0.00      0.00         2
#     latin_venezuelan-joropo       0.00      0.00      0.00         1
#   latin_venezuelan-merengue       1.00      1.00      1.00         1
#    latin_venezuelan-sangueo       0.00      0.00      0.00         1
#               middleeastern       0.00      0.00      0.00         1
#           neworleans_chacha       0.00      0.00      0.00         1
#             neworleans_funk       0.00      0.00      0.00         3
#       neworleans_secondline       0.00      0.00      0.00         2
#          neworleans_shuffle       0.00      0.00      0.00         1
#                         pop       0.00      0.00      0.00         2
#                 pop_groove7       0.00      0.00      0.00         1
#                    pop_soft       0.00      0.00      0.00         1
#                        punk       0.50      0.33      0.40         3
#                      reggae       0.50      0.33      0.40         3
#                 reggae_slow       0.00      0.00      0.00         1
#                        rock       0.30      0.74      0.42        34
#                   rock_folk       0.00      0.00      0.00         1
#                rock_groove8       0.00      0.00      0.00         1
#               rock_halftime       0.00      0.00      0.00         3
#                  rock_indie       0.00      0.00      0.00         1
#                   rock_prog       0.00      0.00      0.00         4
#             rock_rockabilly       0.00      0.00      0.00         3
#                rock_shuffle       0.00      0.00      0.00         3
#                        soul       0.00      0.00      0.00         3
#               soul_groove10       0.00      0.00      0.00         1
#                soul_groove3       0.00      0.00      0.00         1
#                soul_groove4       0.00      0.00      0.00         1
#                soul_groove9       0.00      0.00      0.00         1
#                 soul_motown       1.00      0.50      0.67         2
#
#                    accuracy                           0.33       202
#                   macro avg       0.16      0.17      0.16       202
#                weighted avg       0.23      0.33      0.25       202
#
#
# Overall Accuracy: 32.67%
# Mean Average Precision (mAP): 0.4156
# Area Under Curve (AUC): 0.9051
#
# Per-class Metrics:
#
# afrobeat:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.0785
#   AUC: 0.8794
#   Support: 3
#
# afrocuban:
#   Precision: 20.00%
#   Recall: 33.33%
#   F1-score: 25.00%
#   mAP: 0.1322
#   AUC: 0.8258
#   Support: 3
#
# afrocuban_bembe:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.5000
#   AUC: 0.9950
#   Support: 1
#
# afrocuban_calypso:
#   Precision: 50.00%
#   Recall: 66.67%
#   F1-score: 57.14%
#   mAP: 0.7037
#   AUC: 0.9598
#   Support: 3
#
# afrocuban_rhumba:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.3333
#   AUC: 0.9900
#   Support: 1
#
# blues_shuffle:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.1764
#   AUC: 0.7425
#   Support: 2
#
# country:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.5278
#   AUC: 0.9150
#   Support: 2
#
# dance_breakbeat:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.1053
#   AUC: 0.9425
#   Support: 2
#
# dance_disco:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.3572
#   AUC: 0.7772
#   Support: 3
#
# funk:
#   Precision: 23.53%
#   Recall: 30.77%
#   F1-score: 26.67%
#   mAP: 0.2762
#   AUC: 0.7981
#   Support: 13
#
# funk_fast:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.0333
#   AUC: 0.8557
#   Support: 1
#
# funk_groove1:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.0167
#   AUC: 0.7065
#   Support: 1
#
# funk_groove2:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.0556
#   AUC: 0.9154
#   Support: 1
#
# funk_groove5:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 1.0000
#   AUC: 1.0000
#   Support: 1
#
# funk_latin:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.5000
#   AUC: 0.9950
#   Support: 1
#
# funk_purdieshuffle:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.0282
#   AUC: 0.7450
#   Support: 2
#
# funk_rock:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.1000
#   AUC: 0.9552
#   Support: 1
#
# gospel:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.1000
#   AUC: 0.9552
#   Support: 1
#
# hiphop:
#   Precision: 42.86%
#   Recall: 42.86%
#   F1-score: 42.86%
#   mAP: 0.4610
#   AUC: 0.9084
#   Support: 7
#
# hiphop_groove6:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.2000
#   AUC: 0.9801
#   Support: 1
#
# jazz:
#   Precision: 44.44%
#   Recall: 40.00%
#   F1-score: 42.11%
#   mAP: 0.5439
#   AUC: 0.9354
#   Support: 10
#
# jazz_fast:
#   Precision: 26.32%
#   Recall: 100.00%
#   F1-score: 41.67%
#   mAP: 0.3846
#   AUC: 0.9797
#   Support: 5
#
# jazz_funk:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.6667
#   AUC: 0.9900
#   Support: 2
#
# jazz_fusion:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.1111
#   AUC: 0.9602
#   Support: 1
#
# jazz_klezmer:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 1.0000
#   AUC: 1.0000
#   Support: 1
#
# jazz_linear:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.4389
#   AUC: 0.9306
#   Support: 4
#
# jazz_march:
#   Precision: 100.00%
#   Recall: 66.67%
#   F1-score: 80.00%
#   mAP: 0.9167
#   AUC: 0.9983
#   Support: 3
#
# jazz_mediumfast:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.1270
#   AUC: 0.9179
#   Support: 3
#
# jazz_swing:
#   Precision: 66.67%
#   Recall: 57.14%
#   F1-score: 61.54%
#   mAP: 0.6239
#   AUC: 0.9077
#   Support: 7
#
# latin:
#   Precision: 66.67%
#   Recall: 100.00%
#   F1-score: 80.00%
#   mAP: 1.0000
#   AUC: 1.0000
#   Support: 2
#
# latin_ando:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.0667
#   AUC: 0.9303
#   Support: 1
#
# latin_bomba:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.5000
#   AUC: 0.9950
#   Support: 1
#
# latin_brazilian:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.1923
#   AUC: 0.9025
#   Support: 2
#
# latin_brazilian-baiao:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.0346
#   AUC: 0.7950
#   Support: 2
#
# latin_brazilian-bossa:
#   Precision: 12.50%
#   Recall: 16.67%
#   F1-score: 14.29%
#   mAP: 0.2071
#   AUC: 0.9337
#   Support: 6
#
# latin_brazilian-frevo:
#   Precision: 100.00%
#   Recall: 100.00%
#   F1-score: 100.00%
#   mAP: 1.0000
#   AUC: 1.0000
#   Support: 1
#
# latin_brazilian-ijexa:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 1.0000
#   AUC: 1.0000
#   Support: 1
#
# latin_brazilian-maracatu:
#   Precision: 50.00%
#   Recall: 50.00%
#   F1-score: 50.00%
#   mAP: 0.6250
#   AUC: 0.9850
#   Support: 2
#
# latin_brazilian-samba:
#   Precision: 18.18%
#   Recall: 50.00%
#   F1-score: 26.67%
#   mAP: 0.5250
#   AUC: 0.9722
#   Support: 4
#
# latin_brazilian-sambareggae:
#   Precision: 100.00%
#   Recall: 100.00%
#   F1-score: 100.00%
#   mAP: 1.0000
#   AUC: 1.0000
#   Support: 2
#
# latin_brazilian-songo:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.1847
#   AUC: 0.9548
#   Support: 3
#
# latin_chacarera:
#   Precision: 66.67%
#   Recall: 100.00%
#   F1-score: 80.00%
#   mAP: 0.8333
#   AUC: 0.9975
#   Support: 2
#
# latin_dominican-merengue:
#   Precision: 50.00%
#   Recall: 50.00%
#   F1-score: 50.00%
#   mAP: 0.8333
#   AUC: 0.9975
#   Support: 2
#
# latin_merengue:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 1.0000
#   AUC: 1.0000
#   Support: 1
#
# latin_reggaeton:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 1.0000
#   AUC: 1.0000
#   Support: 1
#
# latin_samba:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.0509
#   AUC: 0.8550
#   Support: 2
#
# latin_venezuelan-joropo:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.1250
#   AUC: 0.9652
#   Support: 1
#
# latin_venezuelan-merengue:
#   Precision: 100.00%
#   Recall: 100.00%
#   F1-score: 100.00%
#   mAP: 1.0000
#   AUC: 1.0000
#   Support: 1
#
# latin_venezuelan-sangueo:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.2000
#   AUC: 0.9801
#   Support: 1
#
# middleeastern:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.0385
#   AUC: 0.8756
#   Support: 1
#
# neworleans_chacha:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.1250
#   AUC: 0.9652
#   Support: 1
#
# neworleans_funk:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.0551
#   AUC: 0.7554
#   Support: 3
#
# neworleans_secondline:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.2649
#   AUC: 0.8350
#   Support: 2
#
# neworleans_shuffle:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 1.0000
#   AUC: 1.0000
#   Support: 1
#
# pop:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.3333
#   AUC: 0.9725
#   Support: 2
#
# pop_groove7:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.0526
#   AUC: 0.9104
#   Support: 1
#
# pop_soft:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.1250
#   AUC: 0.9652
#   Support: 1
#
# punk:
#   Precision: 50.00%
#   Recall: 33.33%
#   F1-score: 40.00%
#   mAP: 0.7556
#   AUC: 0.9950
#   Support: 3
#
# reggae:
#   Precision: 50.00%
#   Recall: 33.33%
#   F1-score: 40.00%
#   mAP: 0.4654
#   AUC: 0.9665
#   Support: 3
#
# reggae_slow:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 1.0000
#   AUC: 1.0000
#   Support: 1
#
# rock:
#   Precision: 29.76%
#   Recall: 73.53%
#   F1-score: 42.37%
#   mAP: 0.5328
#   AUC: 0.7936
#   Support: 34
#
# rock_folk:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.3333
#   AUC: 0.9900
#   Support: 1
#
# rock_groove8:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.0059
#   AUC: 0.1642
#   Support: 1
#
# rock_halftime:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.2211
#   AUC: 0.8794
#   Support: 3
#
# rock_indie:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.5000
#   AUC: 0.9950
#   Support: 1
#
# rock_prog:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.4372
#   AUC: 0.9545
#   Support: 4
#
# rock_rockabilly:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.6000
#   AUC: 0.9849
#   Support: 3
#
# rock_shuffle:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.1366
#   AUC: 0.7655
#   Support: 3
#
# soul:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.3444
#   AUC: 0.9732
#   Support: 3
#
# soul_groove10:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.0097
#   AUC: 0.4925
#   Support: 1
#
# soul_groove3:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.0091
#   AUC: 0.4577
#   Support: 1
#
# soul_groove4:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 0.0179
#   AUC: 0.7264
#   Support: 1
#
# soul_groove9:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-score: 0.00%
#   mAP: 1.0000
#   AUC: 1.0000
#   Support: 1
#
# soul_motown:
#   Precision: 100.00%
#   Recall: 50.00%
#   F1-score: 66.67%
#   mAP: 0.5145
#   AUC: 0.8325
#   Support: 2
